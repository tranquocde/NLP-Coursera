# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Table of Contents
#
# - [Import Functions and Data](#0)
# - [1 - Logistic Regression](#1)
#     - [1.1 - Sigmoid](#1-1)
#         - [Exercise 1 - sigmoid (UNQ_C1)](#ex-1)
#     - [1.2 - Cost function and Gradient](#1-2)
#         - [Exercise 2 - gradientDescent (UNQ_C2)](#ex-2)
# - [2 - Extracting the Features](#2)
#     - [Exercise 3 - extract_features (UNQ_C3)](#ex-3)
# - [3 - Training Your Model](#3)
# - [4 - Test your Logistic Regression](#4)
#     - [Exercise 4 - predict_tweet (UNQ_C4)](#ex-4)
#     - [4.1 - Check the Performance using the Test Set](#4-1)
#         - [Exercise 5 - test_logistic_regression (UNQ_C5)](#ex-5)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Import Functions and Data

# %%
# run this cell to import nltk
import nltk
from os import getcwd
import w1_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/quocdetran/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/quocdetran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Imported Functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * process_tweet: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * build_freqs: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the 'freqs' dictionary, where each key is the (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs

# %% [markdown]
# ### Prepare the Data
# * The `twitter_samples` contains subsets of five thousand positive_tweets, five thousand negative_tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported build_freqs function.
#     * We highly recommend that you open utils.py and read the build_freqs function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The 'freqs' dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11427

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11436
# ```

# %% [markdown]
# ### Process Tweet
# The given function 'process_tweet' tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# <a name='1'></a>
# ## 1 - Logistic Regression
#
# <a name='1-1'></a>
# ### 1.1 - Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1 -  sigmoid
# Implement the sigmoid function.
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: sigmoid
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE ###
    # calculate the sigmoid of z
    h = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %%
# Test your function
w1_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# #### Logistic Regression: Regression and a Sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the deep learning specialization, we referred to the weights with the 'w' vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# <a name='1-2'></a>
# ### 1.2 - Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label 'y' is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - gradientDescent
# Implement gradient descent function.
# * The number of iterations 'num_iters" is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are 'm' training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use numpy.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 GRADED FUNCTION: gradientDescent
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = x.dot(theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = -1/m*(y.T.dot(np.log(h)) + (1-y).T.dot(np.log(1-h)))
        # print(J)
        # update the weights theta
        theta = theta - alpha * (1/m * x.T.dot(h-y))
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %%
# Test your function
w1_unittest.test_gradientDescent(gradientDescent)
# Out:
#  All tests passed

# %% [markdown]
# <a name='2'></a>
# ## 2 - Extracting the Features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# <a name='ex-3'></a>
# ### Exercise 3 - extract_features
# Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the 'freqs' dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)
#
# **Note:** In the implementation instructions provided above, the prediction of being positive or negative depends on feature vector which counts-in duplicate words - this is different from what you have seen in the lecture videos

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the 'get' function of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 GRADED FUNCTION: extract_features
def extract_features(tweet:list, freqs:dict, process_tweet=process_tweet):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    print(word_l)
    # 3 elements for [bias, positive, negative] counts
    x = np.zeros(3) 
    
    # bias term is set to 1
    x[0] = 1 
    
    ### START CODE HERE ###
    
    # loop through each word in the list of words
    for word in word_l:
        if freqs.get((word,1.0)):
        # increment the word count for the positive label 1
            x[1] += freqs[(word,1)]
        if freqs.get((word,0)):
        # increment the word count for the negative label 0
            x[2] += freqs[(word,0)]
        
    ### END CODE HERE ###
    
    x = x[None, :]  # adding batch dimension for further processing
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function
# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# [[1.000e+00 3.133e+03 6.100e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.000e+00 3.133e+03 6.100e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# ['blorb', 'bleeeb', 'blooob']
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %%
# Test your function
w1_unittest.test_extract_features(extract_features, freqs)
# Out:
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['blorb', 'bleeeb', 'blooob']
# ['hello', 'world', "all'", 'good']
# ['sad']
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix X.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['hey', 'jame', 'odd', ':/', 'pleas', 'call', 'contact', 'centr', '02392441234', 'abl', 'assist', ':)', 'mani', 'thank']
# ['listen', 'last', 'night', ':)', 'bleed', 'amaz', 'track', 'scotland']
# ['congrat', ':)']
# ['yeaaah', 'yipppi', 'accnt', 'verifi', 'rqst', 'succeed', 'got', 'blue', 'tick', 'mark', 'fb', 'profil', ':)', '15', 'day']
# ['one', 'irresist', ':)', 'flipkartfashionfriday']
# ['like', 'keep', 'love', 'custom', 'wait', 'long', 'hope', 'enjoy', 'happi', 'friday', 'lwwf', ':)']
# ['second', 'thought', '’', 'enough', 'time', 'dd', ':)', 'new', 'short', 'enter', 'system', 'sheep', 'must', 'buy']
# ['jgh', 'go', 'bayan', ':d', 'bye']
# ['act', 'mischiev', 'call', 'etl', 'layer', 'in-hous', 'wareh', 'app', 'katamari', 'well', '…', 'name', 'impli', ':p']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['love', 'big', '...', 'juici', '...', 'selfi', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['perfect', 'alreadi', 'know', "what'", 'wait', ':)']
# ['great', 'new', 'opportun', 'junior', 'triathlet', 'age', '12', '13', 'gatorad', 'seri', 'get', 'entri', ':)']
# ['lay', 'greet', 'card', 'rang', 'print', 'today', 'love', 'job', ':-)']
# ["friend'", 'lunch', '...', 'yummm', ':)', 'nostalgia', 'tb', 'ku']
# ['id', 'conflict', 'thank', 'help', ':d', "here'", 'screenshot', 'work']
# ['hi', 'liv', ':)']
# ['hello', 'need', 'know', 'someth', 'u', 'fm', 'twitter', '—', 'sure', 'thing', ':)', 'dm', 'x']
# ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# ["i'v", 'heard', 'four', 'season', 'pretti', 'dope', 'penthous', 'obv', 'gobigorgohom', 'fun', "y'all", ':)']
# ['yeah', 'suppos', 'lol', 'chat', 'bit', 'x', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['💅🏽', '💋', ':)', 'seen', 'year']
# ['thank', ':-)']
# ['hope', 'rest', 'night', 'goe', 'quickli', '...', 'bed', '...', 'got', 'music', 'fix', 'time', 'dream', ':)']
# ['spiritu', 'ritual', 'festiv', 'népal', 'begin', 'line-up', ':)', 'left', 'line-up', 'see', '...']
# ['hey', 'sarah', 'send', 'us', 'email', 'bitsy@bitdefender.com', "we'll", 'help', 'asap', ':)']
# ['lol', ':d']
# ['kik', 'hatessuc', '32429', 'kik', 'kikm', 'lgbt', 'tinder', 'nsfw', 'akua', 'cumshot', ':)']
# ['come', 'hous', ':)']
# ['nsn_supplement', 'effect', 'press', 'releas', 'distribut', 'result', ':)', 'link', 'remov', 'pressreleas', 'newsdistribut']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x46']
# ['everyon', 'watch', 'documentari', 'earthl', 'youtub', ':-)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# ['buuut', 'oh', 'well', ':-)']
# ['look', 'forward', 'visit', 'next', 'week', 'letsgetmessi', 'jo', ':-)']
# ['make', 'u', 'feel', 'better', 'never', 'see', 'anyon', 'kpop', 'flesh', ':d']
# ['good', 'girl', 'best', 'wish', ':-)']
# ['great', 'enough', 'reason', 'listen', 'one', 'epic', 'soundtrack', ':d']
# ['thank', 'shout', 'great', 'friday', ':)']
# ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '4']
# ['would', 'love', 'see', 'dear', 'jordan', ':)', 'wait', ':)']
# ['oh', 'okay', ':d', 'thank']
# ['like', 'fake', 'gameplay', ';)', 'haha', 'im', 'kid', 'im', 'kid', 'good', 'stuff', ':)']
# ['yeah', 'exactli', ':)']
# ['new', 'product', 'line', 'etsi', 'shop', 'check', ':)', 'boxroomcraft']
# ['hope', 'vacat', 'go', 'great', ':d']
# ['recharg', 'normal', 'come', 'charger', 'u', 'buy', ':)']
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['well', 'asleep', 'one', 'talk', 'sooo', 'someon', 'text', ':)']
# ['ye', 'suppos', 'bet', "he'll", 'blue', 'fit', 'hear', 'speech', 'today', 'piti', ':-)']
# ['green', 'garden', 'midnight', 'sun', 'beauti', 'canal', 'dasvidaniya', 'till', 'next', 'visit', ':)']
# ['scout', 'sg', 'futur', 'wlan', 'pro', 'confer', 'asia', ':)']
# ['good', 'u', 'better', 'chang', 'lollipop', '🍭', ':)']
# ['<3', 'u', 'nez', ':)', 'agnezmo']
# ['follow', 'pleas', ':)', 'big', 'dream', ':)']
# ['oley', ':d']
# ['mama', 'reason', 'stand', 'stronger', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['oh', 'god', 'misti', 'babi', 'cute', ':d']
# ['love', 'blue', ':)', 'flipkartfashionfriday']
# ['woohoo', "can't", 'wait', ':)', 'sign', 'yet', 'still', 'think', 'mka']
# ['liam', 'access', ':)']
# ['welcom', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['surpris', '...', 'amaz', 'figur', ':)']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['happybirthdayemilybett', ':)', 'wish', 'best', 'beauti', 'sweet', 'talent', 'amaz', '…']
# ['2', 'plan', 'day', 'drain', 'great', ':)']
# ['gotta', 'love', 'timezon', ':p']
# ['parent', 'proud', '—', 'lol', 'least', ':d', 'mayb', 'sometim', 'get', 'happi', 'grade', 'al', '...']
# ['grand', ':)']
# ['manila_bro', 'chosen', 'follow', 'twitter', 'thank', 'follow', ':)']
# ['sure', 'let', 'know', 'around', '..', 'side', 'world', 'eh', 'u', 'take', 'care', ':-)']
# ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# ['final', 'fuck', 'weekend', ':)']
# ['real', ':)']
# ['thank', ':d']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x45']
# ['ye', 'join', 'hushedcallwithfraydo', 'call', 'gift', '<3', 'gotta', 'get', ':d']
# ['yeahhh', ':)']
# ['dm', 'make', 'night', 'better', ':)']
# ['join', 'hushedpinwithsammi', 'event', ':d', 'might', 'get', 'text', 'day', 'luv', 'u']
# ['would', 'realli', 'appreci', 'share', 'video', 'around', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['oh', 'wow', 'beauti', 'tom', ':)']
# ['love', ':)']
# ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '3']
# ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['gym', 'monday', "can't", 'wait', ':)', 'like']
# ['hey', "here'", 'invit', 'join', 'scope', 'influenc', ':)']
# ['friend', 'know', ':)']
# ['wait', 'nude', ':-)']
# ['go', 'sleep', 'u', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['birthday', 'week', 'today', ':d']
# ['want', 't-shirt', 'cool', ':d']
# ['haw', 'phela', 'look', 'like', 'mom', 'obvious', 'look', 'like', ':)']
# ['princ', 'charm', 'stage', ':)', 'x']
# ['realli', 'good', 'luck', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['tyler', 'hipster', 'glass', ':d']
# ['hey', 'marti', 'glad', 'see', 'twitter', ':)']
# ['hi', 'join', 'today', ':)']
# ['done', 'thank', ':-)']
# ['alreadi', 'afternoon', 'let', 'read', 'al', 'kahfi', 'day', 'finish', ':)']
# ['ohmyg', 'yaya', 'dub', 'im', 'done', 'stalk', 'ig', 'accnt', '..', 'gondooo', 'moo', 'tologooo', ':)', 'haha']
# ["here'", 'invit', 'becom', 'scope', 'influenc', ':)', 'detail']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['thank', ':)', 'zzz', 'xx']
# ['physiotherapi', 'friday', 'hashtag', 'today', 'custom', ':-)']
# ['know', '💪', 'monica', 'miss', 'yeah', 'sound', 'good', ':)']
# ['good', 'morn', 'beauti', ':)', "that'", 'take']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x43']
# ['oh', 'yeah', 'definit', 'go', 'tri', 'tonight', ':)', 'took', 'advic', 'treviso']
# ['follow', 'follow', 'u', 'back', ':)']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['fine', '...', 'gorgeou', 'friday', 'friend', '..', 'xo', '..', ':)']
# ['oven', 'roast', 'garlic', 'oliv', 'oil', 'sun', 'dri', 'tomato', 'dri', 'basil', 'centuri', 'tuna', ':)']
# ['right', 'back', 'atchya', 'great', 'day', 'everyon', ':)']
# ['even', 'follow', 'back', ':-)']
# ['futur', 'almost', ':)']
# ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# ['chanc', ':)']
# ['cheer', ':)']
# ['go', 'po', 'ice', 'cream', ':)']
# ['agre', '100', ':)']
# ['heheheh', 'that', 'point', ':p']
# ['next', 'time', 'stay', 'home', ':)']
# ['thank', ':)']
# ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# ['soon', 'promis', ':)']
# ['web', 'whatsapp', 'volta', 'funcionar', 'com', 'iphon', 'jailbroken', ':-)']
# ['plan', 'watch', 'later', '34', 'min', 'leia', 'appear', 'hologram', 'r2d2', 'w', 'messag', 'obi', 'wan', 'sit', 'w', 'luke', ':)']
# ['inter', '3', 'ucl', 'arsen', '...', 'small', 'team', 'right', ':)']
# ['pass', ':)', '🚂', 'dewsburi', 'railway', 'station', 'dew', 'dewsburi', 'west', 'yorkshir']
# [':)', '430', 'smh']
# ['9:25', ':)', 'live', 'scotland', ':)', 'strang', 'imagin', 'megan', 'xx']
# ['masaantoday', 'masaantoday', 'a4', '...', 'shweta', 'tripathi', 'masaantoday', 'masaantoday', ':-)', '..']
# ['5', '20', 'w', 'kurta', 'mom', 'half', 'number', ':d', 'wsalelov']
# ['ah', 'hello', 'back', 'larri', ':)']
# ['anyway', 'friday', 'look', 'kinda', 'goood', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['lol', 'well', "that'", 'life', ':)', 'thank', 'god', 'enn']
# ['sure', 'could', 'warmup', 'morn', 'come', '15th', 'bath', ':)', 'xx']
# ['dum', 'dum', 'andar', 'ram', 'sampath', 'sona', 'mohapatra', 'samantha', 'edward', 'mein', 'tulan', 'razi', 'razi', 'wah', "that'", 'josh', ':)']
# [':)', 'alway', 'smile']
# ['pictur', ':)']
# ['thank', 'time', '16.20', 'right', "that'", 'perfect', 'time', ':)']
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['know', ':)']
# ['giveitup', 'alreadi', 'given', 'ga', 'subsidi', 'long', 'back', 'initi', 'propos', '..', 'feel', 'delight', 'done', ':)']
# ['miss', 'yesterday', ':-)']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x42']
# ['lmaoo', 'best', 'song', 'ever', '<3', 'shall', 'littl', 'throwback', 'week', ':p']
# ['go', 'outli', 'island', 'cheung', 'chau', 'mui', 'wo', '...', 'total', 'differ', ':)']
# ['kfckitchentour', 'kitchen', 'clean', "i'm", 'total', 'amaz', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['cusp', 'test', 'water', 'hope', 'reward', ':)']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['arummzz', "let'", 'go', '...', "i'll", 'drive', ':p', 'travel', 'travel', 'yogyakarta', 'jeep', 'indonesia', 'instamood', '…']
# ['anyon', 'wanna', 'skype', ':d']
# ['may', 'look', 'bit', 'real', 'nice', 'friendli', 'girl', ':-)']
# ['im', 'like', 'pretend', ':)']
# ['watch', 'concert', 'film', ':)']
# ['congratul', 'winner', 'cheesydelight', 'contest', ':)', 'pleas', 'dm', 'us', 'address', 'contact', 'number']
# [':)', 'great', 'weekend', 'guy']
# ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# ['cool', 'see', 'film', 'today', ':)']
# ['check', 'email', 'market', '24/7', 'regret', 'buy', ':)']
# ['lol', 'come', 'join', 'us', '...', 'see', 'u', 'around', '14', 'hour', 'u', 'leav', 'without', 'delay', ':)']
# ['actual', 'easi', 'like', 'must', 'station', 'guess', 'train', 'wd', 'take', 'least', 'hour', 'shift', 'engin', 'etc', ':-)']
# ['sunburn', 'peel', ':-)']
# ['visit', 'blog', 'thank', ':d']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['talk', 'help', ':)']
# ['huge', 'warm', 'welcom', ':-)', '☆', 'final', 'complet', 'triangl', '☆']
# ['live', 'northern', 'ireland', ':)', 'sight', 'seen']
# ['follow', 'follow', 'u', 'back', ':)']
# ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['feel', 'smthng', 'smthng', 'fr', 'u', '...', 'lol', '...', 'wanna', 'hug', 'u', '...', 'xoxo', '...', 'love', 'uu', 'jaann', 'take', 'care', ':)', '<3']
# ['thank', 'mom', ':)']
# ['thank', 'topnewfollow', 'happi', 'connect', ':)']
# ['wonder', 'thing', 'made', 'feel', 'fluffi', 'insid', 'great', 'pirouett', 'moos', ':d']
# ['trip', 'philli', 'decemb', ':)', "i'd", 'love', 'come', 'dude']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x41']
# ['question', 'flaw', 'pain', 'negat', 'strength', ':)']
# ['went', 'solo', 'move', 'made', ':d']
# ['hey', 'fav', 'nirvana', 'song', 'smell', 'like', 'teen', 'spirit', 'rip', 'ami', 'winehous', ':-)']
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ["let'", 'go', '...', "i'll", 'drive', ':p', 'travel', 'travel', 'yogyakarta', 'jeep', 'indonesia', 'instamood', '…']
# ['name', 'coupl', 'yet', 'tomhiddleston', 'elizabetholsen', 'yaytheylookgreat', ':)']
# ['love', 'goodnight', 'vid', 'go', 'wake', 'love', 'one', ':)']
# ['weekend', 'gonna', 'shoot', 'love', '<3', 'pictur', 'made', 'last', 'time', ':d']
# ['anyway', ':-)']
# ['itti', 'bitti', 'teeni', 'bikini', ':)']
# ['join', 'hushedpinwithsammi', 'event', ':d', 'might', 'get', 'text', 'day', 'luv', 'u']
# ['alway', 'much', 'fun', '4th', 'hour', 'get', 'togeth', ':)', 'end', 'night', 'ice', 'cream', 'xfile', 'content']
# ['easi', ':d']
# ['ye', 'surpris', 'see', 'bit', 'rain', 'today', '...', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['fabul', 'friday', 'keep', 'fantast', 'work', ':)']
# ['pleas', 'follow', '♡', '♡', '♡', 'pleas', 'jb', 'follow', 'love', 'alway', 'forev', "i'm", 'belieb', '♡', '♡', '♡', ':)', 'love', 'u']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['morn', ':)']
# ['good', 'hear', ':)']
# ['nighti', 'night', 'let', 'bed', 'bug', 'bite', ':d']
# ['beauti', 'bracelet', 'good', 'idea', ':)']
# ['wait', 'foundri', ':)']
# ['like', 'game', ':)']
# ['ah', 'make', 'sens', '...', 'see', 'pic', 'ef', 'phone', 'last', 'night', 'woot', ':)', 'x']
# ['hi', 'derek', 'could', 'tri', 'use', 'parkshar', 'gloucestershir', ':)']
# ['aaaahhh', 'man', 'track', 'traffic', 'stress', 'reliev', ':)']
# ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# ["how'r", 'today', 'dear', ':)']
# ['hear', 'guy', 'want', 'arbeloa', ':d']
# ['turn', '17', '15', 'day', '...', 'omg', 'least', '3', 'year', 'differ', ':)']
# ['well', 'say', 'europ', 'rise', 'find', 'hard', 'believ', ':)']
# ['wsalelov', 'uncount', 'coz', 'love', 'unlimit', ':)']
# ['ye', 'cours', ':)', 'teamposit']
# ['ye', 'love', ':-)', 'aldub']
# [':)', '☕', '☕', '☕', 'thank', 'rita']
# ['hi', 'could', 'pleas', 'dm', 'us', 'info', "we'd", 'happi', 'help', ':)']
# ['way', 'boy', ':)']
# ['hope', 'get', 'lot', 'nice', 'gift', ':d']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x40']
# ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# ['true', ':)']
# ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '3']
# ['sethi', 'high', ':)']
# ['exe', 'skeem', 'saam', ':)']
# ['peopl', 'make', 'smile', ':)']
# ['thank', 'invit', ':)']
# ['polit', 'izzat', ':)', 'wese', 'trust', 'khawateen', 'k', 'sath', 'selfi', 'say', 'mana', 'kar', 'deya', ':)']
# ['thank', "that'", 'friday', 'even', 'sort', ':-)']
# ['smart', ':)']
# [':-)', 'nice', 'hair', 'tbh']
# ['5', 'year', ':)']
# ['jacob', 'g', 'upgrad', ':-)']
# ['nice', 'tee', 'man', ':)']
# ['happi', 'famili', 'vacat', '..', ':d', 'pic', '—']
# ['sleep', 'would', 'nice', ':-)']
# ['read', 'beauti', 'like', 'read', ':)']
# ['talk', 'one', 'person', '...', 'two', 'convers', ':)']
# ['skype', 'fun', ':-)']
# ['onlin', ':)']
# ['...', 'friday', ':d']
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['someth', 'get', 'friday', 'great', 'start', ':)', 'great', 'day', 'mclaren', 'fridayfeel', 'tgif']
# ['follow', 'follow', 'u', 'back', ':)']
# ['squar', 'enix', 'bissmillah', 'ya', 'allah', ':)']
# ["we'r", 'train', 'socent', 'startup', 'week', 'w', "we'd", 'love', 'drop', 'your', 'arnd', 'town', ':)']
# ['basic', 'piss', 'cup', 'test', ':)']
# ['next', ':)']
# ['also', 'twitter', 'terribl', 'complic', 'discuss', ':)']
# ['snapchat', 'lynettelow', 'snapchat', 'kikmenow', 'snapm', 'hot', 'snapchat', 'amazon', 'kikmeguy', ':)']
# ['look', 'forward', '12', 'hour', 'shift', 'today', ':)']
# ['defin', 'agre', 'grow', 'sport', 'drop', 'email', 'detail', 'see', ':-)']
# ['last', 'rt', ':)']
# ['...', 'rakyat', 'keep', 'visit', 'blog', 'read', 'write', ':)']
# ['ever', 'sinc', 'mention', 'fli', 'fish', 'day', "i'm", 'get', 'follow', 'promot', 'post', 'lol', 'cyber', 'stalk', ':-)']
# ['ourdaughtersourprid', 'mypapamyprid', 'proud', 'papa', 'coach', ':)']
# ['great', 'talk', ':d']
# ['never', 'see', 'posit', 'kha', 'u', 'could', 'also', 'mention', 'atleast', 'go', ':)']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x39']
# ['mango', "lassi'", "monty'", 'marvel', ':d', 'though', 'suspect', "that'", 'meant', '...']
# ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['haha', 'ye', '24', 'hr', 'time', 'come', 'touch', 'kepler', '452b', 'chalna', 'hai', ':d']
# ['follow', 'follow', 'u', 'back', ':)']
# ['thankyou', 'pretti', ':)']
# ['definit', 'hazel', 'food', 'market', 'brooklyn', 'pta', ':)']
# ['still', 'awak', ':)']
# ['okayi', ':d']
# ['awww', 'thank', ':)']
# ['ha', 'surpris', 'least', 'okay', 'see', 'doc', 'afternoon', 'yorkshir', 'splendid', 'though', ':)', 'xx']
# ['spam', 'folder', 'wow', 'huge', 'amount', 'need', 'travel', 'nigeria', 'claim', ':)']
# ['rted', 'good', 'luck', ':)']
# ['leg', 'hurt', 'bad', ':)']
# ['get', 'mine', 'saturday', ':-)']
# ['thaaank', 'decemb', 'puhon', ':)']
# ['happinesss', ':)']
# ['true', 'chang', 'tnc', 'without', 'prior', 'notif', 'could', 'use', 'last', 'night', ':-)']
# ['probabl', 'find', 'funni', '2:22', ':-)']
# ['fat', 'co', 'probabl', 'ate', 'yuna', ':d', ':d', ':d']
# ['fun', 'tamesid', ':)']
# [':-)', ':-)', ':-)']
# ['´', 'welcom', ':)']
# ['googl', 'account', ':)']
# ['call', 'scouser', 'everyth', 'hope', 'zoe', 'well', 'mate', ':)']
# ['right', 'liter', 'like', 'mayb', 'u', 'get', 'peopl', 'actual', 'know', "they'r", ':-)']
# ['samee', 'rest', 'well', ':)']
# ['happi', 'birthday', 'edgar', 'hope', 'good', 'one', 'keep', 'updat', 'travel', 'log', ':)']
# ['hello', ':d']
# ['bring', 'abe', ':)']
# ['stat', 'day', 'arriv', '2', 'new', 'follow', 'unfollow', ':)', 'via']
# ['someon', 'talk', ':)']
# ['never', 'ever', 'meet', ':d']
# ['come', 'man', ':d', ':d']
# ['follow', 'follow', 'u', 'back', ':)']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x38']
# ['sigh', 'dreamili', 'pout', 'come', 'bath', 'eye', ':-)', 'quacketyquack']
# ['happi', 'birthday', 'love', ':)']
# ['cheer', ':-)']
# ['funni', 'happen', 'phil']
# ["i'd", 'call', 'em', 'del', 'rodder', ':)', 'els']
# ['hi', 'may', 'like', 'play', 'newest', 'gamejam', 'game', 'would', 'happi', ':)']
# ['great', 'irish', 'literatur', 'realli', 'inaccess', 'us', 'without', 'irish', ':)']
# ['yeah', 'fun', ':)', 'flipkartfashionfriday']
# ['nice', 'music', ':)', 'check']
# ['strang', "kareena'", 'fan', 'know', "kareena'", 'fan', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['better', ':)']
# ['cool', 'look', ':)']
# [':)', 'beauti']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# ["that'", 'fair', 'enough', ':)', 'rush', 'back', 'either']
# ['brandi', '18', 'fb', 'drop', 'selfi', ':)', 'fun']
# ['follow', 'follow', 'u', 'back', ':)']
# ['carniv', 'men', 'put', 'mask', 'mask', 'xavier', 'forneret', ':-)']
# ['jennif', 'check', 'site', 'u', 'wanna', 'get', 'free', '50.000', '8', 'ball', 'pool', 'coin', 'thank', ':)']
# ['beauti', 'edit', 'trish', ':)', 'love', '♥']
# ['grate', 'happi', ':)', 'post', 'three', 'thing', 'grate', 'today', 'comment']
# ['love', 'wakeup', 'besid', 'real', 'dirti', 'dirti', 'sex', ':-)']
# ['lmaooo', 'hot', '😤', '😤', 'like', 'loui', ':)', "he'", 'hot']
# ['gonna', 'throw', 'idea', 'caus', "they'r", 'bad', 'inspir', 'think', 'someth', 'much', 'better', ':-)']
# ['ff', 'best', 'twoof', 'follow', 'gr8', 'wkend', ':)']
# ['wish', 'could', 'mayb', 'one', 'year', ':)']
# ['hey', 'guy', ':)']
# ['think', 'need', 'go', 'bed', 'kind', 'exhaust', 'good', 'night', 'twitter', ':)']
# ['thank', 'much', '..', 'glad', 'like', '..', ':-)']
# ['get', 'better', 'time', ':)']
# ['kind', 'word', 'thank', 'much', 'much', 'good', 'cheltenham', 'area', ':)']
# ['hi', 'beauti', 'follow', 'pleas', ':)']
# ['’', 'kale', 'crisp', ':-)', 'ruin', 'good', 'thing']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x37']
# ['open', 'worldwid', ':)']
# ['get', 'fuck', 'outta', ':d']
# ['cool', 'guy', 'sfvbeta', 'releas', 'work', ':)']
# ['realli', 'look', 'vantast', ':)']
# ['today', 'final', 'time', 'work', 'xcylin', ':d']
# ['thank', 'bundl', 'show', 'internet', 'price', 'phone', 'realisticli', 'pay', 'net', ':)']
# [':)', 'true', 'educ', 'power', 'weapon', 'use', 'chang', 'world', 'nelson', 'mandela']
# ['follow', 'follow', 'u', 'back', ':)']
# ['recent', 'trip', 'j', 'k', 'total', 'love', ':d', "that'", 'chenab', 'flow', 'pakistan', 'incredibleindia']
# ['teenchoic', 'choiceinternationalartist', 'superjunior', ':)']
# ['caught', 'first', 'salmon', 'today', ':d']
# ['happi', 'friday', 'check', 'see', 'enjoy', 'super-blend', ':)']
# ['thank', 'follow', 'get', 'touch', 'like', 'info', 'project', 'youth@bipolaruk.org.uk', ':)']
# ['pleas', 'go', 'check', 'awesom', "friend'", 'stream', "he'", 'fantast', 'artist', ':)']
# ['alma', 'mater', ':)', 'highschoolday', 'clientvisit', ':)', 'faith', 'christian', 'school']
# ['good', 'luck', 'lizaminnelli', 'upcom', 'uk', 'appear', ':-)']
# ['lol', '😄', '😄', 'realli', "can't", 'believ', 'beauti', 'girl', 'like', 'singl', ':p']
# ['never', 'listen', 'hill', 'everi', ':-)']
# ['would', 'listen', 'beat', '1', 'went', 'wrong', 'life', ':)']
# ['haha', "that'", 'great', ':)']
# ['get', 'everyth', 'readi', 'natur', 'pefumeri', 'workshop', 'neal', 'yard', 'covent', 'garden', 'tomorrow', ':)']
# ['fback', ':)', 'indo', 'harmo']
# ['americano', ':)']
# [':-)']
# ['love', 'way', ':)', '<3']
# ['alway', 'rememb', ':)']
# ['aww', 'thank', 'beauti', 'pic', ':d']
# ['head', ':)']
# ['hi', 'saw', 'u', 'follow', 'thought', 'u', 'might', 'like', 'dark', 'plz', 'let', 'us', 'know', 'u', 'think', ':)']
# ['smart', 'handshom', 'cute', 'juga', ':d']
# ['hurray', 'look', 'forward', 'meet', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['caus', 'hate', 'cours', 'lol', 'cant', 'decid', 'want', 'chang', 'im', 'go', 'take', 'time', 'save', 'mayb', 'travel', ':)']
# ['list', "i'm", 'still', 'show', ':)']
# [':)']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['oh', 'awesom', 'thank', 'much', ':)']
# ['perfect', ':)']
# ['hiya', 'email', 'web', 'exec', 'loryn.good@lincs-chamber.co.uk', 'abl', 'help', ':)']
# [':)', 'enjoy', 'photo', 'mom', 'babi']
# ['big', 'thx', '4', 'kind', 'support', 'good', 'luck', ':-)']
# ['china', 'actual', 'girl', 'homosexu', 'love', 'either', 'way', ':d', 'hyungbot']
# ['caus', 'like', 'lot', ':)']
# ['give', 'time', 'fam', 'got', 'thing', 'mind', ':-)']
# ['thank', 'god', 'friday', ':)', 'jgh']
# ['love', ':)']
# ['timetunnel', '1982', 'quit', 'sure', 'radio', 'set', 'heart', ':)']
# ['hiii', 'jack', ':)', 'ili', '✨', '✨', '✨']
# ['play', 'domino', 'pub', 'got', 'quit', 'heat', 'enjoy', 'though', ':d']
# ['prob', ':)']
# ['enjoy', 'sorri', 'hastili', 'type', 'messag', ':)']
# ['ff', 'thank', ':-)']
# ['say', 'big', 'thank', 'person', 'came', 'idea', 'screenshot', ':-)']
# ['true', 'pakistani', ':p']
# [':)', '...', 'mention']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x36']
# ['3point', 'dreamteam', 'gooo', 'bailey', ':)', 'pbb', '737gold']
# ['thank', ':)']
# ['drank', ':)']
# ['old', 'pic', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['gotten', 'sleep', '3', '1/2', 'hour', ':)']
# ['welsh', 'wale', 'today', 'yippe', ':-)']
# ['done', ':)']
# ['happi', 'birthday', 'babi', '💟', '💟', 'miss', 'much', 'love', 'much', ':)']
# ['thank', 'bro', ':d', 'x']
# ['that', 'lord', ':)']
# ['sweet', ':)']
# ['like', 'michael', ':)', 'thank', 'kind', 'word', 'cheer', 'em']
# ['morn', 'realli', ':d', "u'r", 'alreadi', 'fun', 'caus', 'weekend', 'right', ':d', 'ure', 'futur', ';)', 'amaz', 'night']
# ['wait', 'peopl', 'call', 'bigot', ':p']
# ['usual', ':)', 'front', 'back', 'squat']
# ['much', 'fun', 'realli', 'enjoy', 'hope', 'next', 'contest', 'come', 'soon', ':-)', ':-)', ':-)']
# ['dobar', 'dan', ':)', 'brand', 'new', 'heavi', 'musicolog', '2015', 'day', '2']
# ['look', 'like', 'great', 'way', 'spend', 'friday', 'afternoon', 'enjoy', 'marathon', 'iflix', ':)']
# ['need', 'someon', 'talk', 'alway', ':)', 'keep', 'head']
# ['offici', 'graduat', ':d']
# ["i'm", 'glad', ':d', 'cri', '__']
# ['thank', ':)']
# ['yep', 'expert', 'bisexu', ':)', 'good', 'luck']
# ['minal', 'aidzin', 'yo', 'pi', ':d']
# ['follow', 'follow', 'u', 'back', ':)']
# ['plan', 'read', 'brand', 'new', 'cook', 'book', 'figur', 'make', 'dinner', 'tonight', ':)']
# ['lol', 'tough', 'choic', 'tbh', 'realli', 'like', 'everi', 'song', 'other', ':p']
# ['welcom', '...', ':-)', ':-)']
# ['chill', 'smu', 'oval', ':d', 'coz', 'basketbal', 'player', 'whahahaha', 'soamaz']
# ['moment', 'decid', 'log', 'onto', 'account', 'year', 'moment', 'saw', 'best', 'thing', 'ever', ':)']
# ['a5', 'girl', 'wardrob', 'would', 'w', ':)', 'wsalelov']
# ['new', 'user', ':-)']
# ['welcom', 'back', 'teamr', ':)']
# ['oh', 'appar', "i'm", 'alreadi', 'member', 'lol', 'hope', 'abl', 'come', 'depend', 'time', ':d']
# ['greatli', 'appreci', ':)']
# ['hi', 'made', 'chang', 'design', 'hope', 'like', ':)']
# ['ahhh', 'ye', ':d']
# ['7th', 'cinepambata', 'video', 'festiv', 'complet', 'mechan', 'offici', 'entri', 'form', 'may', 'download', 'sali', 'na', ':d']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['follow', 'follow', 'u', 'back', ':)']
# ['ur', 'mom', 'get', 'u', 'swisher', 'ur', 'cop', 'monday', ':)']
# ['song', 'week', 'ducktail', 'surreal', 'exposur', 'sotw', 'jingli', 'jangli', 'loveli', ':-)']
# ['halesowen', 'blackcountryfair', 'tomorrow', 'follow', 'go', 'come', 'say', 'hello', 'stand', 'high', 'street', ':-)']
# ['good', 'luck', 'assess', 'today', ':)']
# ['mental', 'strength', ':d']
# ['look', 'beauti', 'amaz', 'bodi', 'ooz', 'sex', 'appeal', ':)', 'xx']
# ['home', 'amassiveoverdoseofship', 'latest', 'vid', 'way', '..', 'enjoy', 'visit', 'site', '..', ':)']
# ['isi', 'chan', ':d']
# ['c', 'note', ':)', 'pkwalasawa']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['thank', 'follow', 'gemma', 'enjoy', 'new', 'orlean', ':)']
# ['fever', 'final', 'caught', '..', 'geskenya', 'obamainkenya', 'magicalkenya', ':-)', 'greatkenya', 'allgoodthingsk']
# ['funni', 'next', 'anim', 'umaru', ':d']
# ['great', 'singer', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['look', 'like', 'game', 'ship', 'us', 'got', 'order', ':)']
# ['take', 'room', 'car', "i'm", 'gone', 'cool', ':)']
# ['go', 'stream', 'soon', ':)']
# ['thank', ':)']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['hahaha', 'everyon', 'fun', 'stori', 'relat', 'song', 'got', 'label', 'worst', 'batch', 'princip', 'due', ':p']
# ['get', 'stuff', 'like', 'march', 'releas', 'one', 'first', 'start', 'new', 'one', ':)']
# ['ff', 'top', 'twoof', 'wooftast', 'wkend', 'guy', ':)']
# ['well', 'receiv', 'necessari', ':)']
# ['long', 'time', 'see', ':/', ':p']
# ["i'll", 'regret', 'rn', 'tomorrow', 'morn', 'whatev', ':)']
# ['hat', ':d']
# ['thank', ':)']
# ['never', 'love', 'life', 'success', ':)']
# ['abstin', ':)']
# ['wtf', 'never', 'happen', 'moment', 'may', 'may', 'like', "there'", 'surpris', 'thrown', ':d']
# ['start', 'middl', 'finish', ':)']
# ['im', 'back', 'twitter', '..', ':-)']
# ['end', 'happi', ':)']
# ['love', 'stuff', 'need', 'repeat', 'relentlessli', 'approxim', 'next', '5', 'year', ':)']
# ['hug', 'mani', ':)']
# ['oldschool', 'runescap', ':)']
# ['thank', 'shout', 'wonder', 'weekend', ':)']
# ['rest', 'day', ':)']
# ['love', 'daaay', ':d']
# ['jumma_mubarik', '<3', '<3', '<3', 'frnd', 'stay_bless', ':)', ':)', '—', 'feel', 'bless']
# ['sens', ':)']
# ['awww', 'pussycat', ':-)', 'xx']
# ['hope', 'everyth', 'go', 'great', ':-)', 'lol']
# ['market', 'main', 'launch', 'pretoria', ':)']
# ['care', 'care', '...', 'fahrinahmad', 'tengkuaaronshah', 'eksperimencinta', ':d']
# ['tykkäsin', 'videosta', '200sub', 'special', '15e', 'paysafecard', 'giveaway', ':)', 'lue', 'desc']
# ['2', 'month', 'wait', 'final', 'hoodi', ':)', 'eeep', 'yay', 'sohappyrightnow']
# ['mmm', 'c', 'love', 'azz-set', 'babe', ':-)']
# ['thx', 'feedback', 'glad', 'gain', 'valu', ':)']
# ['good', 'night', 'love', 'hope', 'peac', 'night', 'rest', 'feel', 'refresh', 'wake', 'sweet', 'dream', ':)']
# ["i'll", 'never', 'get', 'use', 'thank', 'much', ':)']
# ['thank', 'manthan', 'stay', 'tune', 'us', ':)']
# ['fresh', 'beauti', 'smile', 'mother', 'determin', 'make', 'day', ':)', 'maxfreshmov']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# ['pleas', 'jame', 'think', 'beauti', 'girl', 'loneliest', 'tattoo', 'chang', 'life', ':)']
# ['hi', 'girl', ':)', 'wish', 'happi', 'friday.and', 'magnific', 'fantast', 'w', 'e', '♡', '♥', '♡', '♥']
# ['achiev', 'togeth', 'thank', 'rashmi', 'time', 'dedic', 'complet', 'inspir', ':)']
# ['ff', 'happyfriday', 'weekend', 'nearli', ':-)']
# ['retweet', ':)']
# ['updat', 'soon', "i'm", 'sure', 'sign', 'set', 'text', 'alert', ':)', 'da']
# ['someth', 'new', ':d']
# ['dang', 'rad', 'fanart', ':d']
# ['cheer', 'tgif', ':-)']
# ['massiv', 'congrat', 'niamh', 'fennel', ':)', 'journal', 'graduat', 'land', 'dream', 'job', 'copi', 'past', 'tweet']
# ['thank', ':)']
# ['stat', 'day', 'arriv', '5', 'new', 'follow', 'unfollow', ':)', 'via']
# ['yesss', 'thank', ':d']
# ['ariana', 'grand', 'selena', 'gomez', 'loui', 'tomlinson', 'rita', 'liam', 'payn', 'caradelevingn', '🌷', 'trade', 'solo', 'dm', ':)']
# ['tire', 'fine', ':)']
# ['nope', 'definit', 'still', 'appli', 'year', 'want', ':d', 'iamca']
# ['ah', 'found', 'thank', ':)']
# ['afti', ':p']
# ['goodmorn', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['’', 'exactli', 'look', '’', 'go', ':d']
# ['prokabaddi', 'koel', 'mallick', 'recit', 'nation', 'anthem', 'day', '6', ':)']
# ['yournaturallead', 'youngnaturallead', 'mon', '27juli', 'cumbria', 'uk', ':)', 'flockstar', 'thur', '30juli', 'itv']
# ['goodmorn', 'goodnight', '...', 'sleeptight', 'haveagoodday', ':)']
# ['one', 'leg', 'septemb', 'perhap', 'bb', 'promot', 'full', 'album', 'septemb', ':d']
# ['still', 'fulli', 'intend', 'write', 'mani', 'game', 'design', 'possibl', 'attack', 'plan', 'next', '6', 'month', '>:d']
# ['bird', 'come', 'join', 'us', 'littl', 'fun', ':)', 'teamadmicro']
# ['fridaydownpour', 'hope', 'clear', 'wkend', 'good', 'one', ':)']
# ['time', 'sleep', ':)']
# ["that'", 'three', 'word', "that'", 'rohit', ':d']
# ['gorgeou', 'queen', '...', 'god', ':)']
# ['long', 'wait', ':)', 'otwolgrandtrail']
# ['get', 'inspir', 'sheer', 'fact', 'obama', 'beat', 'innumer', 'odd', 'becom', 'us', 'presid', 'ni', 'shauri', 'yako', ':-)', 'memotohat']
# ['everyon', 'go', 'drop', 'follow', 'stream', ':d']
# ['happi', 'birthday', 'sunday', ':)', 'hope', 'great', 'day', 'lot', 'pamper', 'love']
# ["t'wa", 'great', 'thank', ':)']
# ["i'm", 'go', 'cabincrew', 'interview', 'langkawi', '1st', 'august', ':)', 'pleas', 'wish', 'luck']
# ['thank', ':d']
# ['fulfil', 'fantasi', ':)', '👉', '👈', '💖']
# ['cool', 'thank', 'think', 'hope', 'well', ':-)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['thank', 'much', 'babe', ':d']
# ['5', 'ex-tweleb', 'side', 'pleas', ':)']
# ['thank', 'bro', ':d', 'x']
# ['great', 'day', ':d']
# ['make', 'much', 'sens', ':d', 'lol']
# ['..', 'wait', ':)']
# ['ff', 'great', 'weekend', ':)']
# ['famili', 'friend', ':)']
# ['apart', 'makeov', 'great', 'idea', 'factori', 'live', ':)']
# ['thank', 'welcom', 'hope', 'goe', 'brilliantli', ':)']
# ['happyyi', 'birthdaaayyy', ':-)']
# ['come', 'kill', ':)']
# ['hi', 'im', 'interest', 'internship', 'program', 'sadli', 'cant', 'access', 'career', 'page', 'u', 'help', 'issu', ':)']
# ['sad', 'hear', 'thank', 'much', 'overwhelmingli', 'beauti', 'game', 'thank', 'hard', 'work', ':)']
# ['aha', 'yesss', 'look', 'forward', 'see', ':)']
# ['happi', 'friday', 'beaut', ':)', '♬', 'ff']
# ['love', 'help', ':)', 'e']
# ['would', 'love', 'win', 'deo', 'faaabul', ':d', 'freebiefriday', 'aluminiumfre', 'stayfresh', 'xx']
# ['ye', 'john', ':)']
# ['thank', 'worri', "i'll", 'navig', 'blog', 'check', ':)']
# ['thnk', 'progrmr', ':-)']
# ['bet', 'well', 'get', 'sleep', '9pm', 'shift', '9am', 'quit', 'hard', 'work', 'thank', ':)', 'xx']
# ['figur', ':-)']
# ['hardli', 'surpris', 'rose', 'inspir', 'much', 'emot', 'poetri', ':)']
# ['follow', ':)']
# ['join', 'frequentfly', 'program', ':)']
# ['alway', 'end', 'break', 'apolog', 'fuck', 'nice', ':-)']
# ['fabul', 'well', 'hope', 'great', 'day', ':-)', 'kb']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['welcom', ':)']
# ['visit', 'blog', 'thank', ':d']
# ['enjoy', 'londondairi', 'icecream', 'share', 'us', 'experi', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['luv', 'ur', ':-)']
# ['past', 'hoodi', 'cover', 'lot', 'sin', ':)']
# ['bet', 'excit', ':)', ":')", 'xxx', 'good', 'luck', 'hope', 'get', 'number', 'one']
# ['welcom', 'jim', 'made', 'chuckl', 'train', 'morn', ':-)', 'happi', 'friday']
# ['shop', 'bit', ':p']
# ['agre', 'haha', ':p']
# ['happi', 'birthday', "we'r", 'posit', 'full', 'cake', ':)']
# ['doh', '500', 'subscrib', 'need', ':)', 'pleas', 'let', 'us', 'know', 'reach', 'number']
# ["i'm", 'good', 'thank', 'hope', 'well', ':-)', 'xx']
# ['dri', 'hot', 'scorch', 'summer', 'ff', ':)']
# ['mayb', 'younger', 'woman', 'stamina', 'tom', ':)']
# ['thing', 'look', 'great', 'either', 'expect', 'anyth', 'less', 'lol', 'least', 'weekend', ':)']
# ['final', 'get', 'bed', ':)', 'good', 'night', 'tweeti']
# ['thank', 'guy', ':)']
# ['fab', 'thank', 'support', ':)']
# ['realli', 'dont', 'love', 'much', ':)']
# ['ff', 'follow', '-->', '10', 'loner', 'side', 'pleas', ':)']
# ['charger', ':)']
# [':-)']
# ['introduc', 'new', 'word', 'vs', 'alter', 'understand', 'word', 'x', 'spread', 'either', 'big', 'problem', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['ff', 'wooftast', 'twoof', 'hope', 'supa', 'dupa', 'weekend', ':)']
# ['near', 'enough', 'dartmoor', ':)']
# ["i'm", 'gonna', 'stay', 'gold', 'colour', 'hope', 'come', 'soon', 'thank', 'anyway', ':)']
# ['follow', 'back', ':)']
# ['yay', 'ok', ':d']
# ['someday', "we'll", 'know', ':)']
# ['u', 'r', 'dii', 'n', 'cant', 'forget', 'si', ':)']
# ['jgh', 'fr', 'smf', 'ft', 'w', 'girl', '<3', ':)']
# ['mayb', 'get', 'japanes', 'import', 'hello', 'kitti', 'match', 'stationari', ':)']
# ['weekend', 'draw', 'close', 'plan', ':d']
# ['hi', 'saw', 'u', 'follow', 'thought', 'u', 'might', 'like', 'dark', 'plz', 'let', 'us', 'know', 'u', 'think', ':)']
# ['hello', 'twitter', 'account', 'broken', ':)']
# ['hi', 'thank', 'connect', 'specialis', 'thermal', 'imag', 'survey', '–', 'need', 'us', ':)']
# ['nice', ':)']
# ['pleas', 'follow', 'back', ':)', 'x', '10']
# ['hi', 'want', 'get', 'connect', ':)', 'plan', 'come', 'south', 'korea']
# ['oh', 'fact', ':p']
# ["i'd", 'plan', 'nice', 'scamper', 'slept', 'alarm', 'two', 'hour', 'suppos', 'need', 'sleep', "ain't", 'mad', ':)']
# ['chweina', '...', 'xd', 'jotzh', ':d', 'dude', '...', 'go', 'school', 'wast', 'time', 'twitter']
# ['hiya', 'yep', 'show', 'take', 'place', 'complet', 'cover', 'worth', 'bring', 'coat', 'beforehand', 'tho', 'foh', 'outsid', ':-)']
# ['thank', ':)']
# ['enjoy', 'holiday', ':d']
# ['seen', 'mani', 'menac', 'sinc', 'finish', 'jojo', ':d']
# ['ta', ':)']
# ['thank', 'alway', 'last', '’', 'back', 'track', ':)', 'hope', 'fantast', 'weekend', ':)']
# ['make', 'better', 'though', ':-)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['accept', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['go', 'guy', 'hope', 'enjoy', 'updat', ':)', 'bye', 'admin', 'lukri']
# ['love', 'day', 'ye', 'stay', 'happi', ':)', '😘']
# ['day', ':)']
# ['happi', 'birthday', 'momma', 'bear', 'love', 'much', '❤', '️', 'redid', 'found', 'last', 'pictur', '8th', 'grade', ':)']
# ['k', "i'll", 'text', 'tomorrow', ':-)']
# ['im', ':)', 'x']
# ['love', 'u', ':p']
# ['nice', 'line', ':-)', ':-)']
# ['play', 'v.ball', 'atm', ':)']
# ['appreci', 'recent', 'retweet', 'great', 'friday', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['build', 'product', 'like', 'pack', 'suitcas', 'plan', 'think', 'need', 'remov', 'half', 'fulli', 'agre', ':)']
# ['hang-copi', 'translat', "dostoevsky'", 'note', '..', ':)']
# ['voucher', '...', 'new', 'bugatti', "what'", 'valu', ':d']
# ['someon', 'love', 'promis', ':)']
# ['know', 'bra', 'know', 'bra', 'get', ':d']
# ['مطعم_هاشم', 'yummi', ':-)', 'a7la', 'bdayt', 'season', ':-)', 'mnwreeen', ':-)', ':-)']
# ['listen', 'jazz', 'truck', ':)']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x34']
# ["can't", 'wait', 'speak', 'pbevent', 'see', ':)']
# ['wait', 'hq', 'pic', 'today', 'add', 'yoona', 'x', 'hairpin', 'otp', 'collect', ':d']
# ['mastership', 'honey', ':d']
# ['paindo', 'want', 'say', 'follow', ':p']
# ['sure', ':)']
# ['awesom', 'await', 'report', ':d']
# ['throwback', 'lol', 'manni', 'still', 'asshol', ':)']
# ['brijresid', 'g', '6', 'stori', 'structur', '156', 'unit', 'encompass', '2', '3', 'bhk', 'flat', ':d', '91', '975-580-', '444']
# ['honor', ':-)']
# ['know', 'like', ':d']
# ['follow', 'follow', 'u', 'back', ':)']
# ['curri', 'close', 'home', ':)']
# ['clash', ':)', 'milano', 'call', '👌']
# ['followback', 'po', ':-)', ':-d']
# ['legit', 'loser', 'sit', 'get', 'gass', ':)']
# ['friend', 'hi', 'saw', 'dead', 'thing', 'made', 'think', 'aww', 'thank', 'guy', ':d']
# ['speak', ':-)']
# ['alway', ':)']
# ['starsquad', '⭐', 'pleas', 'get', 'follow', 'awesom', ':)']
# ['awww', 'thank', ':-)']
# ['thank', 'news', 'man', ':)', 'utc']
# ['rememb', 'one', 'time', 'go', 'flume', 'kaytranada', 'alunageorg', 'even', 'though', 'ticket', 'still', 'want', 'km']
# ['oh', 'good', 'haha', 'let', 'know', 'think', ':)']
# ['thank', '4', 'give', 'certainti', 'problem', ':)', 'hope', 'u', 'could', 'solv', 'faster', '👊', 'least', 'know', 'dont', 'hurri', '4', 'totem']
# ['somewher', 'later', ':)']
# ['good', 'advic', 'friday', ':)']
# ['cheer', 'alic', ':)']
# ['go', 'pleas', 'click', 'link', 'checkout', ':)']
# ['two', 'dog', 'one', 'cat', 'good', 'friend', ':-)', 'goodwynsgoodi', 'freebiefriday']
# ['ugh', "i'v", 'never', 'rt', 'fade', 'moan', 'leed', 'tweet', ':)']
# ['look', 'forward', 'jozi', 'guy', ':)']
# ['hello', ':d', 'found', 'time', 'wasnt', 'follow', 'till']
# ['think', 'fifth', 'album', 'im', ':)', 'okay', ':)', 'fuck', ':)']
# ['may', 'avail', 'tix', 'pa', 'ba', 'ng', 'atl', 'concert', 'thank', ':)']
# ['yeah', '20', 'coldplay', 'song', 'playlist', ':p', 'love', 'favorit', 'scientist', 'fix', 'yellow', 'atla', ':p']
# ['awesom', ':)', "i'll", 'wait']
# ['follow', 'follow', 'u', 'back', ':)']
# ['done', 'yein', ':)']
# ['haha', 'receiv', 'ff', 'thing', 'friday', 'nice', 'way', 'start', 'day', ':)', 'xx']
# ['lol', 'selo', ':)']
# ['jabongatpumaurbanstamped', 'an', '7', 'time', 'arriv', ':)']
# ['waiter', 'bill', 'sir', 'custom', 'ok', 'kitchen', ':d']
# ['titl', 'say', ':d']
# ['hey', 'almost', 'time', 'visit', 'citi', ':)']
# ['keep', 'insid', 'pocket', 'ur', 'wrip', 'jean', ':)']
# ['beauti', ':)']
# ['well', 'haha', ':d']
# ['love', 'conni', 'fabul', 'ship', 'amaz', 'crew', 'staff', 'great', 'time', ':-)']
# ['hi', 'sweetan', 'best', 'ask', ':)', 'great', 'day', 'fun', 'film']
# ['nope', ':-)']
# ["that'", 'ok', 'thank', 'follow', ':)']
# ['mum', 'beg', 'watch', 'soprano', "i'll", 'watch', ':-)']
# ['follow', 'back', 'pleas', ':)']
# ['oh', 'fun', ':)']
# ["that'", 'great', 'hear', ':d']
# ['also', 'ff', 'ukrain', ':)']
# ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x33']
# ['follow', 'pleas', 'olli', ':)']
# ['beauti', ':)', 'via', 'disney.art', 'talent', 'elmoprinssi', ':)', 'forget', '…']
# ['bit', 'tire', '3', 'hour', 'salsa', 'danc', 'last', 'night', 'definit', 'worth', 'happi', 'friday', 'everyon', ':-)']
# ['thank', 'haha', 'tell', 'truth', ':)', ':)', ':)']
# ['ye', 'pl', ':)']
# ['gotten', 'least', '3', 'hour', 'sleep', 'past', '4-6', 'day', 'rest', 'week', 'interest', ':)', '3', ';)']
# ['thank']
# ['check', 'bro', '2nd', 'blogiversari', 'mani', 'awesom', 'review', 'come', ':d', '...']
# ['top', 'cuti', 'bohol', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['briliant', 'liter', 'convers', 'post', 'v', 'email', 'saw', ':)']
# ['key', 'word', 'annual', 'read', 'anyon', 'write', ':)']
# ['product', 'day', 'far', ':)', 'happi', 'day', '...', ':)', ':)', 'head', 'spin', 'thing', 'voic', 'keep', 'call', '..', 'lol', '\U000fe334']
# ['yeheyi', 'thank', 'much', 'pinya', ':)', 'whoooah', 'win']
# ['good', 'morn', 'dear', 'friend', '<3', 'listen', 'tranc', 'lover', 'enjoy', ':d', 'happi', 'friday', '<3']
# ['favorit', 'subject', 'school', '—', 'physic', ':)']
# ['congrat', ':)', 'good', 'news', 'head', 'weekend']
# ['take', 'head', 'stop', ':)']
# ['ब', 'matter', 'jungl', 'accommod', ':-)']
# ['hi', 'shout', 'list', 'one', 'best', "what'", 'secret', 'behind', ':)', 'sandroforceo', 'ceo', '1month']
# ['swag', ':d']
# ['wait', 'till', 'turn', 'go', 'mia', ':-)']
# ['thank', ':)']
# ['love', 'time', 'go', 'flow', 'workinprogress', 'love', 'choos', 'colour', ':)', '…']
# ['love', 'finnigan', ':)', 'loyal', 'royal']
# ['fotoset', 'reus', 'seem', 'like', 'somebodi', 'fun', 'today', ':d']
# ['love', ':-)']
# ['quit', ':)', 'sell', 'young', 'understand', 'muntu']
# ['anoth', 'gem', 'today', 'falco', 'cool', ':)', 'supersmash']
# ['good', 'morn', 'hotnsexi', 'girl', 'amaz', 'friskyfriday', 'beach', ':d']
# ['welcom', ':d']
# ['lol', 'tire', 'good', 'look', ':)']
# ['wrong', 'turn', '6', 'amaz', 'movi', ':)']
# ['glad', 'hear', "that'", 'back', 'see', 'anyth', 'els', 'crop', 'let', 'us', 'know', ':-)', 'ba']
# ['kill', ':)', ':)']
# ['pic', 'nash', 'come', ':)']
# ['make', 'sure', 'alway', 'tissu', 'chocol', 'tea', 'everi', 'hannib', 'episod', ':)', 'work', 'way', ':)']
# ['contact', 'us', 'today', "we'll", 'get', 'citi', 'hotb', 'bush', 'somewher', ':)', 'classicassur']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['glad', 'like', 'check', 'nice', 'stuff', 'wsalelov', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['thrill', 'first', 'intern', 'assign', 'aerial', 'camera', 'oper', '...', 'wale', 'come', 'boom', 'never', 'forget', 'smile']
# ['friday', 'night', 'hong', 'kong', '...', 'ferri', 'central', 'meet', 'new', 'girlfriend', 'after-work', 'drink', ':-)', '...']
# ['famili', 'time', ':d', 'dj', 'resto', '—']
# ['good', 'morn', ':)', '—', 'drinkt', 'koffi']
# ['a6', 'girl', 'wardrob', 'would', 'w', ':)', 'wsalelov']
# ['stargat', 'atlanti', 'cool', 'show', ':)']
# ['great', 'muaahhh', ':)']
# ['ohh', 'hii', ':)', 'haha', 'thank', 'info', "i'll", 'check', '🙈', 'mayb', 'di', 'nagsend', 'yung', 'order', 'form', 'ko', '</3', 'haha', 'thank', 'ulit', ':)']
# ['happi', 'birthday', ':)', '🎉', '🎈']
# ['trust', 'without', 'us', 'ugli', 'without', 'u', ':-)']
# ['legget', 'qui', 'per', 'la', 'chat', 'larri', ':)', 'mar']
# ['encourag', 'employ', 'board', 'stuck', 'poster', ':)']
# ['sticker', 'came', 'sponsor', 'prize', 'entri', 'tablet', ':)']
# ['goodnight', 'liam', 'hope', 'fantast', 'day', 'today', '(:', 'sweet', 'dream', 'babi', 'love', 'heart', ':d', 'xx']
# ['oh', 'yeah', 'milo', 'aurini', 'juicebro', 'fuck', 'pillar', 'respect', 'commun', ':d']
# ['yeah', 'boii', 'look', 'arriv', 'post', 'morn', 'latest', 'smashingbook', '5', 'new', 'bibl', ':d']
# ['ill', 'better', 'soon', ':)', '—', 'feel', 'sick']
# ['lamo', 'first', 'fangirl', 'hard', '..', "i'd", 'love', 'share', 'platon', 'pic', ':d', 'know', 'scienc']
# ['morn', '...', 'friday', 'happi', 'friday', 'beauti', 'peopl', ':)', 'smile']
# ['thank', "we'r", 'set', 'anoth', 'great', 'day', 'support', 'commun', 'help', 'resid', ':-)', 'servicewithasmil']
# ['sound', 'good', ':)', "i'll", 'see', 'saturday', '✨']
# ['live', 'night', 'two', 'fam', ':)', 'bloodlin', 'huski']
# ['welcom', ':)']
# ['pictur', "i'd", 'like', 'see', 'obituari', 'advert', ':)', 'goofingaround', 'mad', 'mad', 'bollywood', '…']
# ['love', 'giveaway', ':)', 'freebiefriday']
# ['dah', 'move', ':)']
# ["there'", 'noth', 'cool', 'total', 'someon', 'bitter', 'anger', 'hatr', 'toward', 'pure', 'indiffer', ':)']
# ['u', 'wake', '4', 'suit', 'life', 'zach', 'codi', ':)']
# ['oh', 'know', ':)', 'ye', 'order', 'deliv', 'work', 'address', 'ad', 'address', 'book', 'ac']
# ['achiev', 'excel', 'music', 'music', 'produc', 'mind', 'boggl', 'fatigu', 'job', '...', 'baareeq', '...', ':)', ':)', ':)']
# ['love', 'thank', 'share', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['gamedev', 'hobbi', ':)']
# ['ye', 'ye', 'ye', '...', ':)']
# ['thank', ':)', 'tweenie_fox', 'hi', 'pleas', 'click', 'list', 'hair', 'accessori', 'product']
# ['sometim', 'tamang', 'hinala', ':)']
# ["i'm", 'follow', ':)']
# ['hello', 'babe', 'got', 'niam', 'access', 'could', 'give', 'someth', 'ship', 'dm', ':)']
# ['selfiee', ':)']
# ['especi', 'three', 'lass', ':)', 'w', 'ale']
# ['hi', 'gorgeou', 'nice', 'swim', 'si', 'get', 'birthday', 'shout', 'pleas', 'would', 'make', 'day', 'perfect', ':)', 'xx']
# ['haha', 'hope', 'got', 'work', 'tho', '..', 'bout', 'quit', ':p']
# ['goodby', 'forget', 'feminist', 'fought', 'right', 'act', 'like', 'snobbi', 'littl', 'bitch', ':-)', 'goodnight']
# ['follow', 'follow', 'u', 'back', ':)']
# ['carolin', 'carolin', 'guy', 'say', 'mighti', 'fine', '🔥', 'threw', 'littl', 'make', ':-)', 'hbd', '❤', '️']
# ['follback', ':)']
# ['time', 'jog', ':p']
# ['place', 'hope', ':)', '’', 'pro', 'remot', 'work', 'travel', ';)']
# ['newli', 'list', 'ebay', 'store', ':-)', '...']
# ['new', 'disneyinfin', 'starwar', 'charact', 'look', 'amaz', 'preorder', 'starter', 'pack', 'store', 'today', ':d']
# ["i'm", 'want', 'talk', ':)']
# ['alway', 'tweet', 'hit', 'snap', '...', 'one', 'ever', 'worth', 'tri', ':)']
# ['homi', 'bought', 'skin', 'bday', ':d']
# ['chant', 'jai', 'itali', '100', 'time', 'fast', ':)']
# ['heeeyyy', 'follow', 'fan', 'account', 'thank', ':)']
# ['uk', ':)']
# ['thank', ':d']
# ['woah', 'nice', 'nice', ':-)']
# ['u', 'welcom', ':-)', '♥']
# ['good', ':)']
# ["here'", '★', '★', '★', 'review', 'phew', "we'r", 'liter', 'overwhelm', ':)']
# ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# ['babi', '😊', '😊', '😊', 'next', 'time', 'hous', 'whenev', ':)']
# ['got', 'thank', 'g', ':)']
# ['encourag', 'employ', 'board', 'stuck', 'poster', ':)']
# ['hug', 'ang', 'kiss', 'philippin', ':)']
# ["i'v", 'enter', 'win', 'huge', 'packag', ':)', 'enter', 'giveaway']
# ['ye', 'work', ':)']
# ['follow', 'follow', 'u', 'back', ':)']
# ['hi', 'great', 'connect', 'specialis', 'thermal', 'imag', 'survey', '–', 'need', 'us', ':)']
# ['yeah', 'bruis', 'rib', ':-)']
# ['flipkartfashionfriday', '😀', '😁', '😂', '😃', '😄', '😅', '😉', 'give', 'dear', 'worri', ':)']
# ['tombraid', 'hype', 'thought', 'might', 'like', ':d']
# ['oh', 'oh', 'oh', 'thejuiceinthemix', 'rela', 'build', ':)']
# ['low', 'prioriti', 'match', ':)', 'hahaha']
# ['fback', ':)']
# ['want', 'harri', 'dm', 'bc', 'wanna', 'give', 'surpris', 'friend', 'birthday', 'wanna', 'make', 'happi', ':)']
# ['opportun', 'time', '2', 'collaps', 'chaotic', 'cosa', '<---', 'note', 'alliter', ':-)']
# ['go', 'well', 'oppayaa', "how'", ':d']
# ['best', 'want', 'bodi', ':)']
# ['natgeo', 'new', 'show', 'u', "can't", 'lick', 'ur', 'elbow', '. .', 'seem', 'interest', '...', ':)']
# ['stat', 'day', 'arriv', '7', 'new', 'follow', 'unfollow', ':)', 'via']
# ['“', 'emu', 'stoke', 'thank', ':)']
# ['woke', 'yo', 'fav', 'tweet', 'made', 'day', ':)', '😂', '😂']
# ['rememb', 'need', "people'", 'approv', "god'", 'approv', ':-)']
# ['jisung', 'kid', 'sunshin', ':)']
# ['mm', 'okay', 'thank', ':)']
# ['messag', 'us', 'right', 'nicola', 'forward', ':)', 'brighten', 'day', ':d', 'helen']
# ['follow', 'follow', 'u', 'back', ':)']
# ['congrat', ':)']
# ['hi', 'brian', "i'll", 'get', 'ship', 'today', 'take', '2-3', 'week', 'australia', 'mani', 'thank', ':)']
# ['good', 'fun', 'time', 'ol', 'bone', 'creak', ':)']
# ['eh', 'abuti', 'welcom', 'tweetland', '...', 'lol', ':p']
# ['thx', 'android', 'support', 'xma', ':)']
# ['great', 'skyblock', 'stream', ':)']
# ['im', 'stand', 'alway', 'belieb', ':)', 'bcaus', '2009', 'die', ':)']
# ['stream', 'twitch', 'join', ':d']
# ['..', 'sympathi', 'laugh', ':)']
# ['would', 'like', ':)', 'xo']
# ['awesom', ':d']
# ['unniee', ':)']
# ['tonight', 'night', '...', ':)', 'nuka', 'penacova', 'djset', 'free', 'edm', 'kizomba', 'latinhous', 'housemus', 'portug', '2015', 'summer']
# ['well', 'wild', 'ride', '>:d']
# ['hahaha', 'tell', 'anytim', 'wanna', 'tast', 'oh', 'yer', 'address', 'send', ':)']
# ['thank', 'team', 'yellow', ':)', 'mtn', '8']
# ['maganda', 'look', 'pretti', 'short', 'hair', 'cute', ':d']
# ['good', 'morn', 'gorgeou', 'mistress', 'saphir', ':)']
# ["i'm", 'work', "i'm", 'busi', 'help', 'finish', 'im', 'home', ':)']
# ['thank', 'amaz', '4000', 'follow', 'instagram', '´', 'among', 'yet', 'feel', 'free', 'connect', ':-)', '...']
# ...
# ['niaaa', 'pl', 'follow', '2/4', 'miss', ':(']
# ["i'v", 'move', 'australia', 'matter', 'time', ':(']
# ['cute', ':(', '💞']
# ['scheme', 'scheme', 'plan', 'yet', ':(']
# ['second', 'wednesday', 'alreadi', ':(']
# ['paper', 'town', 'pleas', ':-(']
# [':(', ':(', 'know', 'goe', 'still', '...']
# ['dude', "i'm", 'fckin', 'okay', 'avoid', ':(']
# ['fuck', ':(']
# ['hii', 'vin', 'plss', 'rpli', 'tweet', ':(']
# ['mean', 'put', 'rat', 'lol', ':(']
# ['delet', 'entir', 'bollywood', 'movi', 'collect', 'make', 'space', 'mac', 'backup', 'actual', 'tear', ':(']
# ['say', 'exam', 'exam', 'na', 'sa', 'lune', 'mart', ':(']
# ['“', 'love', 'spot', 'robinhood', 'wild', 'thank', 'support', 'robinhoodi', '🚙', '💚']
# [':(']
# ['docopenhagen', 'hors', 'ass', ':(']
# ["i'll", 'write', 'bunch', 'ugli', 'setter', 'function', '...', ':(']
# ['im', 'swipe', 'right', 'dont', 'see', 'anyth', ':(']
# ['gonna', 'live', 'without', 'bbygurl', 'two', 'whole', 'day', ':(']
# ['fuck', 'u', 'neil', 'u', 'ruin', '>:-(']
# ['yeah', "i'm", ':(']
# ['2', 'year', 'ago', 'today', 'pack', 'caribbean', ':(']
# ['hack', 'gone', 'size', ':(', '6yr', 'ago', 'gone', 'size', '12', 'size', '18', ':(', 'hate', ':(']
# [":'(", 'tri', 'hard', 'lost', ':(', 'jabongatpumaurbanstamped']
# ['bro', 'choos', 'takraw', ':(']
# [':(', 'like', 'fersure', 'thing', 'yet', 'though']
# ['“', 'oh', 'poor', 'babi', ':(', '😁', '😭']
# ['hell', 'naw', 'angi', "ain't", 'nobodi', 'pay', 'fuck', 'though', ':(']
# ['awww', 'thank', ':(', 'im', 'still', 'ugli', 'huhu', 'idk']
# ['ice', 'cream', 'sandwich', 'plsss', ':-(']
# ['sheriff', 'seen', 'aaa', 'aaag', ':(']
# ['alway', 'hard', 'leav', 'heart', ':(', "i'mo", 'sulk', 'day', 'today']
# ['peopl', 'like', 'fra', '...', 'kinda', 'selfish', ':(']
# ["that'", 'fair', 'wanna', 'meet', 'sooo', 'bad', '<3', '<3', ':(']
# ['follow', 'trick', 'nonc', ':(']
# ["can't", 'charg', 'pad', 'toffe', 'though', 'tri', 'switch', 'someon', 'bison', 'never', 'got', 'back', ':(']
# ['need', 'get', 'motiv', 'mean', 'walk', 'way', "q'don", 'think', 'energi', ':(']
# ['oh', 'crikey', 'good', ':(', 'look', 'sore', 'hope', 'start', 'feel', 'better', 'sinc', 'though', 'x']
# ['heart', 'rate', 'ridicul', 'today', ':(']
# ["i'm", 'proud', 'heart', 'play', 'stab', 'cheat', 'burn', 'broken', 'somehow', 'still', 'work', ':(', 'unknown']
# ["can't", 'go', 'ed', ':(', ':(']
# ["there'", 'total', 'stomp', ':(']
# ['aaaaaaaaah', 'sound', 'kany', 'make', 'hey', 'mama', 'cute', ':(']
# ['feel', 'ill', 'today', ':(']
# ['jdjdjdjd', 'detail', 'stop', ':(']
# ['want', 'add', ':(']
# ['said', 'never', 'gonna', 'eat', 'banana', 'anymor', 'dont', 'choic', ':(']
# ['asleep', '3', '4', 'hour', 'ago', ':(']
# ["jimin'", 'fancaf', 'post', 'yesterday', '>:(', 'gone']
# [':(', 'free', 'time', 'monday']
# ['nooo', 'friday', 'work', 'weekend', ':(']
# ['want', 'flip', 'belgium', 'waffl', 'thrown', 'face', ':(']
# ['one', ':(', 'perhap', 'someth', 'els', '87.7', '2fm']
# ['kik', 'himseek', '8', 'kik', 'kiksex', 'kikmsn', 'like', '4like', 'kissm', 'akua', 'hotel', ':(']
# ['home', 'gg', ':(']
# ['glo', 'yet', ':(']
# ['want', 'home', "i'm", 'eat', 'properli', "i'm", 'sleep', 'pass', 'time', "i'm", 'miser', ':(']
# ['miss', ':(', 'pl', 'follow']
# ['get', 'sad', 'cori', 'monteith', 'like', 'often', ':(', 'sure', 'lot', 'peopl', 'gone', 'soon', 'hit', 'close', 'home', 'could']
# ['aw', 'know', "i'm", 'sorri', ':(', 'hashbrown', '😂', '😊', '💘', '💘']
# ['ahh', 'wonder', "they'r", 'realli', 'support', 'pg', 'shame', 'msc', 'like', ':(']
# ['hierro', ':(']
# ['snapchat', 'shirleycam', 'snapchat', 'hornykik', 'dmme', 'kikchat', 'selfi', 'amazon', 'phonesex', ':(']
# ['look', 'good', 'pal', 'glad', 'paid', '£', '111', 'jersey', 'gilet']
# ['look', 'cheek', 'squishi', ':(', 'cutest', ';(']
# ['oh', 'realli', 'wonder', 'expens', ':(', 'u', 'donat']
# ['stay', 'lahhh', ':(']
# ['debut', "i'm", 'still', 'student', ':(', 'enough', 'money', 'pay', 'eon']
# ['even', 'notic', ':(']
# ['im', ':(']
# ['sorri', 'hear', 'dog', ':(']
# ['sunris', 'pretti', 'get', 'good', 'pictur', ':(']
# ['kik', 'guy', 'beeti', '697', 'kik', 'kikmeguy', 'kikm', 'makeup', 'sex', 'video', 'kikkomansabor', ':(']
# ['getaway', 'car', 'commit', 'crimin', 'act', ':(', '☼']
# ['mad', 'sure', 'three', 'amiibo', 'price', 'four', 'nintendo', 'store', 'backup', '…', ':(']
# ['batman', "can't", 'fli', "can't", 'help', ':(', 'habe', 'fail', 'ate']
# ['make', 'wish', 'travel', ':-(']
# ['siannn', '7', 'march', '2017', ':(']
# ['free', 'twitter', ':(']
# ['may', 'list', 'ba', ':(']
# ['well', 'absolut', 'chuckin', 'ampsha', ':(', 'rain', 'rain', 'rain']
# ['answer', 'fan', 'sleep', ':(']
# ['nia', 'want', 'meet', ':(']
# ['ahh', 'hope', ':(']
# ['terribl', 'terribl', ':(']
# [':(']
# ['miss', 'senior', 'much', ':(']
# ['pleas', 'help', 'find', 'replac', 'strap', 'dz9055', ':(', 'love', 'watch']
# ['kik', 'entlead', '590', 'kik', 'kikmenow', 'nude', 'hornykik', 'tinder', 'quot', 'webcamsex', ':(']
# ['tuesday', 'daw', ':(']
# ['today', 'meant', 'quiet', 'day', 'clean', 'shop', "i'm", 'super', 'busi', 'client', ':(']
# ['yep', 'twice', ':(']
# ['justinbieb', 'u', 'pl', 'follow', 'daianerufato', "i'v", 'tri', 'long', ':(', 'ilysm', 'bae', 'xx', 'juli', '24', '2015', '07:02']
# ['ice', 'cream', 'ifsc', 'mayor', 'street', ':(']
# ['biodivers', 'taxonom', 'infrastructur', 'intern', 'collabor', 'new', 'speci', 'discoveri', 'suppl', 'data', 'pdf', ':(']
# ['want', 'fuck', 'day', 'collar', ':(']
# ['jealou', 'much', ':(']
# ['follow', 'back', ':(']
# ['yep', '3:03', "can't", 'sleep', ':(']
# ['ummm', 'found', ':(']
# [':(', 'okay', 'worst']
# ['god', ':(', ':(', ':(']
# ['hardli', 'respond', ':-(']
# ['go', 'miss', 'belt', 'sam', 'smith', 'daili', 'car', 'ride', ':(']
# ['hope', ':(', 'zayniscomingbackonjuli', '26']
# ['realli', 'want', ':(']
# ['wish', 'good', 'makeup', 'thing', 'im', 'good', 'eyelin', ':(']
# ['end', 'would', 'leav', 'work', 'therefor', 'miss', ':(']
# ['thought', 'best', 'day', 'paper', 'town', 'today', ':(']
# ['pleas', 'come', 'netherland', ':(']
# ['actual', 'made', 'cri', 'disgust', 'actual', 'fuck', 'im', 'disgust', "i'v", 'seen', 'poor', 'peopl', ':(']
# ['lol', 'forgot', 'mubank', 'today', ':(']
# ['max', 'el', 'togeth', ':(']
# ['jeb', 'bush', 'call', 'blacklivesmatt', 'slogan', 'via', 'msnbc', 'cnn', 'jebbush', 'thank', 'lucki', 'star', '...', ':-(']
# ['true', '...', ':-(']
# ['famish', ':(']
# ['damn', 'd:', 'feel', 'way', 'mayb', ':(', 'like', 'happi', 'san', 'marino', 'qualifi', 'want', 'suzi', 'qualifi', 'd:']
# ["i'm", 'get', ':(', "we'r", 'least', 'speak']
# ['rip', 'momo', ':(']
# ['rip', 'skirt', 'hurt', 'back', 'im', 'injur', 'lol', ':(']
# ['miss', 'brace', ':(']
# ['sorri', ':(']
# ['final', 'could', 'stream', 'ugh', 'make', 'home', 'past', 'day', 'broadcast', ':(']
# ['whenev', 'hear', 'tama', "can't", 'help', 'repeat', 'head', 'pabeb', 'warrior', 'say', ':(']
# ['even', 'awak', ':(']
# ['nearli', '50', 'dead', '100', 'wound', 'report', 'bomb', 'attack', 'iraq', 'one', 'week', '300', 'human', 'be', 'kill', ':(']
# ["everyone'", 'holiday', ':(']
# ['far', 'would', 'go', 'win', 'camara', 'know', ':-(', 'bride', 'wore', 'coveral', 'romanc', 'inspi']
# ['around', 'tom', ':(']
# ['mr', 'happili', 'mr', 'sneezi', 'mr', 'sleepi', ':-(']
# ['said', 'got', 'much', 'time', 'hand', ':(', 'rogerwatch']
# ['asham', 'languag', ':(']
# ['stalker', ':(']
# ['red', 'velvet', 'cake', 'plsss', ':(']
# ['everybodi', 'fell', 'asleep', ':(']
# ['yeah', "i'v", 'heard', ':(', 'think', 'learn', 'littl', 'tradit', "people'", 'beheaviour', 'visit', 'countri', '...']
# ['parent', 'let', '>:(']
# ['sigh', 'yeah', ':(']
# ['miss', "robert'", 'cute', 'ass', ':-(']
# ['true', 'life', 'cant', 'hide', 'anyth', '...', ':(', '.\n.', 'love', '...', '❤', '.\n.', '...', '...']
# ['fuck', 'hate', 'wake', 'like', 'time', "can't", 'fall', 'back', 'asleep', 'ugh', ':(']
# ['aaron', 'said', 'shit', 'ago', 'said', 'worth', 'take', "that'", 'bang', 'well', 'jelous', ':(']
# ['truli', 'better', 'feel', 'mtg', 'get', 'thoughtseiz', 'twice', 'first', '2', 'round', 'game', '1', 'take', 'playabl', 'away', ':(']
# ['oldi', 'goodi', ':(']
# ['miss', 'mcg', 'rn', ':(']
# ['woohyun', 'seem', 'weird', 'inspirit', 'shine', 'night', '...', ':(', 'im', 'ise', 'see', 'like', '...', 'happen', ':/']
# ['forev', 'food', 'home', 'food', 'school', 'even', 'nice', ':-(']
# ['let', 'assum', 'high', 'waist', "harry'", 'jean', ':(', ':(']
# ['know', ':(']
# ['chanc', 'find', 'black', 'guin', 'wallet', 'venu', 'last', 'night', 'show', 'lost', 'wallet', ':(', ':(', ':(', 'thank']
# ['evil', 'pepper', 'system', ':(']
# ['kik', 'thessidew', '877', 'kik', 'kikmeguy', 'facetim', 'omegl', 'bore', 'quot', 'sexi', ':(']
# ["there'", 'meet', 'sunday', 'genesi', 'back', 'mexico', 'yet', ':(']
# ['upset', "i'm", 'go', 'novemb', 'man', 'hope', "there'", 'go', 'next', 'time', 'uk', ':(']
# ['crave', 'wing', ':(']
# ['mash', 'phone', 'lost', 'number', '..', ':(', 'whattsap', 'avail']
# ['yeah', ':(', 'idk', 'never', 'found', 'time', 'finish', 'inuyasha', "i'v", 'seen', 'lot', 'anim', 'grew', 'watch', 'inuyasha']
# ['hey', 'girl', 'must', 'googl', 'plu', "can't", 'convinc', 'fr', 'end', 'hang', 'outfwith', ':(']
# ['want', 'myungsoo', 'gyu', 'hoya', 'yeol', ':(']
# ['victoria', 'park', 'book', 'close', ':(']
# ['hard', 'find', 'organis', "we'r", 'satisfi', ':(']
# ['god', 'im', 'sorri', 'hope', 'better', ':-(', 'wah']
# ['stock', 'sa', '1', 'hour', ':(']
# ['lay', 'challo', 'pliss', ':(']
# ['hell', ':(']
# ['omg', "i'd", 'facetim', 'juliana', 'rn', 'phone', ':-(']
# ['still', 'confus', 'enrol', 'sem', ':(']
# ["i'm", 'work', 'next', 'weekend', ':(']
# [':(', 'even', 'u', 'hit', '5']
# ['fell', 'asleep', ':(', 'guy', 'wanna', 'come', 'starbuck', 'w', 'lol']
# ['darlen', 'followback', 'pleas', ':(']
# ['gay', 'togeth', 'least', 'leav', 'alon', ':(']
# ['emoji', ':(']
# ['freak', 'cat', 'cuddl', ':-(']
# ['see', 'meet', 'greet', 'tour', 'come', 'unfortun', 'come', 'brisban', ':(']
# ['late', ':(']
# ['hi', 'merlin', 'current', 'wait', 'roof', 'repair', 'kitchen', 'let', 'water', ':(']
# ['saw', 'mention', 'omg', 'sorri', ':-(']
# ["i'm", 'sorri', 'sweeti', ':(', 'one', 'deserv']
# ['nawwwe', 'miss', 'hyperbulli', 'like', 'tong', '3rd', 'yr', 'nga', 'seatmat', 'rajud', 'mi', 'mag', 'barkada', ':(']
# ["i'll", 'miss', 'buddi', ':(']
# ['ore', ':(']
# ['sick', ':(']
# ['look', 'promis', 'even', 'cricket', ':(']
# ['sleep', 'good', "i'm", 'kayla', ':(']
# ['miss', 'everyon', 'much', 'feel', 'like', "i'v", 'seen', 'long', ':(']
# ['yet', 'finish', "i'm", 'still', 'season', '7', ':(']
# ['look', 'fun', 'snapchat', 'ericavan', '18', 'snapchat', 'snapchatm', 'likeforlik', 'interraci', 'model', 'repost', 'sexo', ':(']
# ['feel', 'well', ':(']
# ['...', ':(', 'hate', 'jong', 'dongwoo', 'photocard', "i'v", 'get', 'wh', 'dw', 'sj']
# ['may', 'brain', 'tumor', 'si', 'vivian', ':(', 'mmsmalubhangsakit']
# ['everyon', 'talk', 'rat', 'boy', 'today', 'bc', ':(']
# ['feet', 'hurt', ':(']
# ['oh', 'man', 'schade', ':(']
# ['ohh', ':(', 'first', 'year', 'bit', 'tire', 'thing', 'get', 'better']
# ['zayn', 'come', 'back', '1d', 'alreadi', ':(']
# ["i'm", 'freez', ':(']
# ['want', 'shoe', 'holiday', 'ship', 'take', '4-5', 'day', 'arriv', 'today', 'even', 'way', ':(']
# ['u', 'follow', ':(']
# ['see', 'must', '...', 'tri', 'think', 'day', 'could', '...', "i'v", 'think', 'figur', ':(']
# ['snapchat', 'jillcruz', '18', 'snapchat', 'kiksext', 'likeforlik', 'hornykik', 'lgbt', 'music', 'camsex', ':(']
# ['feel', 'like', "i'm", 'person', 'ireland', 'go', 'see', 'croke', 'park', ':(']
# ['sore', 'qt', ':(']
# ['til', '19th', 'sept', 'co', "that'", 'bill', 'start', 'full', 'rent', ':(']
# ['ok', 'whole', 'time', "i'v", 'toss', 'turn', 'bed', 'tri', 'go', 'sleep', "can't", ':(']
# ['show', 'open', 'shop', 'co-work', 'mia', ':(', 'hope', 'arriv', 'soon', "i'm", 'starv']
# ['yup', 'alway', 'order', 'anyway', '😂', 'hope', 'push', ':(']
# ['dare', ':(']
# ['unsettl', 'weather', 'trend', 'next', 'day', 'sun', 'morn', 'shower', 'afternoon', 'gh', '18c', 'mix', 'bag', 'weekend', ':-(']
# ['get', 'sick', ':(']
# ['two', 'day', 'birthday', ':(']
# ['im', 'listen', 'everyth', ':(']
# ['shit', 'rlli', ':(', 'heard', 'hamster', 'eat', 'that', 'pretti', 'fuck', 'hamster', 'r', 'weird']
# ['wanna', 'see', 'ed', 'sheeran', 'preform', 'tonight', ':(']
# ['peanut', 'probabl', 'crash', ':(', '..', 'seen', 'drive', 'monash', '...']
# ['p', '...', ':(']
# ['cant', 'find', 'gift', 'end', 'use', 'money', 'starbuck', ':(']
# ['hope', 'hitmark', 'glitch', 'fix', 'soon', ':(']
# ['okay', 'safaa', 'pleas', 'follow', ':(', 'love']
# ['guess', "who'", 'miss', "selena'", 'tweet', 'fan', ':(']
# ['summer', 'sleep', 'schedul', 'back', ':(']
# ['eye', 'want', 'sleep', 'rest', ':(', 'bad']
# [':(', 'u', 'okay']
# ['ye', 'galat', 'hai', 'tum', 'ne', 'mjhe', 'ab', 'non', 'respect', 'lrka', 'bna', 'dia', 'itna', 'rude', 'word', 'use', 'kia', 'hai', 'ke', 'ab', 'mere', 'bhook', 'hi', 'khatam', 'ho', 'jai', 'hai', ':(']
# ['anyon', 'give', 'money', 'train', 'see', 'today', ':(']
# ['gym', 'week', 'need', 'big', 'person', 'push', 'today', 'get', 'tonight', '...', "i'v", 'make', 'excus', 'lazi', ':-(']
# ['annoy', ':(']
# ["ain't", 'gonna', 'follow', ':(']
# ['social', 'experi', 'made', 'cri', ':(']
# ['miss', ':-(']
# ['afterschool', 'cant', 'comeback', 'even', 'tho', 'want', 'coz', 'money', ':(']
# ['pleas', 'pray', 'friend', 'bilal', 'ashraf', 'icu', ':(']
# ['thanksss', ':(']
# ['miss', 'mani', 'peopl', ':-(']
# ['long', 'us', ':(']
# ['ah', 'im', 'sorri', ':-(']
# ['annnd', 'go', 'winchest', '{:']
# ['1', 'year', 'sinc', 'text', '...', 'miss', 'everyth', 'know', 'never', ':(']
# ['aw', 'use', 'photo', ':(']
# ['exactli', ':(']
# ['alway', 'make', 'much', 'effort', 'talk', 'get', 'like', 'one', 'two', 'tweet', 'dm', 'day', '...', 'like', 'realli', 'come', ':(']
# ["that'", 'aw', ':(']
# ['grepe', 'grepein', ':(']
# ['want', 'panem', 'end', ':(', 'love', 'book', 'movi']
# ['idk', 'wanna', 'watch', 'episod', ':(']
# ['lover', ':(', 'go', 'zoo']
# ['babi', 'boyfriend', 'bitch', 'know', 'complet', ':(']
# ['ice', 'cream', 'van', 'busi', ':(', 'mayb', 'later', '...', 'ubericecream']
# ['hope', ':(', 'sulli', 'like', '...', 'well', 'injur', 'amber', 'still', 'haha', 'sigh', 'f', 'x']
# ['ouch', ':(', "what'", 'happen', 'make', 'say', 'darren', 'anyth', 'help']
# ['even', 'sleepi', ':(']
# ['cpm', 'condemn', 'rest', 'polit', 'parti', 'quiet', ':(']
# ['realis', '2/3', 'big', 'summer', 'plan', 'gone', ':(', ':(', ':(', 'next', 'pari', '✔', '️']
# ['oop', '...', 'server', 'error', 'occur', 'email', 'sent', ':(', ':(']
# ['miss', ':(']
# ['...', 'mental', ':(']
# ['nooo', ':(', 'late', 'nvm', 'lah']
# ['everyth', 'remind', 'u', ':-(']
# ['date', 'yet', ':(']
# ['feel', 'like', 'eat', 'unagi', 'sudden', ':(']
# ['straight', '7elw', ':(', 'least', 'mesh', 'beyt', '3a2ad']
# ['late', ':(']
# ['lol', "i'm", 'still', 'fluent', 'peopl', 'say', 'sound', 'white', ':(', 'varsiti', 'ruin', 'sengenza', 'typo', 'use', 'word', 'context']
# ['movnat', 'belgium', 'first', 'search', 'yield', 'noth', '...', ':-(', 'nbhero']
# ['tri', 'xbox', 'seem', 'work', '...', ':(', "it'd", 'make', 'killer', 'background']
# ['look', 'fun', 'kik', 'agov', '73', 'kik', 'kikgirl', 'hornykik', 'makeup', 'orgasm', 'brasileirao', 'sexdat', ':(']
# ['watch', 'abus', 'relationship', 'video', 'fuck', 'hard', "i'm", 'tri', 'cri', 'like', '...', ':(']
# ['also', 'good', '..', 'u', 'present', 'seen', 'u', 'long', 'time', ':(']
# ['like', 'u', 'sm', ':-(']
# ["i'm", 'inact', 'wanna', 'cri', ':(']
# ['look', 'fun', 'snapchat', 'jillcruz', '18', 'snapchat', 'kikhorni', 'talk', 'teen', 'oralsex', 'batalladelosgallo', 'kikhorni', ':(']
# ['srsli', 'fuck', 'u', 'unfollow', 'hope', 'ur', 'futur', 'child', 'unpar', 'u', '>:-(']
# ['ah', 'honestli', 'love', 'dad', 'much', "i'm", 'slightli', 'upset', "i'm", 'see', 'birthday', ':(']
# ['bianca', 'ur', 'one', 'bun']
# ['alreadi', 'knew', 'stand', 'let', 'peopl', 'dislik', ':(', 'burdensom', 'want', 'total', 'clear', 'soon', 'possibl']
# ['omg', 'miss', 'badli', ':(']
# ['amelia', 'didnt', 'stalk', 'twitter', ':(']
# ['oh', 'miss', 'broadcast']
# ['realli', "can't", 'stream', 'melon', 'feel', 'useless', ':-(']
# ['need', 'stop', 'look', 'old', 'soccer', 'pictur', ':(']
# ['got', 'interview', 'job', 'want', 'rang', 'tuesday', 'interview', 'thursday', 'holiday', ':(']
# The cost after training is 0.22521264.
# The resulting vector of weights is [6e-08, 0.0005382, -0.0005583]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.22522315.
# The resulting vector of weights is [6e-08, 0.00053818, -0.0005583]
# ```

# %% [markdown]
# <a name='4'></a>
# ## 4 -  Test your Logistic Regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
# <a name='ex-4'></a>
# ### Exercise 4 - predict_tweet
# Implement `predict_tweet`.
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 GRADED FUNCTION: predict_tweet
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet,freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(x.dot(theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# ['happi']
# I am happy -> 0.519275
# ['bad']
# I am bad -> 0.494347
# ['movi', 'great']
# this movie should have been great. -> 0.515980
# ['great']
# great -> 0.516065
# ['great', 'great']
# great great -> 0.532097
# ['great', 'great', 'great']
# great great great -> 0.548063
# ['great', 'great', 'great', 'great']
# great great great great -> 0.563930

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.519275
# I am bad -> 0.494347
# this movie should have been great. -> 0.515979
# great -> 0.516065
# great great -> 0.532096
# great great great -> 0.548062
# great great great great -> 0.563929
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# ['learn', ':)']
# array([[0.83110764]])

# %%
# Test your function
w1_unittest.test_predict_tweet(predict_tweet, freqs, theta)
# Out:
# ['happi']
# ['bad']
# ['movi', 'great']
# ['good', 'day']
# ['bad', 'bad', 'day']
# ['good', 'day']
# ['bad', 'bad', 'day']
# ['movi', 'great']
#  All tests passed

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 -  Check the Performance using the Test Set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# <a name='ex-5'></a>
# ### Exercise 5 - test_logistic_regression
# Implement `test_logistic_regression`.
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your 'predict_tweet' function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification 'y_hat' to 1, otherwise set the model's classification 'y_hat' to 0.
# * A prediction is accurate when the y_hat equals the test_y.  Sum up all the instances when they are equal and divide by m.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use numpy.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 GRADED FUNCTION: test_logistic_regression
def test_logistic_regression(test_x, test_y, freqs, theta, predict_tweet=predict_tweet):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE ###
    
    # the list for storing predictions
    y_hat = []
    m = test_y.shape[0]
    print(m)
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet,freqs,theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the listgo
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = np.sum(np.array(y_hat)==np.reshape(test_y,(m,)))/m
    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# 2000
# ['bro', 'u', 'wan', 'cut', 'hair', 'anot', 'ur', 'hair', 'long', 'liao', 'bo', 'sinc', 'ord', 'liao', 'take', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', ':)', 'bro', 'lol', 'sibei', 'xialan']
# ['back', 'thnx', 'god', "i'm", 'happi', ':)']
# ['thought', 'ear', 'malfunct', 'thank', 'good', 'clear', 'one', 'apolog', ':-)']
# ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', '...', ':)']
# ['happi', 'friday', ':-)']
# ['follow', ':)', 'x']
# ['teenchoic', 'choiceinternationalartist', 'superjunior', 'fight', 'oppa', ':d']
# ['birthday', 'today', 'birthday', 'wish', 'hope', "there'", 'good', 'news', 'ben', 'soon', ':-)']
# ['good', 'morn', ':-)', 'friday', '\U000fec00', 'plan', 'day', 'current', 'play', 'shop', '...']
# ['happi', 'friday', ':)']
# ['3', 'good', 'nigth', ':)', 'estoy', 'escuchando', 'enemi', 'god']
# ['actual', 'bye', 'bye', 'inde', 'go', 'take', 'drama', 'elsewher', ':)']
# ['ff', 'readi', 'weekend', ':)', 'smile']
# ['work', ':)']
# [':)', 'mood', 'bipolar']
# ['thank', ':)']
# ['hahahahahahahahahahahahahaha', 'die', ':)', 'liter', 'front', 'like']
# ['yoohoo', 'shatter', 'record', 'bajrangibhaijaanstorm', 'superhappi', ':d']
# ["who'", 'awak', ':-)']
# ['happi', 'friday', ':-)']
# ['pleasur', 'doll', 'thank', 'wonder', 'energi', 'class', ':)']
# ['f', ':)']
# ['delight', "m'dear", ':)']
# ['hi', 'emma', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# ['followback', 'beauti', 'girl', 'today', ':)']
# ['lyka', 'followback', ':)']
# ['alrd', 'joy', ':)']
# ['ourdaughtersourprid', 'dhan', 'dhan', 'satguru', 'tera', 'hi', 'aasra', '...', 'mani', 'congratul', 'pita', 'g', '...', 'keep', 'bless', 'alway', ':-)']
# ['thank', 'ye', "let'", 'hope', 'work', 'miss', ':-)']
# ['keeo', 'guess', 'what', 'behind', 'white', 'cover', ':)', 'special', '..', 'happi', 'bday', 'darl', '…']
# ['happi', 'friday', 'everyon', ':)', 'big', 'followfriday']
# ['awkward', 'moment', 'name', 'akarshan', 'end', 'stay', 'singl', ':d', 'foreveralon']
# ['know', ':)', 'hot', 'alway']
# ['worri', ':)', 'know', 'much', 'stress', 'problem', 'site', "can't", 'wait', 'till', 'event']
# ['say', 'sweetpea', 'start', 'hold', 'regular', 'gluten', 'free', 'cake', 'pastri', 'workshop', ':)']
# ['highfiv', 'probabl', 'ahead', 'sinc', 'less', 'artsi', 'verbal', ':d']
# ['bae', ':)', '<3']
# ['kid', 'kaaa', ':p']
# ['love', 'chat', 'cycl', 'oxford', 'campaign', 'way', 'home', 'yesterday', 'cycl', 'rout', 'pleas', ':)', 'cycl', 'oxford']
# ['wahoo', 'team', ':-)', 'masaantoday']
# ['anchor', 'sea', '..', ':)']
# ['dat', 'rp', 'tho', 'thank', 'much', 'guy', 'celebr', 'one', 'month', 'partnership', 'ty', 'raid', ':d']
# ['visit', 'robbenisland', 'cultur', 'experi', 'tri', 'whale', 'watch', 'aquat', 'safari', 'either', 'great', ':)']
# ['least', 'friday', ':d']
# ['mayb', 'garru', 'liara', 'rest', 'crew', ':d']
# ['thank', 'follow', 'great', 'day', ':)']
# ['massag', 'appoint', 'avail', 'tomorrow', 'morn', 'burnley', 'give', 'us', 'call', 'book', ':)', '01282', '453', '110']
# ['great', 'hear', 'nice', 'day', 'thank', 'visit', ':)']
# ['bore', 'everyth', ':d']
# ['drama', 'korea', '49', 'day', ':)']
# ['btw', 'anyon', 'repres', 'footbal', 'manag', 'commun', 'youtub', ':)', 'fm15', 'fmfamili', 'vidcon', '2015']
# ['mean', 'aamir', 'khan', 'one', ':)']
# ['happi', 'friday', ':)']
# ['right', 'back', 'excel', 'job', 'difficult', 'medium', ':)']
# [':)', 'want', 'ff']
# ['tweet', ':p']
# ['hey', 'come', 'see', 'us', 'summer', 'fine', 'food', 'fair', 'sunday', '11am', '4pm', 'ride', 'school', ':)']
# ['pleas', 'follow', 'liam', ':)']
# ['love', 'write', ':)', 'absolut', 'ador', 'nva', 'lucki', 'enough', 'live', '5', 'minuet', 'away', 'roll', 'gamec']
# ['ff', 'thank', 'brian', ':)']
# ['headrest', 'loos', "that'", 'reason', 'pit', ':-)']
# ['hi', "i'v", 'spoken', 'store', 'advis', 'paypoint', 'card', 'top', ':)', 'thank', 'beth']
# ['thank', 'help', ':-)']
# ['deepthroat', 'good', 'movi', ':)']
# ['hallo', 'twitter', ':d']
# ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# ['thank', 'wish', ':)']
# ['aitor', 'sn', 'would', 'mind', 'check', 'bio', 'particip', 'ps4', 'giveaway', 'could', 'winner', ':)']
# ['hi', 'jawad', 'today', 'thank', 'follow', 'retweet', 'much', 'appreci', ':)']
# ['thank', ':)']
# ['actual', 'need', 'stop', 'tweet', 'drive', ':-)']
# ['kind', 'feedback', 'truli', 'made', 'day', 'perfect', 'way', 'end', 'work', 'week', ':)']
# ['well', "that'", 'presal', 'ticket', 'bought', 'thank', 'wonder', 'take', 'book', '...', 'thing', 'parent', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['hope', 'goe', 'well', ':-)']
# ['betcha', ':)', 'dumb', 'butt', ':)']
# ['kik', 'qualki', '808', 'kik', 'kikmenow', 'milf', 'like', '4like', 'bore', 'summer', 'sexysaturday', ':)']
# ['follow', ':-)']
# ['thank', ':)']
# ['ye', 'hun', "i'm", 'good', ':)']
# ['enjoy', ':)']
# ['wow', 'vw', 'bu', 'lot', 'umpfff', 'love', ':)']
# ['ca', 'retweet', 'domg', 'nanti', 'difollow', ':d']
# ['wish', ':d', ':d', ':d', ':d', ':d', ':d', ':d', 'kid']
# ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# ['ye', 'car', ':)']
# ['like', 'especi', 'klee', 'one', ':-)']
# ['look', 'amaz', 'april', 'love', 'glass', ':d']
# ['know', ':)']
# ['build', 'hous', ':)']
# ['yeah', 'kinda', 'feel', 'like', 'warm', 'butter', ':d']
# ['realli', 'week', 'big', 'decis', 'feel', 'rather', 'badass', ':)']
# ["i'm", 'go', 'sleep', 'hope', 'wake', 'follow', 'luke', 'hem', 'someday', ':)', 'goodnight', 'fam', 'ili', '5so', 'lot', '💟']
# ['congrad', 'better', 'updat', 'page', 'accomplish', ':-)', 'keep', '...']
# ['film', 'day', 'invit', 'reason', 'lol', ':)']
# [':)']
# ['whenev', 'sister', 'see', 'cri', 'text', 'ask', 'im', 'okay', 'aw', 'someon', 'care', ':-)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# ['t-shirt', ':d', 'awesom']
# ['belat', '..', 'thank', 'thank', ':d']
# ["can't", 'wait', 'see', ':-)']
# ['happi', 'happi', 'birthday', 'happi', 'happi', 'birthday', ':)']
# ['take', 'care', ':)']
# ['road', 'trip', 'tregaron', 'view', 'potenti', 'new', 'boar', 'finger', 'cross', 'bring', 'boy', 'home', ':)']
# [':)', 'good', 'know', ':)']
# ['told', 'im', 'gorgeou', 'extrem', 'sweati', 'walk', 'work', 'made', 'day', ':)']
# ['morn', 'em', ':)']
# ['glyon', ':d']
# ['💓', '🚮', '👯', 'definit', 'perfect', 'would', 'pictur', 'next', ':)']
# ['initi', "tee'", 'pm', 'order', ':)']
# ['confess', ':)', 'nice']
# ['welcom', ':)']
# ['nice', 'dave', ':d']
# ['know', 'dumb', 'think', 'johnni', 'rock', 'u', 'seen', 'utub', "video'", 'mad', 'respect', ':d']
# ['sorri', 'loss', 'hope', 'goe', 'well', ':)']
# ['combin', 'three', 'add', 'bit', 'asian', 'u', 'got', 'truli', ':)']
# ['happi', 'birthday', ':)']
# ['got', 'call', 'end', 'pigeon', 'home', 'safe', ':)', 'definit', 'worth', 'contact']
# ['morn', 'hospit', 'day', 'today', 'hope', 'final', 'get', 'sign', 'long', 'year', 'pain', 'op', 'fingerscross', ':)']
# ['best', 'photobomb', ':d', 'pic', '—']
# ['thank', 'se', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['finish', 'day', '33', 'plan', 'bibl', '90', 'day', 'check', '2', 'chronicl', '23', 'complet', ':)']
# ['yo', 'gimm', 'month', 'free', 'bill', 'sinc', 'servic', 'pretti', 'much', 'everi', 'day', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['hi', "i'm", 'definetli', 'exit', "i'm", 'go', 'new', 'york', ':)']
# ['saturday', ':)']
# ["i'v", 'type', 'wors', 'thing', 'good', ':p']
# ['beat', 'da', 'beat', 'sit', 'well', 'includ', 'new', 'video', ':-)', 'mobilegam', 'io', '8', 'android']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# ['thank', ':)', '💕']
# ['soon', '...', ':)']
# ['sure', ':)']
# ['look', 'fun', 'kik', 'thencerest', '547', 'kik', 'kiksext', 'sex', 'followback', 'l4l', 'indiemus', 'kikgirl', ':)']
# ['goodnight', 'guy', ':-)', 'rememb', 'tomorrow', 'brand', 'new', 'day', 'fresh', 'start', 'anoth', 'chanc']
# ['bom-dia', ':)', 'apod', 'ultraviolet', 'ring', 'm31', '2015', 'jul', '24']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# ['thank', 'follow', 'great', 'day', ':)']
# ['oooh', 'love', 'hope', 'fantast', 'time', ':)']
# ['yawn', 'good', 'morn', 'everyon', 'wag', 'tail', 'everyon', 'today', ':d']
# ['congrat', 'launch', ':d']
# ['happi', 'wonder', 'birthday', 'love', '💟', 'beauti', 'day', 'world', ':)']
# ['ftw', ':)']
# ['ah', 'see', 'song', 'prefer', 'take', 'maman', ':)']
# ['hi', 'hayley', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# ['gud', 'afterznoon', 'jumma', 'mubarak', 'tweeep', ':-)', 'plz', 'rememb', 'us', 'ur', 'prayer']
# ['welcom', 'bomb', 'famili', ':)', 'x']
# ['abp', 'news', 'ka', 'articl', 'read', 'kiya', ':d', 'bajrangibhaijaanhighestweek', '1']
# ['like', 'hurt', 'feel', 'anyth', 'right', ':)']
# ['check', 'new', 'van', 'outsid', 'olymp', 'park', 'anniversari', 'game', ':)']
# ['everi', 'year', 'august', 'get', 'fever', ':p', 'dunno', '😷']
# ['yeah', 'classi', 'look', ':-)', "i'v", 'seen', 'peopl', 'attach', 'sort', 'life', 'save', 'equip', 'bed', 'fix', '0']
# ['trend', '..', 'follow', 'bobbl', 'link', ':)']
# ['next', 'year', 'sure', 'though', ':)', "there'", '2', 'girl', 'piss']
# ['stand', 'cool', ':)']
# ['movi', 'key', 'life', 'japanes', 'version', 'interest', 'storylin', ':)']
# ['thank', 'anu', ':)']
# ['also', 'new', 'layout', 'new', ':)']
# ['im', 'tri', 'l', 'mh3', 'english', 'patch', 'psp', ':d']
# ['want', 'tweet', 'someth', 'thought', "i'll", 'probabl', 'lose', 'lot', 'liam', 'girl', 'mutual', ':)']
# ['1', 'day', 'go', '1', 'day', 'left', 'sponsor', 'us', 'matter', 'small', 'donat', 'differ', 'make', 'huge', ':)']
# ['thank', ':)']
# ['follow', ':)']
# ['hey', 'emili', 'love', 'work', "i'd", 'like', 'contribut', 'huffpost', 'busi', "what'", 'best', 'way', 'contact', ':)']
# ['asshol', '😂', "that'", 'honest', 'tribut', ':)']
# ['h_eartshapedbox', 'first', 'leg', 'magictrikband', 'tour', 'go', 'well', ':d', 'music', 'band', 'rock', 'magictrik', 'tour', '…']
# ['tower', 'ladi', ':)', 'tb', 'eid']
# ['whatsapp', 'roommat', 'want', 'anyth', 'pari', 'french', 'man', ':)', 'lol', 'sure', "i'll", 'head', 'park', 'grab', 'one']
# ['great', 'weekend', 'tami', 'thank', ':)']
# ['love', ':-)']
# ['want', 'look', 'good', ':)']
# ['sure', ':)']
# ['excit', 'weekend', ':-)']
# ['b3dk', 'far', '7an', 'ank', 'mi', '15', ':)']
# ['god', 'give', 'us', 'strength', 'purpos', 'help', 'other', 'struggl', ':-)']
# ['lol', 'meant', 'lucki', 'eagl', 'thank', 'servic', 'oceana', ':-)']
# ['woke', 'feel', 'incred', 'sick', 'idk', 'caus', 'drank', 'starbuck', '11', "o'clock", 'last', 'night', 'reaction', 'med', ':)']
# ['oop', '...', "that'", 'call', 'fridayfauxpa', ':)', "i'll", 'get', 'chang', 'right', 'thank', 'g']
# ['fulfil', 'fantasi', ':)', '👉', '👈', '💗']
# ['call', 'night', 'go', 'sleep', ':)']
# ['yeah', "they'r", 'give', 'subtl', 'hint', 'also', 'tip', '2', 'use', 'commun', 'last', 'year', ':-)', 'prim', '’', 'algorithm', 'iii']
# ['funni', 'ye', 'soon', 'alway', 'go', 'soon', ':d']
# ['thank', ':)', 'get', 'retweet', 'x']
# ['smile', 'receiv', 'text', 'dad', 'say', 'suck', ':)']
# ['wat', ':)']
# ["can't", 'wait', 'rosa', 'love', 'xma', ':)', 'welcom', 'back', 'ann', 'hope', 'u', 'good', 'one', 'back', 'time', ':)', 'x']
# ['morn', 'tweep', 'new', 'post', 'today', 'pleas', 'like', 'share', 'see', 'thank', ':)']
# ['yvw', 'great', 'day', 'weekend', ':d']
# ['awww', 'here', 'quick', 'workout', 'boost', ':-)']
# ['lol', ':d', 'know', 'idea', ':p', 'coz', 'unforgett', 'sens', 'humor', ';)', ':)', ':d', 'love', 'bro']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ["mum'", 'home', '...', 'hahahhaah', 'thank', 'lord', ':)']
# ['safe', ':d']
# ['girl', ':)']
# ['sombrero', 'high', 'okay', "i'm", 'lost', ':)']
# ['hellooo', "i'm", 'rose', 'nice', 'meet', ':)']
# ['thank', 'screenshot', 'po', 'let', 'take', 'care', 'spammer', ':)', 'proceed', 'c', '...']
# ['perfect', 'thing', 'pick', ':)', 'wsalelov']
# ['thank', 'amaz', 'job', ':)']
# ['die', 'actual', 'pretti', 'entertain', ':p']
# ['congrat', '100k', 'man', "can't", 'wait', 'till', 'hit', 'mileston', ':)']
# ['morn', '...', 'judith', 'answer', 'district', 'council', 'relat', 'question', 'today', ':-)']
# ['see', 'tomorrow', ':)']
# ['saw', 'comment', 'midar', 'gender', 'unknown', 'like', ':)', 'yeah', 'keep', 'say']
# ['wow', 'realli', 'hate', ':)']
# ['watch', 'saw', 'dan', ':)']
# ['thank', ':-)', 'ilysm', 'xx']
# ['thank', 'trade', ':)']
# ['look', 'forward', ':-)', 'ks']
# ['lesley', ':)']
# ['want', 'protect', 'relationship', 'other', "i'll", 'talk', 'ppl', 'need', 'know', 'awesom', ':)']
# ['oh', 'dang', 'zen', 'look', 'outsid', 'space', 'neat', ':-)']
# ['look', 'good', 'outfit', ':)']
# ['hiya', "i'm", 'afraid', "we'v", 'alreadi', 'pick', 'rider', 'year', "we'll", 'look', 'next', 'year', ':)']
# ['good', 'morn', 'u', ':)']
# ['ha', 'ha', 'ok', 'honey', 'go', 'ahead', 'fyi', 'still', 'dig', 'ya', 'enjoy', 'vote', 'watch', 'side', ':)']
# ['lucki', ':)']
# ['learn', 'new', 'skill', 'take', 'time', 'perfect', 'master', 'thank', 'favourit', ':)']
# ['👱🏽', '👽', '🌳', '😂', '😂', '😂', "i'v", 'talk', 'u', 'coupl', 'time', 'u', 'seem', 'nice', 'funni', ':)']
# ['agre', 'suspici', 'mind', ':)']
# ['good', 'afternoon', ':)']
# ['whoop', 'whoop', 'bring', 'fun', ':)']
# ['new', 'report', 'talk', 'burn', 'calori', 'cold', 'work', 'harder', 'warm', 'feel', 'better', 'weather', ':p']
# ['say', 'someth', "i'm", 'give', ':)', "i'm", 'sorri', 'get', ':d']
# ['good', 'night', ':)']
# ["there'", 'gonna', 'anoth', 'one', 'final', ':)']
# ['welcom', 'jessica', 'enjoy', ':)']
# ['best', 'friend', 'carina', 'one', 'san', 'francisco', 'let', 'know', 'want', 'get', 'touch', ':)']
# ['thank', 'mommi', 'teret', ':)', ':)', 'potassium', 'rehydr', 'drinkitallup', 'thirstquench']
# ["i'm", 'sure', 'tapir', 'calf', 'one', 'like', 'adventur', 'mealtim', ':)']
# ['uhc', 'box', 'larg', 'scale', 'one', 'network', 'server', ':p']
# ['ever', 'areal', "we'll", 'lunch', 'dinner', ':)']
# ["here'", 'one', 'extremesport', 'fan', 'among', 'love', 'quadbik', 'get', 'touch', ':)', 'bloggersrequir', 'bloggersw']
# ['thank', '...', 'love', 'cake', ':)', 'bear', 'hug', 'end']
# ['masa', 'nowaday', 'brainer', 'type', 'invest', 'list', 'mse', 'fund', ':)']
# ['magnific', ':-)']
# ['love', 'work', 'tokyo', ':)', 'kunoriforceo', 'ceo', '1month']
# ['yeah', 'tri', 'look', 'x', ':)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# [':)', 'hehe', 'get', 'think', 'mean', 'need', 'sleep', 'nooowww', 'nite', 'nite', ':)']
# ['hi', '5', 'back', ':)', ':)']
# ['ye', 'omg', 'lile', 'tid', 'tmi', ':)']
# ['may', 'deploy', 'degre', 'sarcasm', ':)']
# ['cute', 'boy', 'jule', ':-)']
# ["can't", 'wait', 'week', ':d']
# ['thank', 'follow', 'us', 'betti', 'miller', 'new', 'friend', 'alway', 'welcom', ':)']
# ['person', 'small', 'thing', 'u', 'expect', 'person', 'u', 'love', ':)']
# ['ye', 'hddc', 'also', 'favourit', ':)', 'salman', 'khan', 'movi', 'etern', 'case', 'watch', 'pthht']
# ['oh', 'shoot', 'well', 'watch', ':d']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['tope', ':)']
# ['good', 'night', 'sweet', 'dream', 'xxoo', '♡', '♥', '♡']
# ['littl', 'finger', ':d']
# ['love', ':)', '13', 'photo', 'explain', 'ukrain', 'russia']
# ['friday', ':)']
# ['hey', 'fam', 'vote', 'alreadi', ':)', 'gotta', 'win', 'boy', 'teenchoic']
# ['hi', 'jane', 'silver-wash', 'fritillari', ':)']
# ['pleasur', ':)']
# ['great', 'day', 'hunni', ':)']
# ['good', 'night', 'moon', ':)', 'pandora']
# ['2', 'ap', 'studi', 'hall', 'haha', 'great', ':)']
# ['follow', 'everyon', 'back', 'teamfollowback', ':-)']
# ['ha', 'almost', 'gave', 'fuck', ':)', 'boy', 'trash', 'wast', 'time', "that'", 'sure']
# ['amaz', 'pic', 'today', ':d']
# ['ye', 'alreadi', 'ad', 'pleas', 'check', 'final', 'design', ':)']
# ['noth', 'much', 'need', 'grow', ':)']
# ['easi', 'clever', 'interest', 'audienc', 'welcom', ':)']
# ['great', 'video', ':d']
# ['ask', 'end', '..', "i'm", 'friend', ':)']
# ["thank'", 'follow', 'keven', ':)']
# ['ha', 'love', 'pic', 'clearli', 'much', 'learn', 'popular', 'english', 'pastim', ':)']
# ['ashramcal', 'return', ':p']
# ['catch', 'fall', 'fall', 'ontrack', ':)']
# ['alway', 'make', 'thing', 'better', ':)', '❤', '️']
# ['guess', "they'll", 'show', 'german', 'also', 'subtitl', ':)']
# ['pinter', ':-)']
# ['goood', 'morninggg', 'jummah', 'mubarak', 'everyon', 'bless', 'amaz', 'day', 'ahead', ':)']
# ['cute', ':-)', '🐶']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['fabul', 'time', 'miss', ':)', 'xx']
# ['noth', 'perfect', 'smile', ':)']
# ['never', 'show', 'much', ':)']
# [':-)', 'cheer', 'pete', 'listen', 'later', '☺', '☺']
# ["that'", 'build', 'sunday', ':p']
# ['direct', 'attent', '...', 'awesome-o', ':)']
# ['get', 'us', 'tune', 'well', 'app', 'multipl', 'option', ':d']
# ['engin', ':)']
# ['happi', 'friday', ':d']
# ['cya', 'week', ':d']
# ['happi', 'shop', ':)']
# ['fantast', 'show', 'harrog', 'home', 'gift', 'back', 'offic', '2', 'day', 'jet', 'see', 'wonder', 'supplier', ':)']
# ['nice', 'one', ':d']
# ['ye', "let'", ':)']
# ['7', ':)', ':)', ':)', ':)']
# ['australia', 'morn', ':d']
# ['req', 'star', ':)', 'fridayloug']
# ['knew', 'whole', 'class', 'cri', 'hurt', 'word', ':)']
# ['opportun', 'anyon', 'ask', 'question', 'babe', 'includ', ':)', '4thstreetmus']
# ['lunch', ':)']
# ["i'll", 'hawaii', 'decemb', "we'll", 'kick', 'back', 'miss', ':)']
# ['two', '17', 'year', 'old', 'deepli', 'love', ':-)']
# ['aha', "that'", 'alright', '❤', '️', 'love', ':)']
# ['hope', 'nate', 'notic', 'edit', 'sinc', 'made', 'icon', ':)']
# ['send', 'john@timney.eclipse.co.uk', ':)']
# ['hah', '...', 'thousand', 'lie', ':d']
# ["i'd", 'will', 'tri', ':)']
# ['read', 'newspap', ':d']
# ['afternoon', 'date', '<3', ':)']
# ["here'", 'fan', 'made', 'art', 'u', ':)', 'guy', 'phone', 'lew', 'bend', ':d']
# ['nah', 'beaut', 'way', ':)']
# ['fallout', '4', 'get', 'see', 'glow', 'sea', 'technic', 'fallout', '3', 'play', 'see', ':d']
# ["i'm", 'friend', 'cousin', 'karen', 'gunderson', 'watch', 'europa', 'report', 'thoroughli', 'impress', 'want', 'say', 'great', 'script', ':-)']
# ['dri', 'start', 'wale', 'wait', 'duck', 'overtak', 'motorway', ':-)']
# ['good', 'morn', 'fab', 'friday', ':)']
# ['hahaha', '...', 'thu', '...', 'sneak', 'away', 'log', 'niteflirt', ':d']
# ['yep', "we'r", 'trash', 'af', 'im', 'indonesia', 'hbu', ':-)']
# ['obvious', 'get', 'better', 'tweet', ':-)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# ['bowl', 'alway', 'best', 'friend', ':)']
# ['hope', "i'll", ':)', 'x']
# ['say', 'must', 'chri', 'elli', ':)']
# ['ye', 'friendli', 'contest', 'loser', 'buy', 'drink', ':)']
# ['thank', 'follow', 'great', 'day', ':)']
# ['thank', ':-)']
# ['thank', ':d']
# ['day', 'practic', 'song', ':)']
# ["here'", 'remind', 'need', 'one', ':-)']
# ['harri', 'niall', '94', 'harri', 'born', 'ik', 'stupid', 'wanna', 'chang', ':d']
# ['select', 'other', '..', 'get', ':)']
# ['...', 'play', 'al', 'n', "he'll", 'score', 'fuck', 'night', ':)']
# ['bff', '..', ':)']
# ['hi', "here'", 'vid', 'stydia', 'take', 'look', ':)']
# ['im', 'send', 'alex', 'like', 'million', 'pictur', ':)']
# ['love', ':)']
# ['visit', 'blog', 'thank', ':d']
# ['happi', 'birthday', 'nawazuddin', 'siddiqu', '...', 'big', 'big', 'fan', ':)']
# ['ye', 'pleas', 'would', 'brighten', 'night', 'shift', 'nomnomnom', ':d', 'chocol', 'dukefreebiefriday', 'xx']
# ['done', 'eonni', ':)']
# ['fantast', 'night', ':)']
# [':)']
# ['boom', 'date', ':d', 'z']
# ['follow', 'alreadi', 'thank', ':)']
# ['thank', ':)']
# ['happi', 'end', 'insyaallah', ':)']
# ['that', 'way', 'see', 'west', 'ham', 'shit', 'small', 'club', 'london', 'villa', '3rd', 'biggest', 'brum', ':)']
# ['deni', 'vagina', 'rli', ':d', 'poor', 'thing', ':d']
# ['smile', 'sunnah', ':)', 'غردلي', 'عن']
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear', 'plz', 'let', 'know', 'u', 'think', ':)']
# ['share', 'readi', ':)']
# ['oh', 'white', 'rabbit', 'cutest', 'thing', "i'v", 'ever', 'seen', 'wait', 'ador', ':)']
# ['welcom', ':)', 'love', 'weekend', 'izzi']
# ['happi', 'birthday', 'mitch', ':-)', 'wish', 'best', 'good', 'day']
# ['thank', ':)']
# ['done', 'ya', 'minn', ':)', 'cjradacomateada']
# ['welcom', 'fun', ':)']
# ['recently.websit', 'upgrad', 'might', 'see', 'new', 'pictur', 'coolingtow', 'soon.thank', 'showinginterest', ':)']
# ['flipkartfashionfriday', 'multicolor', 'maxi', 'dress', 'pair', 'wid', 'wedg', 'make', 'ur', 'life', 'bright', 'color', ':)']
# ['alway', 'motiv', ':-)']
# ['nnnnot', 'see', 'upsid', ':-)']
# ['haha', 'kyle', "gf'", 'babi', ':)']
# ['lol', 'ok', 'watch', 'ya', 'bit', ':p']
# ['bluesidemenxix', "i'd", 'love', 'win', 'one', ':)']
# ['happi', 'birthday', ':)']
# ['hello', ':)', 'ardent', 'follow']
# ['goood', 'mooorn', ':)', 'want', 'sleep', '...']
# ['ghost', 'bae', ':d', 'love', 'wuppert', 'tagsforlikesapp', 'instagood', 'smile', 'follow', 'cute', 'photooftheday', '…']
# ['hahaha', 'okay', 'thank', ':)']
# ['lose', ':d']
# ['hehe', 'cool', ':)']
# ['morn', 'u', 'today', 'u', 'got', 'plan', 'lazi', "i'm", 'still', 'bed', 'toast', 'fresh', 'coffe', '2', ':)', 'great', 'fridayfunday']
# ['welcom', 'famili', ':)']
# ['re-sign', ':)']
# ['meet', 'harri', "that'", 'need', 'life', ':-)']
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['one', 'sleep', 'til', 'wed', ':-)']
# ['excit', 'chalkhil', 'park', 'celebr', 'tomorrow', 'midday', 'come', 'join', 'fun', ':-)']
# ['hello', ':)', 'love', 'carter', ':)']
# ['good', 'read', ':)']
# [':-)']
# ['enjoy', 'hope', 'weather', 'hold', 'guy', ':-)']
# ['done', ':)']
# ['remedi', 'media', 'tell', ':-)']
# ['thank', ':)']
# ['jumma', 'mubarak', 'stay', 'bless', ':)']
# ["we'r", 'look', 'forward', 'abl', 'spend', 'time', ':)', 'enjoy', 'iflix', ':)']
# ['tgif', 'weekend', '...', 'enjoy', ':)']
# ['im', 'thank', 'someon', 'like', 'life', 'inspir', 'better', 'everyday', 'love', 'mind', 'follow', ':)']
# ['becom', 'better', 'atrack', 'better', ':)']
# ['first', 'third', 'look', 'promis', 'els', 'fail', 'make', 'decis', 'go', ':)']
# ['crazi', 'girlfriend', 'like', ':-)', '(-:', 'jesu', 'christ']
# ['morn', ':)', 'gd', 'day', 'store', "i'm", 'badminton', '2', "littl'un", 'fabfriday']
# ['kid', 'insid', 'want', 'one', ':-)']
# ['imran', 'khan', 'hero', ':)', 'realli', 'ikprideofpak']
# ['janjua', 'friend', ':)']
# ['sorri', 'fuck', 'eric', 'think', 'he', 'funni', ':)']
# ['say', 'bday', ':)']
# ['hey', ':)', 'check', 'pictur', 'think', ':)', 'notic', 'follow', 'pleas', '💕', 'x']
# [':)', ':)', ':)', 'pimpl', ':)', ':)', ':)', 'forehead', ':)', ':)', 'size', ':)', ':)', ':)', 'volcano', ':)']
# ['good', 'luck', 'coupl', 'get', 'marri', 'weekend', ':)']
# ['back', ':)', 'done', 'na', 'mag', 'miryenda', ':)']
# ['wait', 'bro', ':-)']
# ['parti', '3d', 'printer', ':)', 'celebr', 'futur', "technology'", 'possibl', 'touchétoday', '…']
# ['u', 'use', 'app', 'listen', 'music', 'ye', 'app', ':-)', '—', 'idownload']
# ['get', '25ish', 'snowbal', ':p']
# ['cours', ':)']
# ['nd', 'go', 'expir', 'next', 'year', 'dat', 'mtn', '6gb', 'u', ':d', 'realli', 'like']
# ['happi', 'birthday', 'nice', 'day', ':)', 'loveu']
# ['wanna', 'go', 'back', 'time', 'everyth', 'still', 'fine', ':-)']
# ['celebr', 'life', ':)', 'summer', 'morefuninthephilippin', 'laho', 'island', 'caramoan', 'island']
# ['nice', 'quot', ':)', 'kunoriforceo', 'ceo', '1month']
# ['good', 'stuff', ':)', 'love', 'bit', 'salmon']
# ['jumma', 'kareem', ':)', 'friday', 'remind', 'recit', 'surah', 'kahaf', '..']
# ["i'm", 'join', 'right', ':d']
# ['sure', '..', ':)']
# ['hi', 'melani', ':-)', 'fact', "they'r", 'realli', 'use', 'case', 'normal', 'wifi', 'could', 'issu', 'mention', '...']
# ['quit', 'phenomen', 'offer', 'bosch', 'wash', 'machin', "week'", 'definit', 'last', 'long', ':)']
# ['one', 'ok', "i'll", 'run', 'photo', 'moment', ':d']
# ['thank', 'refollow', ':)']
# ['slept', 'less', '7', 'hour', 'last', 'night', 'prepar', 'possibl', 'nap', ':p']
# ['idk', ':p', 'follow', '😎', '💁🏻']
# ['feel', 'like', 'relaps', ':-)']
# ['girl', 'nice', 'wallet', 'boy', 'prada', 'hai', '..', 'girl', 'rich', '..', 'boy', 'stupid', 'mean', 'bhai', 'ka', 'hai', ':p', 'prada', 'punjabiswillgetit']
# ['☺', 'morn', 'babe', ':)']
# ['lol', 'sorri', 'ultor', 'first', 'hitter', '...', 'favor', 'much', ':)']
# ['finish', 'mass', 'effect', '1', 'yesterday', 'dont', 'know', 'shoud', 'start', 'mass', 'effect', '2', '100', 'game', ':)']
# ['bad', 'would', 'remind', 'exercis', '1:12', ':-)', 'miss', 'need', 'come', 'back']
# ['add', 'kik', 'ughtm', '545', 'kik', 'kikmeguy', 'kissm', 'nude', 'likeforfollow', 'musicbiz', 'sexysasunday', ':)']
# ['overwhelm', 'groupmat', 'thank', 'group', 'got', '1', '75', 'recit', ':)']
# ['ha', 'mistak', 'thank', 'point', ':)']
# ['kyunk', 'aitchison', 'hai', ':p', 'look', 'respons', 'origin', 'tweet', 'know', 'brother']
# ['snapchat', 'sexyjudi', '19', 'snapchat', 'kikmeboy', 'tagsforlik', 'pussi', 'gay', 'indiemus', 'sexo', ':)']
# ["that'", 'true', 'inde', 'curvi', 'rout', ':)']
# ['come', 'chill', 'fire', ':)']
# ['mont', 'doa', 'header', ':d']
# ['haha', 'x', ':d']
# ['ted', 'speaker', 'say', 'stress', 'good', 'bodi', 'anoth', 'speaker', 'introduc', 'way', 'avoid', 'stress', ':)', 'ted', 'thought', 'laboratori', ':)']
# ['thing', 'note', 'awesom', ':-)']
# ['might', 'lose', 'friend', 'today', 'know', 'idc', ':)']
# ['good', 'morn', ':d', 'lol', 'realli', 'fuckin', 'dark', 'gonna', 'rain', 'hard', 'coupl', 'minut']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['ff', 'amaz', 'singer', 'actress', 'model', ':-)']
# ['happi', 'birthday', 'see', 'tonight', ':)']
# ["i'm", 'amsterdam', 'guy', 'wooo', ':d']
# ['stuff', 'happen', ':)']
# ['friend', ':)']
# ['neobyt', ':)', 'univers', 'pictur', 'seed', 'pirat', 'movi', 'copi', 'file', 'takedown', 'notic']
# ['2', 'indirag', 'want', 'judiciari', 'commit', 'govt', 'polici', 'want', 'rbi', 'commit', 'know', 'mani', 'similar', 'view', ':)']
# ["thought'", 'kepler', '452b', ':d']
# ['progress', 'stone', 'transfer', 'chelsea', ':d']
# ['gg', 'bro', ':)', 'fun', 'seri']
# ['alway', 'part', 'part', 'defenit', '...', '♬', ':p']
# ['cours', 'man', ':)', 'nofx', 'shit']
# ['friskyfiday', 'yipee', ':)', 'x']
# ['morn', 'kim', 'sorri', 'hear', 'shed', 'light', 'issu', 'look', ':)', 'helen']
# ['great', 'incent', 'get', 'kid', 'eat', 'fruit', 'vege', ':-)']
# ['welcom', 'sir', ':)']
# ['know', 'averag', 'take', '6', 'second', 'read', 'god', 'dam', 'mother', 'fuck', 'tweet', ':)']
# ['thank', 'favourit', 'tweet', 'marin', ':)']
# ['get', 'close', "can't", 'wait', 'new', 'season', ':)']
# ['gz', ':d', 'name']
# ['morn', 'day', ':-)']
# ['guess', 'sleep', 'list', 'thing', 'today', ':-)']
# ['hai', 'rajeev', '..', 'hope', 'u', 'r', 'hvng', 'funfil', 'friday.it', 'ws', 'reali', 'amaz', 'c', 'diff', 'side', 'kabir.fel', 'luv', 'u', ':)', 'smile', 'pl']
# ['prettier', ':)', 'mine', ':)']
# ['happi', 'birthday', 'best', 'wish', 'dresden', 'germani', ':)', 'love', '<3', '<3', '<3', '<3', 'pleas', 'share']
# ['wanna', 'loser', 'like', ':)', '♥']
# ['zayn', 'pleas', 'follow', 'would', 'mean', 'world', 'birthday', ':d', 'love', 'much', 'amaz', '<3']
# ['congratul', 'friend', 'graduat', 'lose', 'plot', ':d']
# ['0', 'sleep', 'offici', 'way', 'pari', 'cannot', 'wait', ':)', 'pari', 'tdf', '2015', '🇫🇷', '🍷', '🍸', '☀', '️', '🇫🇷', '🚲', '🇫🇷', '🍷', '🍸', '☀', '️', '🚲']
# ['put', 'trust', ':)']
# ['hey', 'good', 'suggest', 'guy', 'make', 'minion', 'slot', 'would', 'fun', 'cute', ':)']
# ['happi', "b'day", ':)']
# ['hah', '...', 'thousand', 'lie', ':d']
# ['wow', 'look', 'good', 'isabella', 'make', 'wanna', 'start', 'work', 'back', ':d']
# ['go', 'room', 'bc', '3', ':-)']
# ['okeyyy', 'vddd', ':)', ');', 'excit', "can't", 'wait', '...', 'love', 'selfee', 'pic', 'insta', ':)', '♥', '♥', 'special', 'coco', '..', '🙆', '🙌', '😛', '😄', '😄', '😁', '😂', '😂', '🐒', '😁', '😝', '❤', 'dishoom']
# ['think', 'write', ':)']
# ['final', 'went', 'drive', 'tonight', ':-)']
# ['thank', 'follow', 'great', 'day', ':)']
# ['im', 'go', 'sleep', 'goodnight', ':)']
# ['hello', ':)']
# ['yup', 'know', 'okay', 'let', 'tri', ':)', 'done', 'hhahhaaa', '—', 'haha']
# ["i'm", 'suppos', 'ask', 'buy', 'album', ':)']
# ['6', 'day', 'go', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['least', "there'", 'one', 'cool', 'thing', ':-)']
# ['hey', 'guy', "that'", 'new', 'page', ':)', 'enjoy']
# ['jeez', 'tara', 'move', 'teamcannib', 'vs', 'teamspacewhalingisthebest', ':p']
# ['morn', 'gym', 'session', 'done', 'feel', 'good', 'workout', 'earli', '...', 'enjoy', 'rest', 'day', ':)', 'friyay', 'workout', 'fitfa', '…']
# ['guess', 'never', 'realli', 'identifi', 'pharmaci', ':)', 'verylaterealis', 'iwishiknewbett']
# ['yeah', 'know', 'lack', 'thing', 'hey', 'pleas', 'check', 'final', 'design', 'satisfi', 'enough', ':)']
# ['wow', 'nice', 'combin', ':)']
# ['charg', 'speaker', 'final', 'got', 'earlier', 'today', ':)']
# [':)', 'masaantoday']
# ['later', 'turn', ':d']
# ['text', 'wanna', 'meet', "i'll", 'get', ':)']
# ['long', ':)']
# ['friend', 'never', 'talk', 'ess-aych-eye-te', 'anyon', ':)']
# ['ya', 'thank', ':)', '😊']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['yeah', 'left', 'one', 'supposedli', 'hurt', 'bc', 'right', 'heart', 'appar', "it'll", 'fine', 'good', 'luck', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['ahh', 'thank', 'u', ':d']
# ['niall', 'follow', 'fan', ':)', "i'm", 'still', 'without', 'follow', '👍']
# ['sister', 'best', 'best', 'pre', 'bday', 'celebr', ':)']
# ['among', 'time', 'fav', 'tweet', ':d']
# ['happi', 'birthday', 'g', 'best', 'life', ':)']
# ['need', 'stress', 'time', ':)']
# ['immedi', 'plan', 'hope', 'someday', 'futur', ':)']
# ['could', 'make', "foxy'", 'song', 'version', 'instrument', 'form', 'sound', 'epic', 'beat', 'alon', ':)']
# ['second', 'well', 'done', ':)']
# ['think', 'hard', 'bed', ':p']
# ['tomorrow', 'goldcoast', ':)']
# ['like', 'way', 'said', 'gal', 'lelomustfal', 'beautiful', 'way', ':)']
# ['happi', 'save', 'day', ':)', 'hope', 'enjoy', 'meal', 'sam']
# ['thank', 'min', ':)']
# ['5g', 'liker', ':)', 'like', 'fast']
# ['like', 'morn', 'got', 'dress', 'bought', ':)', "i'm", 'total', 'love', '♡', 'newdress', 'happi', '…']
# ['ff', 'could', 'anyon', 'resist', 'beauti', 'smile', ':-)', 'quacketyquack']
# ['u', 'mean', 'hide', 'fot', ':p']
# ['aww', 'thankyou', ':)']
# ['ok', 'good', 'night', 'wish', 'troy', 'ugli', 'met', 'today', ':)', '):', 'ok', 'today', 'fun', "i'm", 'excit', 'tmrw']
# ['inde', ':-)']
# [':)', 'good', 'afternoon', ':d', 'twitterfollowerswhatsup', 'happyfriedday', 'keepsafealway', 'loveyeah', 'emojasp_her']
# ['okay', ':)']
# ['make', 'two', 'us', ':d']
# ['hurt', 'read', "people'", 'holiday', 'work', ':d']
# ['nice', 'hear', 'want', 'switch', 'us', ':)', 'pro', 'kit', 'would', 'best', 'choic', 'follow', 'link']
# ['beauti', '...', 'winter', 'like', 'summer', 'russia', ':)']
# ['thought', '’', 'like', 'mate', ':)']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['dm', ':p']
# ['also', 'come', 'game', ':)']
# ['thank', ':)']
# [':)', 'hope', 'enjoy']
# ['ok', 'first', 'time', 'chat', 'made', 'joke', 'lol', 'believ', 'wont', 'forget', 'u', ':)', 'name']
# ['mymonsoonstori', 'bodi', 'shop', 'bodi', 'mist', 'vanilla', 'work', 'wonder', 'skin', ':)']
# [':)', 'best', 'youtub', '...', 'keep', 'good', 'work', 'man', 'starsquad', 'sidemen']
# ['yaaayyy', 'best', 'friendaaa', 'shout', 'like', 'minion', ':)']
# ['thank', 'ad', 'us', 'list', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# ['1tbps4', 'wow', 'prize', 'delight', 'eye', 'pick', 'win', 'burst', 'sing', 'ps4', 'mine', 'feel', 'divin', ':)']
# ['bath', ':)', 'even', '’', 'wheeli', 'bin', 'nowher', 'put']
# ['get', 'readi', '...', 'ubericecream', 'messengerforaday', ':)']
# ['yeap', ':)']
# ['must', 'watch', ':d', 'bajrangibhaijaanhighestweek', '1']
# ['cool', '...', 'congrat', 'kyli', 'u', 'look', 'nice', ':-)']
# ['thought', 'work', 'season', 'realli', 'busi', 'day', 'ok', 'deal', 'weekend', 'toilet', 'break', ':p']
# ['daddi', 'af', '...', ':-)']
# ['latest', 'one', ':)']
# ['happi', 'make', ':)']
# ['far', 'good', 'ikaw', 'musta', 'cheatmat', ':)']
# ['e', 'l', 'f', 'thank', 'singer', ':)', 'kyuhyun', 'thank', 'e', 'l', 'f']
# ['20', 'ghanton', 'se', 'light', 'nahi', ':)']
# ['one', 'last', 'long', 'lol', 'block', 'alreadi', 'must', 'nice', 'tweet', 'hate', ':)']
# ['ur', 'skin', 'think', 'ur', 'still', '16', 'decid', 'break', ':-)', 'cool']
# ['easy.get', '5:30', 'go', 'work', 'come', 'home', 'bout', '6', 'take', 'care', 'home', 'famili', 'therein', "that'", 'see', ':-)']
# ['thank', 'majalah', 'juli', 'issu', ':)', 'love', '👍🏼', '👍🏼', '👍🏼', '😍', '😍', '😍', '🌸', '🌸', '🌸']
# ['piti', 'parti', ':-)']
# ['tgif', 'unless', 'one', 'student', ':)', 'light', 'read', 'singapor', 'hero', 'gp', 'essay', 'alevel']
# ['dominiqu', "i'm", 'biggest', 'fan', 'like', 'oh', "i'm", 'england', 'get', 'fan', 'sign', ':)']
# ['good', 'caus', "i'd", 'like', 'upload', ':)']
# ['goood', 'mornin', 'earthl', ':d']
# ['happi', 'tweet', 'like', 'new', 'build', ':)', 'mm']
# ['okay', 'yay', 'ask', 'tomorrow', 'pleas', ':)']
# ['alway', ':)', 'posit']
# ['lamp', 'shop', ':)']
# ['word', 'big', 'site', 'got', 'chang', 'a-foot', ':)', 'websit', 'develop', 'revamp']
# ['vote', 'brainchild', '3', 'time', 'pleas', 'may', 'poem', ':d']
# ['confid', 'confin', 'u', 'ur', 'limit', '...', ':)']
# ['wish', 'colorado', ':)']
# ['happi', 'friday', 'folk', 'order', 'goodyear', 'tyre', 'onlin', 'get', 'upto', '£', '40', 'cashback', 'cs', 'appli', 'yourewelcom', ':)']
# ['nightli', 'routin', 'simpin', ':-)']
# ['add', 'snapchat', 'yall', ':)', 'give', 'name']
# ["i'm", 'look', 'influenc', 'app', ':)', 'interest', "here'", 'invit']
# ['sketchbook', 'art', 'love', '4wild', 'draw', 'hair', 'turn', 'pretti', 'cool', ':d', 'art', 'hair', 'color', 'colorpencil', 'cray', '…']
# ['tune', 'back', 'hubbi', ':)', 'u', 'play', 'queen', 'pl']
# ['fell', 'asleep', 'like', '6:30', "can't", 'fall', 'asleep', 'two', 'hour', ':-)']
# ['great', 'night', 'great', 'peopl', ':)']
# ['imma', 'use', 'next', 'time', ':)']
# ['ob', '11h', 'v', 'kino', ':)']
# ['gone', 'make', 'tho', 'posit', 'day', ':)', 'adult', "can't", 'keep', 'act', 'like', 'mom', '..']
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear', 'plz', 'let', 'know', 'u', 'think', ':)']
# ['great', 'went', 'kardamena', 'last', 'summer', 'amaz', 'beach', 'wonder', 'sea', 'year', 'time', 'go', 'samo', 'greec', ':)', ':)']
# ['chicken', 'caesar', 'salad', 'tad', 'bland', 'live', ':)']
# ['love', 'afraid', 'respond', 'hate', ':)', 'ili', 'x', 'x', 'x']
# ['first', 'leg', 'tour', 'go', 'well', ':d', 'music', 'band', 'rock', 'magictrik', 'tour']
# ['okk', 'den', 'call', 'abp', 'n', 'spread', 'allov', 'india', 'n', 'abroad', 'well', ':p']
# ['thank', 'much', ':)']
# ['pleas', 'let', 'us', 'know', 'store', 'abl', 'visit', 'may', 'inform', 'expect', ':)']
# ['tweet', 'much', 'appreci', 'thank', 'dedic', 'member', ':)']
# ['freedom', 'hangout', 'whoever', 'want', ':)']
# ["i'm", 'like', ':)']
# ['hi', ':-)', 'look', 'tourist', 'info', 'get', 'applic', 'zonzofox', 'click', 'link', 'bye', ';-)']
# ['leo', 'season', ':-)', '♌', '️']
# ['life', 'kutiyapanti', ':d', 'love', 'life', ':d']
# ['thank', 'support', ':)', 'kunoriforceo', 'ceo', '1month']
# ['profession', 'hit', 'video', 'wick', 'boomshot', 'fuh', 'di', 'world', 'even', 'thank', ':)']
# ['yeeey', 'welcom', 'club', 'one', 'half', 'year', 'whatsapp', '..', 'donot', 'regret', '..', ':)']
# ['problem', ':)', 'pleasur', '❤', '️']
# ['send', 'one', 'pleas', ':)', 'wont', 'expos', 'roast', '<3']
# ['lemm', 'cover', 'u', 'lipstick', 'n', 'cran', 'vodka', ':-)']
# ['road', 'trip', ':d']
# ['alway', 'walk', 'past', 'place', 'may', 'go', 'tri', ':d']
# ['yeah', "i'v", 'lost', 'call', 'day', ':)']
# ['jummah', 'mubarak', 'rememb', 'prayr', ':)']
# ['member', 'හෙල', 'හවුල', 'chanc', ':d']
# ['miss', 'babi', ':)', 'onemochaonelov']
# ['yo', 'southpaw', 'great', 'movi', 'someon', 'better', 'get', 'award', ':d']
# ['music', 'human', 'geniu', 'stroma', ':)']
# ['🔴', 'live', 'younow', 'jonah', 'jareddd', ':)']
# ['messag', 'full', 'name', 'b', 'address', 'postcod', 'talkmobil', 'phone', 'number', 'thank', ':)']
# ['last', 'class', 'morn', 'two', 'week', 'break', ':-)']
# ['happi', 'happi', 'birthday', 'emili', ':d']
# ['elf', 'fight', 'huha', ':d', ':)', 'teenchoic', 'choiceinternationalartist', 'superjunior']
# ['may', 'find', 'confus', ':)', 'simpl', 'wolf']
# ['nice', 'pic', ':)']
# ['promot', ':)']
# ['yeah', 'bird', 'transform', 'sword', ':d']
# ['even', 'real', 'word', ':d']
# ['could', 'misread', 'wors', 'thing', ':p']
# ['forward', 'richard', '...', 'follow', ':)']
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via']
# ['yup', 'happen', 'everywher', 'peopl', 'cant', 'debat', 'come', 'name', 'call', ':-)']
# ['need', 'get', 'work', 'today', 'ibiza', ':)', ':)', ':)', 'birthdaymoneyforjesusjuic']
# ['anytim', ':)']
# ['mistak', 'happen', 'man', 'long', 'get', 'play', 'game', "we'll", 'happi', ':)']
# ['hey', 'wanna', 'check', 'ytb', 'channel', 'post', 'gameplay', 'tutori', ':)', 'via']
# ['one', 'construct', 'critic', 'welcom', ':)', 'ganesha', 'textur', 'photographi', 'art', 'hinduism', 'hindugod', 'elephantgod']
# ['ye', 'alway', 'selfish', 'fuck', ':)']
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via']
# ['want', 'creat', 'first', 'bboy', 'cardgam', 'pixelart', 'gamedesign', ':d', 'think', 'indiedev', 'pixel_daili', 'gamedev']
# ['sound', 'still', 'like', 'good', 'idea', ':)']
# ['limit', 'plateau', 'must', 'stay', 'must', 'go', 'beyond', ':)', 'bruce', 'lee']
# ['man', 'sing', 'rain', ':)']
# ['laguna', ':)', 'see']
# [':)', 'time', 'nhi', 'tha', 'offic', 'work', 'bahot', 'tha', '10', 'baje', 'raat', 'ko', 'liya', 'tha', 'hath', 'tri', 'creat', 'best', '2', 'ghant', 'itna', 'hi', 'bana', 'paya']
# ["that'", 'true', 'quit', 'whenev', 'want', ':d']
# ['thank', ':)', 'weekend', 'tri', 'best', ':)']
# ['u', 'like', 'uta', 'read', 'manga', ':-)', 'love', 'even', ':-)', 'haha', 'yeah']
# ['famili', 'hang', ':)', '—', 'feel', 'festiv', 'jamuna', 'futur', 'park']
# ['move', 'forward', 'happi', 'spirit', 'find', 'thing', 'alway', 'work', '\\:']
# ['rememb', 'sent', 'present', 'last', 'christma', 'dub', 'swiftma', ':)']
# ['miss', ':-)']
# ['super', 'proud', ':)']
# ['love', 'pic', 'fab', 'show', ':-)', 'x']
# ['morn', ':)']
# ['tha', 'case', 'trion', 'interact', 'forum', 'twitch', ':)']
# ["that'", 'spirit', ':)', 'wsalelov']
# ['sort', 'earli', 'hour', 'thank', 'help', 'rais', 'initi', 'issu', 'make', 'commun', ':)']
# ['hii', 'follow', 'pleas', "i'd", 'like', 'ask', 'one', 'thing', 'dm', ':)', '💞']
# ['happi', 'b-day', ':)']
# ["that'", 'disgust', 'glad', 'acc', 'back', ':)', 'hope', 'get', 'deserv']
# ['back', '80', 'brand', 'new', 'commodor', '64', 'program', 'commun', 'town', ':)', '12th', 'august']
# ['okay', ':)']
# ['im', 'wear', 'mine', 'dj', 'next', 'fri', ':-)']
# ['thank', 'take', 'time', 'tweet', 'us', 'annabel', "we'll", 'pass', 'london', 'bridg', 'team', ':)']
# ['alreadi', ':)']
# ['everi', 'way', 'like', 'jess', ':)']
# ['happi', 'friday', ':)']
# ['short', 'routin', 'quest', 'borderland', ':)', 'wanderrook']
# ['thank', 'made', 'day', ':)', "let'", 'organis', 'meet', 'soon', 'base', 'london']
# ["i'm", 'person', 'workout', 'eat', 'healthi', 'minut', 'gain', 'weight', ':-)']
# ['gm', 'meet', 'preciou', 'soft', 'ladi', 'real', 'friend', 'mizz', 'preciou', ':)', ';)', 'mani', 'like', '...']
# ['aameen', '..', ':)', 'long', 'live', 'pakistan', '..', 'bleedgreen', '..', '✌🏻', '️']
# ['alreadi', 'follow', 'back', 'oppa', ':)']
# ['liam', 'sophia', 'chicago', ':)', '♥']
# ['btw', 'honeymoon', ':)']
# ['yeah', 'bring', 'boom', "da'esh", 'co-ord', 'fsa', 'estat', ':)']
# ['welcom', ':)', "when'", 'next', 'meet']
# ['singer', 'dusti', 'tunisia', '<3', 'music', 'tunisia', '<3', 'wonder', 'nice', 'peopl', ':-)', '<3', 'youtub', '...']
# ['la', "class'", ':p']
# ['hahaha', 'go', 'doug', ':-)']
# ['forgot', 'ask', 'may', 'post', 'fb', 'happi', 'friday', ':-)']
# ['visit', 'blog', 'thank', ':d']
# ['everyon', 'fuckin', 'irrit', ':)']
# ['also', 'mean', 'imma', 'go', 'back', 'twitter', 'activ', ':d', 'caus', 'know', 'everyon', 'miss', ';)', 'xd']
# ['hello', 'ladi', 'apolog', 'delay', 'pleas', 'dm', 'us', 'address', 'size', 'detail', "we'll", 'ship', 'prize', ':)']
# ['free', 'voucher', 'twitter', 'friend', 'use', 'fiverr', ':)']
# ['oh', 'gina', 'busi', ':-)', "can't", 'wait', 'see', 'hear', 'xxx', 'soproud']
# ['happi', 'friday', 'everyon', 'hope', 'fantast', 'week', ':)', 'friday']
# ['ye', 'one', 'team', ':)']
# ['happi', 'belat', 'birthday', 'sweeti', ':)']
# ['morn', 'emma', ':)']
# ['thank', 'guy', ':)']
# ['would', 'say', ':-)']
# ['love', 'make', 'two', 'heart', 'one', ':)']
# ['thank', 'ad', 'us', 'list', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# ['thank', 'mr', 'bee', 'xxx', ':-)']
# ['thankyou', ':)']
# ['close', 'enought', ':)']
# ['good', 'luck', '...', 'anoth', 'potenti', 'favourit', 'water', 'hole', ':-)']
# ['bad', 'boy', ':)', 'burger', 'melbourneburg']
# ['want', 'ft', 'arianna', ':-)']
# ['everyon', 'follow', ':)']
# ['hey', 'lesley', 'sorri', 'get', 'shall', 'send', 'post', 'tonight', ':)']
# ['thank', 'esai', ':-)']
# ['thank', 'text', 'back', ':)', "i'm", 'text', 'tomorrow', ':)']
# ['unfollow', 'back', ':)']
# ['hope', 'enjoy', 'stay', 'rotterdam', 'know', 'cheer', 'jordi', 'clasi', ':)']
# ['hi', 'hot', 'girl', 'say', 'hot', 'horni', 'darl', 'xx', ':)', '♥']
# ['sure', 'done', ':)']
# ['salon', 'bleach', 'hair', 'olaplex', 'damag', 'like', ':)']
# ['teamwork', 'right', ':d', 'zitecofficestori']
# ['ff', 'happyfriday', 'great', 'friday', ':-)']
# ['sure', ':)']
# ['다쇼', 'got', '7', "let'", 'got', '7', 'fact', ':)']
# ['still', 'tomorrow', 'work', 'colleagu', 'interest', 'bring', 'kid', 'along', ':)', 'point', 'eb', 'page']
# ['tack', '<3', ':d']
# ["t'would", 'tweetup', 'without', 'book', 'rest', 'assur', 'book', ':)']
# ['thank', 'much', 'know', 'greatest', 'magic', 'detect', 'jonathancreek', 'back', 'tv', 'set', 'dvr', ':)']
# ['get', 'home', '4', 'wake', '9', ':)', ':)']
# ['thank', 'take', 'time', 'tweet', 'kat', ':)']
# ['lot', 'rarer', 'life', 'twitter', ':)']
# ['okkk', 'frend', 'milt', 'h', 'break', 'k', 'bad', ':)']
# ['could', 'fun', 'sexi', 'girl', 'two', 'sexi', 'girl', ':)', '👉', '👈', '😘']
# ['..', 'thank', 'mario', '...', 'wonder', 'friday', '...', ':)']
# ['fun', 'daniel', 'hope', 'goe', 'well', ':-)']
# ['thank', 'hope', 'got', 'good', 'book', 'keep', 'compani', ':-)']
# ['yeah', "i'v", 'watch', 'cours', 'rewatch', 'ad', 'free', 'faster', 'hope', ':)', 'thank', 'look', 'forward']
# ['price', 'around', '1600', "i'm", 'gonna', 'forward', 'info', 'email', 'decid', 'interest', ':)']
# ['got', 'bed', 'yet', ':-)']
# ['awww', 'sige', 'next', 'time', 'u', 'know', 'na', 'punta', 'kayo', 'dun', 'imma', 'make', 'sure', 'na', "we'll", 'go', 'din', ':-)']
# ['sure', 'thing', ':)', 'x']
# ['...', 'friday', ':d']
# ['cours', 'would', 'like', ':)', 'x']
# ['nooo', 'didnt', 'even', 'know', 'that', 'actual', 'type', 'googl', ':)']
# ['found', 'prompt', ':-)']
# ['chillin', 'w', 'salmon', ':)']
# ['see', 'beauti', 'believ', 'exist', 'first', ':)']
# ['hi', 'j', 'upgrad', 't-mobil', 'orang', 'ee', 'us', 'dm', 'mobil', 'number', "i'll", 'ask', 'sale', 'call', ':)']
# ['congratul', 'realli', 'look', 'forward', 'book', 'good', 'sunday', 'morn', 'view', "that'", 'awesom', 'teapot', 'btw', ':-)', 'x']
# ['three', 'refresh', 'cocktail', 'even', '«', 'hotter', '»', 'summer', 'one', 'suit', ':)', 'londoutrad', 'cocktail']
# ['love', ':)', '<3']
# ['wip', 'let', 'get', 'thing', 'tweak', "i'll", 'link', ':)', 'max', 'kal', 'tak']
# ['fab', 'giveaway', ':)']
# ['case', '..', 'facebook', 'wall', ':p']
# ['stat', 'week', 'arriv', '3', 'new', 'follow', 'unfollow', ':)', 'via']
# ['home', 'alon', ':d']
# ['wish', 'happi', 'birthday', 'awesom', 'fun', 'fill', 'day', ':d']
# ['let', 'know', 'hear', 'anyth', ':)', 'xx']
# ['wayward', 'pine', 'later', ':)']
# ['yeah', 'better', 'use', 'offici', 'account', ':)', 'like', '❤', '️']
# ['rock', 'muscl', ':d', 'ilikeit']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['check', 'page', 'belong', 'one', 'watford', 'commun', 'hous', 'trust', 'enterpris', 'cube', 'particp', ':-)', '...']
# ['follow', 'back', 'pleass', ':)']
# ['omg', 'that', 'sweet', 'thing', 'say', 'thank', ':-)', 'yeah', 'use', 'go', 'saudi', 'arabia', 'lot', 'dad']
# ['ty', 'followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['good', 'luck', 'ur', 'exam', ':)']
# ['one', 'approv', 'recogn', 'fanbas', 'bailona', ':)']
# ['nice', 'see', 'peopl', 'chang', 'need', 'fix', 'care', ':)']
# ['happi', 'responsibilti', 'ask', 'other', 'make', 'happi', ':)', 'fb']
# ['park', 'get', 'sunlight']
# ['happi', ':)', '<3']
# ['good', 'night', 'tiger', 'sweet', 'furri', 'dream', 'xxoo']
# ['nice', 'one', ':)']
# ['want', 'elev', 'posit', 'want', 'promot', 'want', 'favor', 'god', 'favor', 'men', '...', ':)']
# ["i'm", 'insecur', 'tonight', ':-)']
# ['<3', 'guy', ':)']
# ['dan', 'god', 'bless', 'meet', 'greet', 'soon', ':)']
# ['mom', ':)', 'horror', 'movi']
# ['oh', 'hell', 'yeah', ':)', "i'll", 'expect', 'text', 'next', 'tuesday']
# ['welcom', 'sabah', ':-)']
# ['match', 'day', 'bitchesss', 'real', 'madrid', 'vs', 'man', 'shitti', ':d']
# ['squash', 'commit', 'still', 'make', '200', 'commit', ':)']
# ['west', 'countri', 'weekend', 'next', 'ride', 'day', 'tuesday', ':)', 'sunni', 'weekend', 'around']
# ['ourdaughtersourprid', 'mani', 'mani', 'congratul', 'papa', 'ji', ':)']
# ['thank', 'becca', ':)']
# ['love', 'new', 'song', 'delta', 'rock', ':)']
# ['saw', 'thought', 'might', 'need', 'upgrad', 'girl', 'get', 'bigger', ':)']
# ['first', 'love', 'wanna', 'fuck', 'late', 'night', 'think', 'got', 'nut', ':-)', 'v', 'look', '...']
# ['enjoy', 'cute', 'babi', 'panda', ':)']
# ['done', 'yun', ':)']
# ['watch', 'joe', 'dirt', '2', ':)']
# ['ohh', 'happyfriday', 'thank', 'love', 'team', ':)']
# ['alway', 'posit', ':)', 'postiv', 'selfi']
# ['good', 'morn', 'sharon', 'realli', 'hope', 'better', 'today', 'medicin', 'work', 'thank', ':)', 'ttyl', 'x']
# ['oh', 'fab', 'gav', 'love', 'love', 'ladi', 'linda', 'talk', 'time', 'great', 'actress', ':d', 'x']
# ['follback', ':d']
# ['answer', 'super', 'sonic', 'fast', ':)', 'would', 'love', 'win', 'first', 'time', ';)', 'gohf']
# ['3hr', '..', ':)', 'tym', 'prepar']
# ['dieback', 'music', 'pack', 'total', 'worth', 'awesom', ':)', 'dota', '2']
# ['morn', ':)']
# ['think', 'might', 'endit', 'london', 'photo', 'vid', 'minecon', 'london', 'video', ':)', 'look', 'rememb', 'great', 'time']
# ['ok', '...', 'sere', '2', 'play', 'yah', 'min', '..', 'haha', ':)']
# ['joerin', 'scene', ':)', 'joshan', 'power', 'tandem']
# [':d', "can't", 'sleep', 'need', 'tri', 'lay', 'bed', 'bore']
# ['stat', 'day', 'arriv', '6', 'new', 'follow', 'unfollow', ':)', 'via']
# ['b', 'call', 'friend', 'need', ':)', '...']
# ['hello', 'ligao', 'citi', 'albay', ':-)', 'concert', 'bcyc', 'lnh']
# ['goodnight', 'love', 'luke', 'heart', ':-)', 'love', '💜']
# ['happi', 'birthday', 'enjoy', 'vacat', ':)']
# ['congratul', 'sat', '3rd', 'honorari', 'degre', 'everyon', 'alac', ':)']
# ['hey', 'raspberri', 'island', 'skelo_ghost', ':)', 'want', 'get', 'iph', '0ne', '6', 'free', 'kindli', 'check', 'bi0', 'thx']
# ['thank', 'u', ':)']
# ['thank', 'great', ':)', '❤', '️', '😘']
# ['deserv', 'madadagdagan', 'pa', 'yan', ':-)', 'congrat', ':-)', 'bmc', '<3']
# ['save', 'money', 'use', 'good', 'way', 'money', 'money', 'better', 'life', 'fun', ':)', 'nice', 'day', '11:11']
# ['u', 'find', 'ur', 'friend', 'ditch', 'u', 'caus', 'lot', 'thing', ':)', 'wtf', 'done', 'im', 'actual', 'nice', 'person']
# ['order', 'dress', '..', ':)', ':)']
# ['like', 'eye', ':d']
# ['dear', 'person', 'pleas', 'studi', 'embarrass', 'urself', 'entropi', 'work', '100', 'w', 'evolut', ':)']
# ['ye', 'stay', 'touch', ':)', 'instagram']
# ['look', 'forward', 'alway', 'love', 'giggl', 'loop', 'two', 'great', 'act', ':)']
# ['cheer', 'mention', '...', 'even', 'wrong', 'section', ':)']
# ['ty', 'dear', 'eva', "i'm", 'total', 'agre', ':-)', 'keep', 'smile', 'u']
# ['spain', 'morn', ':)', 'good', 'morn', 'ian']
# ['anoth', 'note', 'found', 'camden', 'town', '...', ':d', 'work']
# ['even', 'talk', 'great', ':)']
# ['ohhh', 'wait', '28', ':)', 'luv', 'uhh']
# ['thank', 'favorit', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# ['scoup', '17', 'like', 'jren', 'nuest', ':d']
# ['oh', 'love', 'lovelayyy', 'thank', 'ok', 'kidney', '..', 'want', 'anyway', ':p']
# ['neuer', 'post', 'onlin', ':)', 'fix', 'spray']
# ['check', 'us', ':)', 'untangl', 'never', 'easier', 'dtangl', 'patent', 'innov']
# ['class', 'today', 'train', 'friend', ':)']
# ['okay', 'let', 'get', 'bat', ':)']
# ['one', 'fall', 'love', 'choic', '’', 'chanc', '...', ':)', '♡']
# ['would', 'email', 'donnae.strydom@westerncape.gov.za', ':-)', 'ta']
# ...
# [':(', 'bitch', 'realli', 'went']
# ['fave', 'unfollow', ':(', '😩', '💖']
# ['realli', 'want', 'visit', 'iceland', ':(']
# ['zayn_come_back_we_miss_y', '<3', '<3', ':(', 'much']
# ['starv', ':-(']
# ['bc', 'feel', 'creepi', 'today', 'pmsl', 'mianh', 'milkeu', ':(']
# ['wanna', 'meet', 'boy', ':(']
# ['internet', 'total', 'bitch']
# ['lrt', 'bambam', 'like', 'soda', ':(', 'meant', ':(']
# ['1', ':(']
# ['wish', 'could', 'go', 'shop', 'whole', 'weekend', 'taken', ':(', 'annoy']
# ['peopl', 'usual', 'stay', 'asleep', 'wtf', ':(']
# ['cheer', ':-(']
# ['payback', 'like', 'video', 'tri', 'help', 'get', 'kit', 'kat', ':(']
# ["i'm", 'even', 'tire', ':-(']
# ['one', 'come', 'smoke', ':(']
# ['87000', 'jobe', 'deliveri', 'pl', ':(']
# ['happi', 'birthday', 'be', 'enjoy', 'day', 'beb', 'love', 'miss', 'sooo', 'muchi', ':(', 'see', 'soon', 'sana', '💞', '🎈', '🎂', '🎉', '😘']
# ['cuti', ':(']
# ['alway', 'fall', 'asleep', 'earli', "i'm", 'text', 'someon', ':(']
# ['say', 'icecream', 'avail', ':(']
# ['ask', 'go', 'bathroom', ':-(', "i'm", 'realli', 'enjoy', 'show', 'though']
# ['lagg', 'much', 'certain', 'peopl', ':(']
# ['need', 'clear', 'head', ':(']
# ['babi', 'went', 'back', 'sleep', "i'm", 'bore', ':-(']
# ['ughh', 'got', 'noth', 'pain', ':(']
# ['laper', 'banget', ':(']
# ['naw', ':(', 'deep', 'dream', 'novel', 'hope', "there'd", 'invis', 'page', 'beast', 'scuttl', 'around', "there'", 'worm', 'track']
# ['bauuukkk', ':(']
# ['bad', 'guy', 'cant', 'attend', "today'", 'music', 'bank', ':(']
# ['worri', ':-(']
# ['“', 'mine', '...', 'damnnn', 'finee', 'omaigoshhh', ':(']
# ['care', 'muslim', ':(']
# [':(']
# ['jessica', 'call', 'quit', 'power', 'ab', '5:15', ':-(']
# ['lost', 'us', 'friend', '...', ':(', 'one', 'start', 'argument']
# ['hope', 'fun', 'vidcon', 'rlli', 'bum', 'couldnt', 'go', ':(', 'love', 'sunshin', '💛', '💛', '💛']
# ['yepp', '..', "i'm", 'get', 'bore', ':(']
# ['last', 'night', 'good', ':(', '😺', '💒', '💎', '🎉']
# ['follow', ':(']
# ['feelin', 'sick', ':(']
# ['want', 'biscuit', 'slather', 'chocol', 'definit', 'tax', 'boo', ':(']
# ['investig', 'answer', 'especi', 'pup', 'die', 'within', 'free', 'insur', 'period', ':(']
# ['jsut', 'end', ':(']
# ['heart', 'hurt', 'real', 'bad', ':(']
# ['aw', ':(']
# ['follow', 'pl', ':(']
# ["i'm", 'realist', '...', ':(']
# ['belov', 'grandmoth']
# ['happi', 'princess', 'today', ':(', 'sigh', 'get', 'work', 'done', 'x', 'purpl', 'princess', 'edit']
# ['babee', ':(', 'demn', 'hotaisndonwyvauwjoqhsjsnaihsuswtf']
# ['someth', 'wrong', ':(']
# ['word', 'explain', 'way', 'miss', ':(']
# ['think', 'need', '2', 'year', 'train', 'beat', 'record', 'sia', ':(']
# ['niram', 'ya', 'geng', ':(', 'fikri', 'anna', '6', 'other', 'tirtagangga', 'hotel', '—']
# ['char', 'im', 'realli', 'sick', ':(', 'one', 'font', 'size', '8', 'minion', 'float', 'font', 'size', '12', 'sick', 'kid', 'pl', ':(']
# ['bestfriend', 'like', 'ed', 'plsss', ':(']
# ['riprishikeshwari', 'soul', 'rest', 'peac', ':(']
# [':(', 'unfollow', 'like', '300', 'peopl', 'caus', 'follow', '1k', 'peopl', 'difficult']
# ['enough', 'time', 'listen', 'artist', 'music', ':-(']
# ['take', 'ice', 'creamist', 'pleasee', ':(']
# ['alway', 'go', 'terribl', 'time', ':(']
# [':-(', 'challeng', 'though', 'pleas', 'check', 'fb', 'page', 'entri', 'rather', 'substitut', 'thank']
# ["can't", 'even', 'see', 'hyungwon', ':(']
# ['tell', 'pl', 'eat', ':-(']
# ['that', 'life', 'get', 'call', 'peopl', 'havent', 'seen', '20', 'year', 'alway', 'favour']
# ['omg', ':(', 'everi', 'time', 'would', 'complain', 'skin', 'mom', 'everyon', 'get', 'pimpl', 'like', 'although']
# ['letsfootbal', 'atk', 'greymind', '43', 'break', 'news', 'chri', 'gayl', 'say', 'cricket', '2-3', 'month', 'due', 'back', 'surgeri', ':(', 'cplt', '20', 'cp', '…']
# ['miss', 'hannah', 'montana', "that'", 'raven', 'sooo', 'much', ':-(']
# ['want', 'rt', ':(']
# ['gonna', 'okay', 'love', ':(']
# ['awh', ':-(', '💙', 'stay', '💪']
# ['last', 'full', 'night', 'greec', ':(', 'opu', 'inner', 'pleasur']
# ['disappoint', 'hear', 'especi', 'invest', 'one', ':-(']
# ['ye', ':(', 'bbq', 'attend']
# ['work', ':(']
# ['three', '190', 'row', '33', ':(']
# ['throat', 'hurt', 'bad', ':(']
# ['lolliv', ':(']
# ['im', 'watch', 'disney', 'channel', ':(']
# ['nobodi', 'pick', 'one', 'right', ':(']
# ['someon', 'gift', ':(', 'calibraskaep', 'need', 'bad']
# ['lol', 'got', 'split', 'hard', 'lol', 'singl', 'singl', 'split', 'collat', 'spilt', 'singl', 'singl', 'spilt', 'singl', 'split', 'singl', 'singl', 'collat', ':(']
# ['hope', 'feel', 'better', 'jay', ':(']
# ['ye', 'mani', 'time', ':(', 'quitkarwaoyaaro']
# ['stu', 'deacti̇v', ':(']
# ['disappoint', ':(', 'never', 'ever', 'lucki', 'handl', 'jabongatpumaurbanstamped']
# ['hello', 'need', '2.5', 'g2a', 'code', 'pl', ':(']
# ['thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'sherep', 'nemen', 'ng', 'behey', 'ke', ':(']
# ['deactiv', 'acc', ':(', 'otwolgrandtrail']
# ['still', 'sad', 'kick', 'epic', 'motherfuck', ':(']
# ['realli', 'want', 'anoth', 'tattoo', ':(']
# ['someon', 'get', 'mad', 'reec', 'vm', 'tomorrow', 'pleas', 'never', 'one', ':(']
# ['deth', 'deth', 'dont', 'leav', ':(']
# ['true', ':-(']
# ["let'", 'go', '더쇼', 'cast', 'vote', 'got', '7', 'today', ':(']
# ['someon', 'hug', 'pl', ':(']
# ['omg', ':(', 'gonna', 'happen', 'yeah', 'wish', '..']
# [':(', 'lest', 'gp', 'get']
# ['aww', ':(', 'catch', 'departur']
# ['appar', 'isnt', ':(']
# ['miss', 'day', ':(', 'toothsensit']
# ['unavail', ':(']
# ['mean', "can't", 'wipe', ':-(']
# ['found', 'flight', 'home', '13', 'hour', 'long', ':(']
# ['ugh', 'yuck', ':(', 'make', 'sure', 'rest', 'next', 'two', 'day']
# ['omg', 'sad', 'birthday', 'sorri', 'didnt', 'send', 'someth', 'ystrday', 'ill', 'later', 'cuz', 'dont', 'phone', ':(']
# ['seolhyun', 'isnt', 'first', 'ep', 'she', 'film', 'drama', ':(']
# ['sorri', ':(']
# ['alway', 'get', 'like', '5', '4', 'piec', 'spici', 'nugget', ':(']
# ['im', 'sooo', 'hungri', 'though', ':(']
# ['thigh', 'cramp', ':-(']
# ['fellow', 'morn', 'owl', 'sure', 'notic', 'sun', 'alreadi', 'rise', 'bit', 'later', '...', 'sign', 'winter', 'come', ':(']
# ['nowher', 'near', 'tire', ':(']
# ['hot', ':(']
# ['dude', ':(', "i'm", 'scare', 'lol']
# ['rain', 'whole', 'day', 'mumbai', '’', 'feel', 'like', 'work', ':(']
# ['best', 'get', 'littl', 'ladi', "pj'", 'need', 'go', 'wallpap', 'mom', ':(', 'realli', 'cba', 'today']
# ['ye', 'pl', 'far', 'need', ':(']
# ['even', 'know', 'could', 'get', 'hotter', 'fml', ':(']
# ['aw', 'bless', 'made', 'smile', "i'm", 'miss', ':(']
# ['hi', 'life', ':(']
# ['mood', 'whole', 'day', ':-(']
# ['almost', 'done', 'park', 'rec', ':(', 'lol']
# ['u', 'come', 'back', ':(']
# ['hi', "we'r", 'sorri', 'hear', ':(', 'log', 'abl', 'see', 'inform', 'need']
# ['gotdamn', ':-(']
# ['want', 'phone', 'baaack', ':(']
# ['honest', 'miss', 'dubai', 'dubai', 'miss', 'want', 'come', 'back', ':(']
# ['final', 'get', 'star', 'driver', 'srw', 'mobag', ':(']
# ['sad', 'reason', 'suck', 'u', 'dunno', 'stop', 'sad', 'u', 'gotta', 'chill', 'ur', 'room', 'listen', 'music', 'b', 'alon', ':(']
# ['stream', 'pass', 'melon', 'pleas', 'stream', 'much', '인피니트', 'digit', 'bad', ':(']
# ['snapchat', 'jannygreen', '18', 'snapchat', 'kiksex', 'hot', 'teen', 'lgbt', 'goodmus', 'sexcam', ':(']
# ['aw', ':(', 'stroke']
# ['first', 'saw', 'gnr', 'open', 'alic', 'cooper', 'famou', 'parti', 'backstag', 'alic', 'r', 'slash', ':(']
# ['tag', '♡', "i'm", 'sorri', 'lot', 'music', 'prolli', 'know', 'half', ':(', 'also']
# ['24', 'hour', 'enough', ':(']
# ['awww', 'poor', 'bunni', ':(']
# ['stress', 'let', 'go', ':(']
# ['wish', 'blooper', ':(']
# ['love', 'u', 'fuck', 'know', ':(']
# ['yeah', ':(']
# ['noth', 'though', ':(']
# ['aww', "i'v", 'alreadi', 'left', 'would', 'come', 'said', 'hey', 'seen', 'sooner', ':(', 'good', 'night', 'x']
# ['weird', ':(']
# ['sr', 'financi', 'analyst', 'expedia', 'inc', 'bellevu', 'wa', 'financ', 'expediajob', 'job', 'job', 'hire']
# ['serious', ':(']
# ['tri', 'make', 'prison', 'style', 'alcohol', 'fail', 'badli', 'end', 'massiv', 'dose', 'shit', '...', ':(']
# ['fair', 'still', 'look', 'cute', ':(']
# ['hi', 'love', 'u', ':(', ':(']
# ['overli', 'attach', ':(']
# ["m'", 'voic', ':(', 'lord', 'help']
# ['want', 'bandana', 'bottl', 'set', 'huhuh', ':(']
# ["can't", 'sleep', 'bc', 'heartburn', ':-(']
# ['meet', 'steven', 'kid', 'listen', ':(']
# ["i'm", 'fuck', 'jealou', 'everyon', 'holiday', ':(']
# ['terribl', 'thing', 'doin', 'yoga', 'work', 'stop', 'start', '...', 'awalmu', 'njareeem', ':(']
# ['nooo', 'last', 'day', 'today', ':(']
# ['care', 'maggi', 'psycho', 'bitch', 'want', 'kill', 'take', 'two', 'day', 'vacat', 'twitter', ':(', 'wahhh']
# ['realli', 'look', 'forward', 'work', 'tonight', 'though', ':(']
# ['miss', 'abudhabi', ':(']
# ['go', 'home', 'blue', ':-(', 'back', 'monday', 'hiby', 'social', 'action', 'plan', 'shareyoursumm']
# ['pro', 'soccer', 'play', 'would', 'cool', ':(']
# ['wish', 'b8', 'strong', ':(']
# ['hey', 'girl', 'must.b', 'dairi', 'produxt', 'want', "can't", 'lactos', 'intoler', ':(']
# ['midland', 'ye', 'thank', 'depress', 'weather', 'forecast', 'word', 'rain', 'mention', 'sever', 'time', ':-(']
# ['cri', ':(']
# ['old', 'one', 'day', '...', ':(']
# ['liter', 'spent', 'day', 'yesterday', 'sleep', 'bed', "i'm", 'still', 'absolut', 'fuck', 'knacker', 'today', ':(']
# ['new', 'sandra', 'bland', 'footag', 'realli', 'ice', 'cake', '..', 'heartbreak', 'drag', 'lifeless', 'bodi', 'polic', 'car', ':(']
# ['knowww', ':(']
# ["we'r", 'sorri', 'feel', 'way', 'shell', ':(', 'regularli', 'review', 'price', 'offer', 'best']
# ['sorri', 'hear', 'jess', ':(', 'quickest', 'way', 'call', '44', '7782', '333', '333', 'add', 'account', 'within', '72', 'hour']
# ['pengen', 'box', ':(', '—']
# ['girlll', 'u', 'hear', 'abt', 'possibl', 'tsunami', 'us', 'west', 'indi', 'im', 'island', 'im', 'afraid', 'lol', ':(']
# ['snap', ':(']
# ['would', 'love', 'see', 'w', 'nick', 'pick', 'one', 'waist', 'tv', 'time', 'never', 'work', 'anyway', ':(']
# ['hulk', 'hogan', 'news', 'racial', 'tirad', ':(', 'thought', 'couldnt', 'stoop', 'lower', 'role', 'thunder', 'paradis']
# ['sorri', 'forget', 'import', 'day', 'huhu', 'fight', 'im', 'sorri', ':(']
# ['break', 'habit', 'lifetim', '...', "i'm", 'play', 'call', 'duti', 'game', '..', ':(']
# ['apolog', 'annoy', 'much', 'snapchat', ':(']
# ['adult', 'take', 'thing', 'seriou', 'realli', 'miss', 'kid', ':(']
# ['facad', 'democraci', 'drop', 'quickli', ':(']
# ['confus', 'brat', ':(']
# ['someon', 'come', "i'll", 'make', 'popcorn', 'watch', 'movi', 'pl', 'cuddl', ':(']
# ['final', 'home', 'drive', 'sinc', '5am', ':(']
# ['tb', 'mr', "o'", 'class', ':(']
# ['bade', 'fursat', 'se', 'usey', 'banaya', 'hai', 'usey', 'uppar', 'waal', 'ney', 'afso', 'hums', 'dur', 'hai', 'wo', ':(']
# ['oh', 'realli', ':(', 'saw', 'gif', 'post', 'seen', 'realli', 'happi', 'mayb', 'peopl', "who'd", 'happi', 'naruhina']
# ["can't", ':(']
# ['that', 'english', 'namee', ':(', 'haiqal', 'isnt', 'english', 'name', 'rememb']
# ['want', 'dont', 'paypal', ':(']
# ["that'", '360hr', 'summer', 'end', '...', 'huhuhu', 'miss', 'picc', 'lot', ':(']
# ['heart', 'hurt', ':(']
# ['instor', 'card', 'expir', 'june', 'havent', 'sent', 'new', 'one', ':(']
# ['mcountdown', 'pre-vot', 'begin', '5th', 'place', ':(']
# ['felt', 'bad', 'iren', 'forgot', 'go', 'say', ':(']
# ['wow', "that'", 'great', "what'", 'usernam', ':(']
# ['minho', 'still', 'injur', ':(', 'get', 'well', 'oppa', 'miss', '<3']
# ["can't", 'even', 'deliv', 'ice', 'cream', 'tri', 'twice', 'ice', 'cream', 'van', 'busi', ':(']
# ['want', 'durian', 'strudel', ':(']
# ['vidcon', ':(']
# ['guy', 'add', 'snapchat', 'amargolonnard', 'snapchat', 'kikmeboy', 'sexi', 'french', 'dirtykik', 'newmus', 'sexcam', ':(']
# ['u', 'chang', 'u', 'say', 'chang', 'tsk', ':(']
# ['damn', '..', 'wish', 'could', 'sleep', ':(']
# ['like', 'join', 'marin', ':-(']
# ["i'm", 'sad', 'yall', 'thought', 'real', ':(']
# ["i'm", 'go', ':(', 'kailan', 'ba', 'may', 'tix', 'ka']
# ['alreadi', 'kill', 'tho', ':(']
# ['hotel', 'dog', 'pretti', 'sad', 'brother', 'sister', 'got', 'separ', ':(']
# ['miss', 'cute', 'someon', 'la', ':(']
# ['payday', 'feel', 'like', 'payhour', 'gone', 'bill', 'immedi', ':(']
# ['lmao', ':(', 'natur', 'hair', "i'v", 'seen', 'ugli', 'swear']
# ['nope', ':(', 'best', 'place', 'get', 'first', 'pre-ord', 'amazon']
# ['sunday', 'littl', 'abl', 'get', 'much', 'year', 'busi', ':(', 'look', 'great', 'tho']
# ['fwm', ':(']
# ["what'", 'wrong', ':(']
# ['miss', 'guppi', ':-(']
# ['go', 'away', '...', 'must', 'go', 'dentist', ':(', 'poorkid']
# ['thank', 'lack', 'time', 'problem', ':(']
# ['get', 'misunderstood', ':(']
# ['ur', 'cat', 'super', 'nice', 'cuddli', 'suddenli', 'scratch', 'tri', 'bite', ':(', 'like', 'trust', 'anymor']
# ['hit', 'thumb', ':(']
# ['almost', 'got', 'see', 'cute', 'ankl', 'sock', ':(']
# ['honestli', 'point', 'care', 'compens', 'want', 'abl', 'play', 'bf', ':(']
# ['song', ':(']
# ['awww', 'babi', ':(', '💕']
# ['sleep', 'last', 'night', 'n', 'help', 'wake', '8', 'morn', 'n', 'phone', 'even', 'charg', ':(']
# ['pleas', 'tell', 'everyon', 'didnt', 'go', 'vidcon', ':(']
# ['need', 'like', 'tell', 'na', 'na', 'okay', 'lang', ':(']
# ['follow', 'back', ':(']
# ['heart', 'current', 'tortur', ':(', 'lol', 'wat']
# ['femal', 'student', 'kill', 'cast', 'love', 'kirkiri', ':(']
# ["i'v", 'run', 'bread', 'feel', 'well', 'enough', 'make', ':(']
# ['dream', ':(']
# [':(', 'broken', 'heart', "that'", 'phase', 'worri']
# ['stop', 'sour', ':(', 'suit', '😂', '💞']
# ['wonho', 'remind', 'someon', '>:(', 'cant', 'put', 'finger']
# ['wont', 'work', 'today', 'feel', 'ill', ':(', 'tummi', 'bug', 'xx']
# ['last', 'day', 'beach', ':-(', ':-(', ':-(', '...']
# ['rain', ':(']
# ['visual', 'studio', '2015', 'got', 'switch', 'alreadi', 'broke', 'lot', 'code', ':(']
# ['serious', 'unfair', 'ask', 'question', 'readi', 'answer', 'win', ':(', "='(", 'busi', 'ask', 'question']
# ['mission', 'bear', 'fail', ':(']
# [':-(', 'ugli', 'af', ':-(']
# ['pap', 'spirit', 'anim', '—', 'dont', ':(']
# ['total', 'ship', 'danzel', "i'm", 'craft', "can't", 'go', 'vidcon', 'would', 'sell', 'soul', 'devil', 'get', 'hug', 'dan', 'phil', ':(']
# ['hate', ':(']
# ["he'", 'gona', 'miss', 'sheff', 'utd', 'york', 'probabl', 'wait', 'visa', 'leav', 'gim', '1', 'friendli', 'bet', 'start', 'season', 'bench', ':(']
# ['lead', 'us', 'gone', ':(']
# ['😂', '😩', '😩', 'mess', ':(']
# ['ironi', 'harm', '..', ':(']
# ['miss', 'much', ':(', 'xxx']
# ['motiv', ':(']
# ['point', 'yolo', 'sort', 'die', 'lactos', '...', 'ugh', 'like', '3', 'month', 'pregnant', 'bloat', ':(']
# ['realli', 'sorri', 'cant', 'find', 'imag', 'mention', ':(']
# ['im', 'get', 'olli', 'tweet', 'notif', ':(']
# ['go', 'home', 'tomorrow', ':-(']
# ['bad', "i'm", 'poor', ':(']
# ['team', 'kill', ':(']
# ['way', ':(']
# ["i'm", 'inact', ':(']
# [':(', 'world', 'alterni', 'kill', 'realli', 'sad', 'leav', 'place', 'everyon', 'die']
# ['everyon', 'gonna', 'talk', 'abt', 'rat', 'boy', 'today', 'bc', ':(']
# ['earth', 'assum', 'rain', 'london', 'like', 'influenc', 'overal', 'warm', 'dri', 'past', 'week', 'continent', 'europ', ':(']
# ['rememb', 'fab', 'four', '24', 'hour', 'call', 'damn', 'miss', 'much', ':(']
# ['😀', '🔫', 'r', 'u', 'sure', 'u', 'want', 'b', 'r', 'u', 'h', 'bare', 'surviv', 'w', 'tank', 'top', ':(']
# ['thirsti', ':(']
# ['konami', 'polici', 'pe', 'pc', 'version', 'happen', 'version', ':(']
# ['sound', 'effect', ':(']
# ['blame', 'ranti', ':(']
# ['ummm', 'ok', 'new', 'develop', ':(']
# ['guy', 'never', ':(', '—', 'aw', 'sorri', "we'r", 'realli', 'bust', 'atm', '..', 'shall', 'back', 'soon']
# ['bad', ':(', 'like', 'video', 'mani', 'pervers']
# ['first', 'time', 'go', 'school', 'without', 'bracelet', ':(', 'feel', 'odd']
# ["can't", 'fall', 'back', 'asleep', ':(']
# ['im', 'twin', 'follow', 'back', 'bylfnnz', ':(']
# ['unfair', '..', 'u', 'ban', 'film', 'pakistan', ':(']
# ['want', 'one', ':(']
# ['feel', 'sick', ':(']
# ['hmmm', '10', 'min', 'get', 'train', "i'm", 'current', '15', 'min', 'away', ':(', 'failsatlif']
# ["i'm", 'hungri', ':(']
# ['want', 'birthday', 'alreadi', ':(']
# ['complet', 'agre', 'press', ':(']
# ['im', 'super', 'duper', 'tire', ':(']
# ['bore', 'time', ':(', 'know', '...']
# ['ill', 'soon', 'promis', ':(', 'waaah']
# ['wanna', 'chang', 'avi', 'usanel', ':(']
# ['puppi', 'broke', 'foot', ':(']
# ["where'", 'jaebum', 'babi', 'pictur', ':(']
# ['mr', 'ahmad', 'maslan', 'cook', ':(']
# ['hull', 'support', 'expect', 'misser', 'week', ':-(']
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %%
# Test your function
w1_unittest.unittest_test_logistic_regression(test_logistic_regression, freqs, theta)
# Out:
# 10
# ['bro', 'u', 'wan', 'cut', 'hair', 'anot', 'ur', 'hair', 'long', 'liao', 'bo', 'sinc', 'ord', 'liao', 'take', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', ':)', 'bro', 'lol', 'sibei', 'xialan']
# ['back', 'thnx', 'god', "i'm", 'happi', ':)']
# ['thought', 'ear', 'malfunct', 'thank', 'good', 'clear', 'one', 'apolog', ':-)']
# ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', '...', ':)']
# ['happi', 'friday', ':-)']
# ['wanna', 'chang', 'avi', 'usanel', ':(']
# ['puppi', 'broke', 'foot', ':(']
# ["where'", 'jaebum', 'babi', 'pictur', ':(']
# ['mr', 'ahmad', 'maslan', 'cook', ':(']
# ['hull', 'support', 'expect', 'misser', 'week', ':-(']
# 10
# ['bro', 'u', 'wan', 'cut', 'hair', 'anot', 'ur', 'hair', 'long', 'liao', 'bo', 'sinc', 'ord', 'liao', 'take', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', ':)', 'bro', 'lol', 'sibei', 'xialan']
# ['back', 'thnx', 'god', "i'm", 'happi', ':)']
# ['thought', 'ear', 'malfunct', 'thank', 'good', 'clear', 'one', 'apolog', ':-)']
# ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', '...', ':)']
# ['happi', 'friday', ':-)']
# ['wanna', 'chang', 'avi', 'usanel', ':(']
# ['puppi', 'broke', 'foot', ':(']
# ["where'", 'jaebum', 'babi', 'pictur', ':(']
# ['mr', 'ahmad', 'maslan', 'cook', ':(']
# ['hull', 'support', 'expect', 'misser', 'week', ':-(']
#  All tests passed

# %% [markdown]
# <a name='5'></a>
# ## 5 -  Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# ['bro', 'u', 'wan', 'cut', 'hair', 'anot', 'ur', 'hair', 'long', 'liao', 'bo', 'sinc', 'ord', 'liao', 'take', 'easi', 'lor', 'treat', 'save', 'leav', 'longer', ':)', 'bro', 'lol', 'sibei', 'xialan']
# ['back', 'thnx', 'god', "i'm", 'happi', ':)']
# ['thought', 'ear', 'malfunct', 'thank', 'good', 'clear', 'one', 'apolog', ':-)']
# ['stuck', 'centr', 'right', 'clown', 'right', 'joker', 'left', '...', ':)']
# ['happi', 'friday', ':-)']
# ['follow', ':)', 'x']
# ['teenchoic', 'choiceinternationalartist', 'superjunior', 'fight', 'oppa', ':d']
# ['birthday', 'today', 'birthday', 'wish', 'hope', "there'", 'good', 'news', 'ben', 'soon', ':-)']
# ['good', 'morn', ':-)', 'friday', '\U000fec00', 'plan', 'day', 'current', 'play', 'shop', '...']
# ['happi', 'friday', ':)']
# ['3', 'good', 'nigth', ':)', 'estoy', 'escuchando', 'enemi', 'god']
# ['actual', 'bye', 'bye', 'inde', 'go', 'take', 'drama', 'elsewher', ':)']
# ['ff', 'readi', 'weekend', ':)', 'smile']
# ['work', ':)']
# [':)', 'mood', 'bipolar']
# ['thank', ':)']
# ['hahahahahahahahahahahahahaha', 'die', ':)', 'liter', 'front', 'like']
# ['yoohoo', 'shatter', 'record', 'bajrangibhaijaanstorm', 'superhappi', ':d']
# ["who'", 'awak', ':-)']
# ['happi', 'friday', ':-)']
# ['pleasur', 'doll', 'thank', 'wonder', 'energi', 'class', ':)']
# ['f', ':)']
# ['delight', "m'dear", ':)']
# ['hi', 'emma', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# ['followback', 'beauti', 'girl', 'today', ':)']
# ['lyka', 'followback', ':)']
# ['alrd', 'joy', ':)']
# ['ourdaughtersourprid', 'dhan', 'dhan', 'satguru', 'tera', 'hi', 'aasra', '...', 'mani', 'congratul', 'pita', 'g', '...', 'keep', 'bless', 'alway', ':-)']
# ['thank', 'ye', "let'", 'hope', 'work', 'miss', ':-)']
# ['keeo', 'guess', 'what', 'behind', 'white', 'cover', ':)', 'special', '..', 'happi', 'bday', 'darl', '…']
# ['happi', 'friday', 'everyon', ':)', 'big', 'followfriday']
# ['awkward', 'moment', 'name', 'akarshan', 'end', 'stay', 'singl', ':d', 'foreveralon']
# ['know', ':)', 'hot', 'alway']
# ['worri', ':)', 'know', 'much', 'stress', 'problem', 'site', "can't", 'wait', 'till', 'event']
# ['say', 'sweetpea', 'start', 'hold', 'regular', 'gluten', 'free', 'cake', 'pastri', 'workshop', ':)']
# ['highfiv', 'probabl', 'ahead', 'sinc', 'less', 'artsi', 'verbal', ':d']
# ['bae', ':)', '<3']
# ['kid', 'kaaa', ':p']
# ['love', 'chat', 'cycl', 'oxford', 'campaign', 'way', 'home', 'yesterday', 'cycl', 'rout', 'pleas', ':)', 'cycl', 'oxford']
# ['wahoo', 'team', ':-)', 'masaantoday']
# ['anchor', 'sea', '..', ':)']
# ['dat', 'rp', 'tho', 'thank', 'much', 'guy', 'celebr', 'one', 'month', 'partnership', 'ty', 'raid', ':d']
# ['visit', 'robbenisland', 'cultur', 'experi', 'tri', 'whale', 'watch', 'aquat', 'safari', 'either', 'great', ':)']
# ['least', 'friday', ':d']
# ['mayb', 'garru', 'liara', 'rest', 'crew', ':d']
# ['thank', 'follow', 'great', 'day', ':)']
# ['massag', 'appoint', 'avail', 'tomorrow', 'morn', 'burnley', 'give', 'us', 'call', 'book', ':)', '01282', '453', '110']
# ['great', 'hear', 'nice', 'day', 'thank', 'visit', ':)']
# ['bore', 'everyth', ':d']
# ['drama', 'korea', '49', 'day', ':)']
# ['btw', 'anyon', 'repres', 'footbal', 'manag', 'commun', 'youtub', ':)', 'fm15', 'fmfamili', 'vidcon', '2015']
# ['mean', 'aamir', 'khan', 'one', ':)']
# ['happi', 'friday', ':)']
# ['right', 'back', 'excel', 'job', 'difficult', 'medium', ':)']
# [':)', 'want', 'ff']
# ['tweet', ':p']
# ['hey', 'come', 'see', 'us', 'summer', 'fine', 'food', 'fair', 'sunday', '11am', '4pm', 'ride', 'school', ':)']
# ['pleas', 'follow', 'liam', ':)']
# ['love', 'write', ':)', 'absolut', 'ador', 'nva', 'lucki', 'enough', 'live', '5', 'minuet', 'away', 'roll', 'gamec']
# ['ff', 'thank', 'brian', ':)']
# ['headrest', 'loos', "that'", 'reason', 'pit', ':-)']
# ['hi', "i'v", 'spoken', 'store', 'advis', 'paypoint', 'card', 'top', ':)', 'thank', 'beth']
# ['thank', 'help', ':-)']
# ['deepthroat', 'good', 'movi', ':)']
# ['hallo', 'twitter', ':d']
# ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# ['thank', 'wish', ':)']
# ['aitor', 'sn', 'would', 'mind', 'check', 'bio', 'particip', 'ps4', 'giveaway', 'could', 'winner', ':)']
# ['hi', 'jawad', 'today', 'thank', 'follow', 'retweet', 'much', 'appreci', ':)']
# ['thank', ':)']
# ['actual', 'need', 'stop', 'tweet', 'drive', ':-)']
# ['kind', 'feedback', 'truli', 'made', 'day', 'perfect', 'way', 'end', 'work', 'week', ':)']
# ['well', "that'", 'presal', 'ticket', 'bought', 'thank', 'wonder', 'take', 'book', '...', 'thing', 'parent', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['hope', 'goe', 'well', ':-)']
# ['betcha', ':)', 'dumb', 'butt', ':)']
# ['kik', 'qualki', '808', 'kik', 'kikmenow', 'milf', 'like', '4like', 'bore', 'summer', 'sexysaturday', ':)']
# ['follow', ':-)']
# ['thank', ':)']
# ['ye', 'hun', "i'm", 'good', ':)']
# ['enjoy', ':)']
# ['wow', 'vw', 'bu', 'lot', 'umpfff', 'love', ':)']
# ['ca', 'retweet', 'domg', 'nanti', 'difollow', ':d']
# ['wish', ':d', ':d', ':d', ':d', ':d', ':d', ':d', 'kid']
# ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48942981	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# ['ye', 'car', ':)']
# ['like', 'especi', 'klee', 'one', ':-)']
# ['look', 'amaz', 'april', 'love', 'glass', ':d']
# ['know', ':)']
# ['build', 'hous', ':)']
# ['yeah', 'kinda', 'feel', 'like', 'warm', 'butter', ':d']
# ['realli', 'week', 'big', 'decis', 'feel', 'rather', 'badass', ':)']
# ["i'm", 'go', 'sleep', 'hope', 'wake', 'follow', 'luke', 'hem', 'someday', ':)', 'goodnight', 'fam', 'ili', '5so', 'lot', '💟']
# ['congrad', 'better', 'updat', 'page', 'accomplish', ':-)', 'keep', '...']
# ['film', 'day', 'invit', 'reason', 'lol', ':)']
# [':)']
# ['whenev', 'sister', 'see', 'cri', 'text', 'ask', 'im', 'okay', 'aw', 'someon', 'care', ':-)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# ['t-shirt', ':d', 'awesom']
# ['belat', '..', 'thank', 'thank', ':d']
# ["can't", 'wait', 'see', ':-)']
# ['happi', 'happi', 'birthday', 'happi', 'happi', 'birthday', ':)']
# ['take', 'care', ':)']
# ['road', 'trip', 'tregaron', 'view', 'potenti', 'new', 'boar', 'finger', 'cross', 'bring', 'boy', 'home', ':)']
# [':)', 'good', 'know', ':)']
# ['told', 'im', 'gorgeou', 'extrem', 'sweati', 'walk', 'work', 'made', 'day', ':)']
# ['morn', 'em', ':)']
# ['glyon', ':d']
# ['💓', '🚮', '👯', 'definit', 'perfect', 'would', 'pictur', 'next', ':)']
# ['initi', "tee'", 'pm', 'order', ':)']
# ['confess', ':)', 'nice']
# ['welcom', ':)']
# ['nice', 'dave', ':d']
# ['know', 'dumb', 'think', 'johnni', 'rock', 'u', 'seen', 'utub', "video'", 'mad', 'respect', ':d']
# ['sorri', 'loss', 'hope', 'goe', 'well', ':)']
# ['combin', 'three', 'add', 'bit', 'asian', 'u', 'got', 'truli', ':)']
# ['happi', 'birthday', ':)']
# ['got', 'call', 'end', 'pigeon', 'home', 'safe', ':)', 'definit', 'worth', 'contact']
# ['morn', 'hospit', 'day', 'today', 'hope', 'final', 'get', 'sign', 'long', 'year', 'pain', 'op', 'fingerscross', ':)']
# ['best', 'photobomb', ':d', 'pic', '—']
# ['thank', 'se', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['finish', 'day', '33', 'plan', 'bibl', '90', 'day', 'check', '2', 'chronicl', '23', 'complet', ':)']
# ['yo', 'gimm', 'month', 'free', 'bill', 'sinc', 'servic', 'pretti', 'much', 'everi', 'day', ':)']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['hi', "i'm", 'definetli', 'exit', "i'm", 'go', 'new', 'york', ':)']
# ['saturday', ':)']
# ["i'v", 'type', 'wors', 'thing', 'good', ':p']
# ['beat', 'da', 'beat', 'sit', 'well', 'includ', 'new', 'video', ':-)', 'mobilegam', 'io', '8', 'android']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418981	b"i'm play brain dot braindot"
# ['thank', ':)', '💕']
# ['soon', '...', ':)']
# ['sure', ':)']
# ['look', 'fun', 'kik', 'thencerest', '547', 'kik', 'kiksext', 'sex', 'followback', 'l4l', 'indiemus', 'kikgirl', ':)']
# ['goodnight', 'guy', ':-)', 'rememb', 'tomorrow', 'brand', 'new', 'day', 'fresh', 'start', 'anoth', 'chanc']
# ['bom-dia', ':)', 'apod', 'ultraviolet', 'ring', 'm31', '2015', 'jul', '24']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418981	b"i'm play brain dot braindot"
# ['thank', 'follow', 'great', 'day', ':)']
# ['oooh', 'love', 'hope', 'fantast', 'time', ':)']
# ['yawn', 'good', 'morn', 'everyon', 'wag', 'tail', 'everyon', 'today', ':d']
# ['congrat', 'launch', ':d']
# ['happi', 'wonder', 'birthday', 'love', '💟', 'beauti', 'day', 'world', ':)']
# ['ftw', ':)']
# ['ah', 'see', 'song', 'prefer', 'take', 'maman', ':)']
# ['hi', 'hayley', ':-)', 'ask', 'bellybutton', 'inni', 'outi']
# ['gud', 'afterznoon', 'jumma', 'mubarak', 'tweeep', ':-)', 'plz', 'rememb', 'us', 'ur', 'prayer']
# ['welcom', 'bomb', 'famili', ':)', 'x']
# ['abp', 'news', 'ka', 'articl', 'read', 'kiya', ':d', 'bajrangibhaijaanhighestweek', '1']
# ['like', 'hurt', 'feel', 'anyth', 'right', ':)']
# ['check', 'new', 'van', 'outsid', 'olymp', 'park', 'anniversari', 'game', ':)']
# ['everi', 'year', 'august', 'get', 'fever', ':p', 'dunno', '😷']
# ['yeah', 'classi', 'look', ':-)', "i'v", 'seen', 'peopl', 'attach', 'sort', 'life', 'save', 'equip', 'bed', 'fix', '0']
# ['trend', '..', 'follow', 'bobbl', 'link', ':)']
# ['next', 'year', 'sure', 'though', ':)', "there'", '2', 'girl', 'piss']
# ['stand', 'cool', ':)']
# ['movi', 'key', 'life', 'japanes', 'version', 'interest', 'storylin', ':)']
# ['thank', 'anu', ':)']
# ['also', 'new', 'layout', 'new', ':)']
# ['im', 'tri', 'l', 'mh3', 'english', 'patch', 'psp', ':d']
# ['want', 'tweet', 'someth', 'thought', "i'll", 'probabl', 'lose', 'lot', 'liam', 'girl', 'mutual', ':)']
# ['1', 'day', 'go', '1', 'day', 'left', 'sponsor', 'us', 'matter', 'small', 'donat', 'differ', 'make', 'huge', ':)']
# ['thank', ':)']
# ['follow', ':)']
# ['hey', 'emili', 'love', 'work', "i'd", 'like', 'contribut', 'huffpost', 'busi', "what'", 'best', 'way', 'contact', ':)']
# ['asshol', '😂', "that'", 'honest', 'tribut', ':)']
# ['h_eartshapedbox', 'first', 'leg', 'magictrikband', 'tour', 'go', 'well', ':d', 'music', 'band', 'rock', 'magictrik', 'tour', '…']
# ['tower', 'ladi', ':)', 'tb', 'eid']
# ['whatsapp', 'roommat', 'want', 'anyth', 'pari', 'french', 'man', ':)', 'lol', 'sure', "i'll", 'head', 'park', 'grab', 'one']
# ['great', 'weekend', 'tami', 'thank', ':)']
# ['love', ':-)']
# ['want', 'look', 'good', ':)']
# ['sure', ':)']
# ['excit', 'weekend', ':-)']
# ['b3dk', 'far', '7an', 'ank', 'mi', '15', ':)']
# ['god', 'give', 'us', 'strength', 'purpos', 'help', 'other', 'struggl', ':-)']
# ['lol', 'meant', 'lucki', 'eagl', 'thank', 'servic', 'oceana', ':-)']
# ['woke', 'feel', 'incred', 'sick', 'idk', 'caus', 'drank', 'starbuck', '11', "o'clock", 'last', 'night', 'reaction', 'med', ':)']
# ['oop', '...', "that'", 'call', 'fridayfauxpa', ':)', "i'll", 'get', 'chang', 'right', 'thank', 'g']
# ['fulfil', 'fantasi', ':)', '👉', '👈', '💗']
# ['call', 'night', 'go', 'sleep', ':)']
# ['yeah', "they'r", 'give', 'subtl', 'hint', 'also', 'tip', '2', 'use', 'commun', 'last', 'year', ':-)', 'prim', '’', 'algorithm', 'iii']
# ['funni', 'ye', 'soon', 'alway', 'go', 'soon', ':d']
# ['thank', ':)', 'get', 'retweet', 'x']
# ['smile', 'receiv', 'text', 'dad', 'say', 'suck', ':)']
# ['wat', ':)']
# ["can't", 'wait', 'rosa', 'love', 'xma', ':)', 'welcom', 'back', 'ann', 'hope', 'u', 'good', 'one', 'back', 'time', ':)', 'x']
# ['morn', 'tweep', 'new', 'post', 'today', 'pleas', 'like', 'share', 'see', 'thank', ':)']
# ['yvw', 'great', 'day', 'weekend', ':d']
# ['awww', 'here', 'quick', 'workout', 'boost', ':-)']
# ['lol', ':d', 'know', 'idea', ':p', 'coz', 'unforgett', 'sens', 'humor', ';)', ':)', ':d', 'love', 'bro']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ["mum'", 'home', '...', 'hahahhaah', 'thank', 'lord', ':)']
# ['safe', ':d']
# ['girl', ':)']
# ['sombrero', 'high', 'okay', "i'm", 'lost', ':)']
# ['hellooo', "i'm", 'rose', 'nice', 'meet', ':)']
# ['thank', 'screenshot', 'po', 'let', 'take', 'care', 'spammer', ':)', 'proceed', 'c', '...']
# ['perfect', 'thing', 'pick', ':)', 'wsalelov']
# ['thank', 'amaz', 'job', ':)']
# ['die', 'actual', 'pretti', 'entertain', ':p']
# ['congrat', '100k', 'man', "can't", 'wait', 'till', 'hit', 'mileston', ':)']
# ['morn', '...', 'judith', 'answer', 'district', 'council', 'relat', 'question', 'today', ':-)']
# ['see', 'tomorrow', ':)']
# ['saw', 'comment', 'midar', 'gender', 'unknown', 'like', ':)', 'yeah', 'keep', 'say']
# ['wow', 'realli', 'hate', ':)']
# ['watch', 'saw', 'dan', ':)']
# ['thank', ':-)', 'ilysm', 'xx']
# ['thank', 'trade', ':)']
# ['look', 'forward', ':-)', 'ks']
# ['lesley', ':)']
# ['want', 'protect', 'relationship', 'other', "i'll", 'talk', 'ppl', 'need', 'know', 'awesom', ':)']
# ['oh', 'dang', 'zen', 'look', 'outsid', 'space', 'neat', ':-)']
# ['look', 'good', 'outfit', ':)']
# ['hiya', "i'm", 'afraid', "we'v", 'alreadi', 'pick', 'rider', 'year', "we'll", 'look', 'next', 'year', ':)']
# ['good', 'morn', 'u', ':)']
# ['ha', 'ha', 'ok', 'honey', 'go', 'ahead', 'fyi', 'still', 'dig', 'ya', 'enjoy', 'vote', 'watch', 'side', ':)']
# ['lucki', ':)']
# ['learn', 'new', 'skill', 'take', 'time', 'perfect', 'master', 'thank', 'favourit', ':)']
# ['👱🏽', '👽', '🌳', '😂', '😂', '😂', "i'v", 'talk', 'u', 'coupl', 'time', 'u', 'seem', 'nice', 'funni', ':)']
# ['agre', 'suspici', 'mind', ':)']
# ['good', 'afternoon', ':)']
# ['whoop', 'whoop', 'bring', 'fun', ':)']
# ['new', 'report', 'talk', 'burn', 'calori', 'cold', 'work', 'harder', 'warm', 'feel', 'better', 'weather', ':p']
# ['say', 'someth', "i'm", 'give', ':)', "i'm", 'sorri', 'get', ':d']
# ['good', 'night', ':)']
# ["there'", 'gonna', 'anoth', 'one', 'final', ':)']
# ['welcom', 'jessica', 'enjoy', ':)']
# ['best', 'friend', 'carina', 'one', 'san', 'francisco', 'let', 'know', 'want', 'get', 'touch', ':)']
# ['thank', 'mommi', 'teret', ':)', ':)', 'potassium', 'rehydr', 'drinkitallup', 'thirstquench']
# ["i'm", 'sure', 'tapir', 'calf', 'one', 'like', 'adventur', 'mealtim', ':)']
# ['uhc', 'box', 'larg', 'scale', 'one', 'network', 'server', ':p']
# ['ever', 'areal', "we'll", 'lunch', 'dinner', ':)']
# ["here'", 'one', 'extremesport', 'fan', 'among', 'love', 'quadbik', 'get', 'touch', ':)', 'bloggersrequir', 'bloggersw']
# ['thank', '...', 'love', 'cake', ':)', 'bear', 'hug', 'end']
# ['masa', 'nowaday', 'brainer', 'type', 'invest', 'list', 'mse', 'fund', ':)']
# ['magnific', ':-)']
# ['love', 'work', 'tokyo', ':)', 'kunoriforceo', 'ceo', '1month']
# ['yeah', 'tri', 'look', 'x', ':)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# [':)', 'hehe', 'get', 'think', 'mean', 'need', 'sleep', 'nooowww', 'nite', 'nite', ':)']
# ['hi', '5', 'back', ':)', ':)']
# ['ye', 'omg', 'lile', 'tid', 'tmi', ':)']
# ['may', 'deploy', 'degre', 'sarcasm', ':)']
# ['cute', 'boy', 'jule', ':-)']
# ["can't", 'wait', 'week', ':d']
# ['thank', 'follow', 'us', 'betti', 'miller', 'new', 'friend', 'alway', 'welcom', ':)']
# ['person', 'small', 'thing', 'u', 'expect', 'person', 'u', 'love', ':)']
# ['ye', 'hddc', 'also', 'favourit', ':)', 'salman', 'khan', 'movi', 'etern', 'case', 'watch', 'pthht']
# ['oh', 'shoot', 'well', 'watch', ':d']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['tope', ':)']
# ['good', 'night', 'sweet', 'dream', 'xxoo', '♡', '♥', '♡']
# ['littl', 'finger', ':d']
# ['love', ':)', '13', 'photo', 'explain', 'ukrain', 'russia']
# ['friday', ':)']
# ['hey', 'fam', 'vote', 'alreadi', ':)', 'gotta', 'win', 'boy', 'teenchoic']
# ['hi', 'jane', 'silver-wash', 'fritillari', ':)']
# ['pleasur', ':)']
# ['great', 'day', 'hunni', ':)']
# ['good', 'night', 'moon', ':)', 'pandora']
# ['2', 'ap', 'studi', 'hall', 'haha', 'great', ':)']
# ['follow', 'everyon', 'back', 'teamfollowback', ':-)']
# ['ha', 'almost', 'gave', 'fuck', ':)', 'boy', 'trash', 'wast', 'time', "that'", 'sure']
# ['amaz', 'pic', 'today', ':d']
# ['ye', 'alreadi', 'ad', 'pleas', 'check', 'final', 'design', ':)']
# ['noth', 'much', 'need', 'grow', ':)']
# ['easi', 'clever', 'interest', 'audienc', 'welcom', ':)']
# ['great', 'video', ':d']
# ['ask', 'end', '..', "i'm", 'friend', ':)']
# ["thank'", 'follow', 'keven', ':)']
# ['ha', 'love', 'pic', 'clearli', 'much', 'learn', 'popular', 'english', 'pastim', ':)']
# ['ashramcal', 'return', ':p']
# ['catch', 'fall', 'fall', 'ontrack', ':)']
# ['alway', 'make', 'thing', 'better', ':)', '❤', '️']
# ['guess', "they'll", 'show', 'german', 'also', 'subtitl', ':)']
# ['pinter', ':-)']
# ['goood', 'morninggg', 'jummah', 'mubarak', 'everyon', 'bless', 'amaz', 'day', 'ahead', ':)']
# ['cute', ':-)', '🐶']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['fabul', 'time', 'miss', ':)', 'xx']
# ['noth', 'perfect', 'smile', ':)']
# ['never', 'show', 'much', ':)']
# [':-)', 'cheer', 'pete', 'listen', 'later', '☺', '☺']
# ["that'", 'build', 'sunday', ':p']
# ['direct', 'attent', '...', 'awesome-o', ':)']
# ['get', 'us', 'tune', 'well', 'app', 'multipl', 'option', ':d']
# ['engin', ':)']
# ['happi', 'friday', ':d']
# ['cya', 'week', ':d']
# ['happi', 'shop', ':)']
# ['fantast', 'show', 'harrog', 'home', 'gift', 'back', 'offic', '2', 'day', 'jet', 'see', 'wonder', 'supplier', ':)']
# ['nice', 'one', ':d']
# ['ye', "let'", ':)']
# ['7', ':)', ':)', ':)', ':)']
# ['australia', 'morn', ':d']
# ['req', 'star', ':)', 'fridayloug']
# ['knew', 'whole', 'class', 'cri', 'hurt', 'word', ':)']
# ['opportun', 'anyon', 'ask', 'question', 'babe', 'includ', ':)', '4thstreetmus']
# ['lunch', ':)']
# ["i'll", 'hawaii', 'decemb', "we'll", 'kick', 'back', 'miss', ':)']
# ['two', '17', 'year', 'old', 'deepli', 'love', ':-)']
# ['aha', "that'", 'alright', '❤', '️', 'love', ':)']
# ['hope', 'nate', 'notic', 'edit', 'sinc', 'made', 'icon', ':)']
# ['send', 'john@timney.eclipse.co.uk', ':)']
# ['hah', '...', 'thousand', 'lie', ':d']
# ["i'd", 'will', 'tri', ':)']
# ['read', 'newspap', ':d']
# ['afternoon', 'date', '<3', ':)']
# ["here'", 'fan', 'made', 'art', 'u', ':)', 'guy', 'phone', 'lew', 'bend', ':d']
# ['nah', 'beaut', 'way', ':)']
# ['fallout', '4', 'get', 'see', 'glow', 'sea', 'technic', 'fallout', '3', 'play', 'see', ':d']
# ["i'm", 'friend', 'cousin', 'karen', 'gunderson', 'watch', 'europa', 'report', 'thoroughli', 'impress', 'want', 'say', 'great', 'script', ':-)']
# ['dri', 'start', 'wale', 'wait', 'duck', 'overtak', 'motorway', ':-)']
# ['good', 'morn', 'fab', 'friday', ':)']
# ['hahaha', '...', 'thu', '...', 'sneak', 'away', 'log', 'niteflirt', ':d']
# ['yep', "we'r", 'trash', 'af', 'im', 'indonesia', 'hbu', ':-)']
# ['obvious', 'get', 'better', 'tweet', ':-)']
# ['welcom', 'kfcroleplay', 'enjoy', 'let', 'friend', ':)']
# ['bowl', 'alway', 'best', 'friend', ':)']
# ['hope', "i'll", ':)', 'x']
# ['say', 'must', 'chri', 'elli', ':)']
# ['ye', 'friendli', 'contest', 'loser', 'buy', 'drink', ':)']
# ['thank', 'follow', 'great', 'day', ':)']
# ['thank', ':-)']
# ['thank', ':d']
# ['day', 'practic', 'song', ':)']
# ["here'", 'remind', 'need', 'one', ':-)']
# ['harri', 'niall', '94', 'harri', 'born', 'ik', 'stupid', 'wanna', 'chang', ':d']
# ['select', 'other', '..', 'get', ':)']
# ['...', 'play', 'al', 'n', "he'll", 'score', 'fuck', 'night', ':)']
# ['bff', '..', ':)']
# ['hi', "here'", 'vid', 'stydia', 'take', 'look', ':)']
# ['im', 'send', 'alex', 'like', 'million', 'pictur', ':)']
# ['love', ':)']
# ['visit', 'blog', 'thank', ':d']
# ['happi', 'birthday', 'nawazuddin', 'siddiqu', '...', 'big', 'big', 'fan', ':)']
# ['ye', 'pleas', 'would', 'brighten', 'night', 'shift', 'nomnomnom', ':d', 'chocol', 'dukefreebiefriday', 'xx']
# ['done', 'eonni', ':)']
# ['fantast', 'night', ':)']
# [':)']
# ['boom', 'date', ':d', 'z']
# ['follow', 'alreadi', 'thank', ':)']
# ['thank', ':)']
# ['happi', 'end', 'insyaallah', ':)']
# ['that', 'way', 'see', 'west', 'ham', 'shit', 'small', 'club', 'london', 'villa', '3rd', 'biggest', 'brum', ':)']
# ['deni', 'vagina', 'rli', ':d', 'poor', 'thing', ':d']
# ['smile', 'sunnah', ':)', 'غردلي', 'عن']
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear', 'plz', 'let', 'know', 'u', 'think', ':)']
# ['share', 'readi', ':)']
# ['oh', 'white', 'rabbit', 'cutest', 'thing', "i'v", 'ever', 'seen', 'wait', 'ador', ':)']
# ['welcom', ':)', 'love', 'weekend', 'izzi']
# ['happi', 'birthday', 'mitch', ':-)', 'wish', 'best', 'good', 'day']
# ['thank', ':)']
# ['done', 'ya', 'minn', ':)', 'cjradacomateada']
# ['welcom', 'fun', ':)']
# ['recently.websit', 'upgrad', 'might', 'see', 'new', 'pictur', 'coolingtow', 'soon.thank', 'showinginterest', ':)']
# ['flipkartfashionfriday', 'multicolor', 'maxi', 'dress', 'pair', 'wid', 'wedg', 'make', 'ur', 'life', 'bright', 'color', ':)']
# ['alway', 'motiv', ':-)']
# ['nnnnot', 'see', 'upsid', ':-)']
# ['haha', 'kyle', "gf'", 'babi', ':)']
# ['lol', 'ok', 'watch', 'ya', 'bit', ':p']
# ['bluesidemenxix', "i'd", 'love', 'win', 'one', ':)']
# ['happi', 'birthday', ':)']
# ['hello', ':)', 'ardent', 'follow']
# ['goood', 'mooorn', ':)', 'want', 'sleep', '...']
# ['ghost', 'bae', ':d', 'love', 'wuppert', 'tagsforlikesapp', 'instagood', 'smile', 'follow', 'cute', 'photooftheday', '…']
# ['hahaha', 'okay', 'thank', ':)']
# ['lose', ':d']
# ['hehe', 'cool', ':)']
# ['morn', 'u', 'today', 'u', 'got', 'plan', 'lazi', "i'm", 'still', 'bed', 'toast', 'fresh', 'coffe', '2', ':)', 'great', 'fridayfunday']
# ['welcom', 'famili', ':)']
# ['re-sign', ':)']
# ['meet', 'harri', "that'", 'need', 'life', ':-)']
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['one', 'sleep', 'til', 'wed', ':-)']
# ['excit', 'chalkhil', 'park', 'celebr', 'tomorrow', 'midday', 'come', 'join', 'fun', ':-)']
# ['hello', ':)', 'love', 'carter', ':)']
# ['good', 'read', ':)']
# [':-)']
# ['enjoy', 'hope', 'weather', 'hold', 'guy', ':-)']
# ['done', ':)']
# ['remedi', 'media', 'tell', ':-)']
# ['thank', ':)']
# ['jumma', 'mubarak', 'stay', 'bless', ':)']
# ["we'r", 'look', 'forward', 'abl', 'spend', 'time', ':)', 'enjoy', 'iflix', ':)']
# ['tgif', 'weekend', '...', 'enjoy', ':)']
# ['im', 'thank', 'someon', 'like', 'life', 'inspir', 'better', 'everyday', 'love', 'mind', 'follow', ':)']
# ['becom', 'better', 'atrack', 'better', ':)']
# ['first', 'third', 'look', 'promis', 'els', 'fail', 'make', 'decis', 'go', ':)']
# ['crazi', 'girlfriend', 'like', ':-)', '(-:', 'jesu', 'christ']
# ['morn', ':)', 'gd', 'day', 'store', "i'm", 'badminton', '2', "littl'un", 'fabfriday']
# ['kid', 'insid', 'want', 'one', ':-)']
# ['imran', 'khan', 'hero', ':)', 'realli', 'ikprideofpak']
# ['janjua', 'friend', ':)']
# ['sorri', 'fuck', 'eric', 'think', 'he', 'funni', ':)']
# ['say', 'bday', ':)']
# ['hey', ':)', 'check', 'pictur', 'think', ':)', 'notic', 'follow', 'pleas', '💕', 'x']
# [':)', ':)', ':)', 'pimpl', ':)', ':)', ':)', 'forehead', ':)', ':)', 'size', ':)', ':)', ':)', 'volcano', ':)']
# ['good', 'luck', 'coupl', 'get', 'marri', 'weekend', ':)']
# ['back', ':)', 'done', 'na', 'mag', 'miryenda', ':)']
# ['wait', 'bro', ':-)']
# ['parti', '3d', 'printer', ':)', 'celebr', 'futur', "technology'", 'possibl', 'touchétoday', '…']
# ['u', 'use', 'app', 'listen', 'music', 'ye', 'app', ':-)', '—', 'idownload']
# ['get', '25ish', 'snowbal', ':p']
# ['cours', ':)']
# ['nd', 'go', 'expir', 'next', 'year', 'dat', 'mtn', '6gb', 'u', ':d', 'realli', 'like']
# ['happi', 'birthday', 'nice', 'day', ':)', 'loveu']
# ['wanna', 'go', 'back', 'time', 'everyth', 'still', 'fine', ':-)']
# ['celebr', 'life', ':)', 'summer', 'morefuninthephilippin', 'laho', 'island', 'caramoan', 'island']
# ['nice', 'quot', ':)', 'kunoriforceo', 'ceo', '1month']
# ['good', 'stuff', ':)', 'love', 'bit', 'salmon']
# ['jumma', 'kareem', ':)', 'friday', 'remind', 'recit', 'surah', 'kahaf', '..']
# ["i'm", 'join', 'right', ':d']
# ['sure', '..', ':)']
# ['hi', 'melani', ':-)', 'fact', "they'r", 'realli', 'use', 'case', 'normal', 'wifi', 'could', 'issu', 'mention', '...']
# ['quit', 'phenomen', 'offer', 'bosch', 'wash', 'machin', "week'", 'definit', 'last', 'long', ':)']
# ['one', 'ok', "i'll", 'run', 'photo', 'moment', ':d']
# ['thank', 'refollow', ':)']
# ['slept', 'less', '7', 'hour', 'last', 'night', 'prepar', 'possibl', 'nap', ':p']
# ['idk', ':p', 'follow', '😎', '💁🏻']
# ['feel', 'like', 'relaps', ':-)']
# ['girl', 'nice', 'wallet', 'boy', 'prada', 'hai', '..', 'girl', 'rich', '..', 'boy', 'stupid', 'mean', 'bhai', 'ka', 'hai', ':p', 'prada', 'punjabiswillgetit']
# ['☺', 'morn', 'babe', ':)']
# ['lol', 'sorri', 'ultor', 'first', 'hitter', '...', 'favor', 'much', ':)']
# ['finish', 'mass', 'effect', '1', 'yesterday', 'dont', 'know', 'shoud', 'start', 'mass', 'effect', '2', '100', 'game', ':)']
# ['bad', 'would', 'remind', 'exercis', '1:12', ':-)', 'miss', 'need', 'come', 'back']
# ['add', 'kik', 'ughtm', '545', 'kik', 'kikmeguy', 'kissm', 'nude', 'likeforfollow', 'musicbiz', 'sexysasunday', ':)']
# ['overwhelm', 'groupmat', 'thank', 'group', 'got', '1', '75', 'recit', ':)']
# ['ha', 'mistak', 'thank', 'point', ':)']
# ['kyunk', 'aitchison', 'hai', ':p', 'look', 'respons', 'origin', 'tweet', 'know', 'brother']
# ['snapchat', 'sexyjudi', '19', 'snapchat', 'kikmeboy', 'tagsforlik', 'pussi', 'gay', 'indiemus', 'sexo', ':)']
# ["that'", 'true', 'inde', 'curvi', 'rout', ':)']
# ['come', 'chill', 'fire', ':)']
# ['mont', 'doa', 'header', ':d']
# ['haha', 'x', ':d']
# ['ted', 'speaker', 'say', 'stress', 'good', 'bodi', 'anoth', 'speaker', 'introduc', 'way', 'avoid', 'stress', ':)', 'ted', 'thought', 'laboratori', ':)']
# ['thing', 'note', 'awesom', ':-)']
# ['might', 'lose', 'friend', 'today', 'know', 'idc', ':)']
# ['good', 'morn', ':d', 'lol', 'realli', 'fuckin', 'dark', 'gonna', 'rain', 'hard', 'coupl', 'minut']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['ff', 'amaz', 'singer', 'actress', 'model', ':-)']
# ['happi', 'birthday', 'see', 'tonight', ':)']
# ["i'm", 'amsterdam', 'guy', 'wooo', ':d']
# ['stuff', 'happen', ':)']
# ['friend', ':)']
# ['neobyt', ':)', 'univers', 'pictur', 'seed', 'pirat', 'movi', 'copi', 'file', 'takedown', 'notic']
# ['2', 'indirag', 'want', 'judiciari', 'commit', 'govt', 'polici', 'want', 'rbi', 'commit', 'know', 'mani', 'similar', 'view', ':)']
# ["thought'", 'kepler', '452b', ':d']
# ['progress', 'stone', 'transfer', 'chelsea', ':d']
# ['gg', 'bro', ':)', 'fun', 'seri']
# ['alway', 'part', 'part', 'defenit', '...', '♬', ':p']
# ['cours', 'man', ':)', 'nofx', 'shit']
# ['friskyfiday', 'yipee', ':)', 'x']
# ['morn', 'kim', 'sorri', 'hear', 'shed', 'light', 'issu', 'look', ':)', 'helen']
# ['great', 'incent', 'get', 'kid', 'eat', 'fruit', 'vege', ':-)']
# ['welcom', 'sir', ':)']
# ['know', 'averag', 'take', '6', 'second', 'read', 'god', 'dam', 'mother', 'fuck', 'tweet', ':)']
# ['thank', 'favourit', 'tweet', 'marin', ':)']
# ['get', 'close', "can't", 'wait', 'new', 'season', ':)']
# ['gz', ':d', 'name']
# ['morn', 'day', ':-)']
# ['guess', 'sleep', 'list', 'thing', 'today', ':-)']
# ['hai', 'rajeev', '..', 'hope', 'u', 'r', 'hvng', 'funfil', 'friday.it', 'ws', 'reali', 'amaz', 'c', 'diff', 'side', 'kabir.fel', 'luv', 'u', ':)', 'smile', 'pl']
# ['prettier', ':)', 'mine', ':)']
# ['happi', 'birthday', 'best', 'wish', 'dresden', 'germani', ':)', 'love', '<3', '<3', '<3', '<3', 'pleas', 'share']
# ['wanna', 'loser', 'like', ':)', '♥']
# ['zayn', 'pleas', 'follow', 'would', 'mean', 'world', 'birthday', ':d', 'love', 'much', 'amaz', '<3']
# ['congratul', 'friend', 'graduat', 'lose', 'plot', ':d']
# ['0', 'sleep', 'offici', 'way', 'pari', 'cannot', 'wait', ':)', 'pari', 'tdf', '2015', '🇫🇷', '🍷', '🍸', '☀', '️', '🇫🇷', '🚲', '🇫🇷', '🍷', '🍸', '☀', '️', '🚲']
# ['put', 'trust', ':)']
# ['hey', 'good', 'suggest', 'guy', 'make', 'minion', 'slot', 'would', 'fun', 'cute', ':)']
# ['happi', "b'day", ':)']
# ['hah', '...', 'thousand', 'lie', ':d']
# ['wow', 'look', 'good', 'isabella', 'make', 'wanna', 'start', 'work', 'back', ':d']
# ['go', 'room', 'bc', '3', ':-)']
# ['okeyyy', 'vddd', ':)', ');', 'excit', "can't", 'wait', '...', 'love', 'selfee', 'pic', 'insta', ':)', '♥', '♥', 'special', 'coco', '..', '🙆', '🙌', '😛', '😄', '😄', '😁', '😂', '😂', '🐒', '😁', '😝', '❤', 'dishoom']
# ['think', 'write', ':)']
# ['final', 'went', 'drive', 'tonight', ':-)']
# ['thank', 'follow', 'great', 'day', ':)']
# ['im', 'go', 'sleep', 'goodnight', ':)']
# ['hello', ':)']
# ['yup', 'know', 'okay', 'let', 'tri', ':)', 'done', 'hhahhaaa', '—', 'haha']
# ["i'm", 'suppos', 'ask', 'buy', 'album', ':)']
# ['6', 'day', 'go', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['least', "there'", 'one', 'cool', 'thing', ':-)']
# ['hey', 'guy', "that'", 'new', 'page', ':)', 'enjoy']
# ['jeez', 'tara', 'move', 'teamcannib', 'vs', 'teamspacewhalingisthebest', ':p']
# ['morn', 'gym', 'session', 'done', 'feel', 'good', 'workout', 'earli', '...', 'enjoy', 'rest', 'day', ':)', 'friyay', 'workout', 'fitfa', '…']
# ['guess', 'never', 'realli', 'identifi', 'pharmaci', ':)', 'verylaterealis', 'iwishiknewbett']
# ['yeah', 'know', 'lack', 'thing', 'hey', 'pleas', 'check', 'final', 'design', 'satisfi', 'enough', ':)']
# ['wow', 'nice', 'combin', ':)']
# ['charg', 'speaker', 'final', 'got', 'earlier', 'today', ':)']
# [':)', 'masaantoday']
# ['later', 'turn', ':d']
# ['text', 'wanna', 'meet', "i'll", 'get', ':)']
# ['long', ':)']
# ['friend', 'never', 'talk', 'ess-aych-eye-te', 'anyon', ':)']
# ['ya', 'thank', ':)', '😊']
# ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['yeah', 'left', 'one', 'supposedli', 'hurt', 'bc', 'right', 'heart', 'appar', "it'll", 'fine', 'good', 'luck', ':)']
# ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# ['ahh', 'thank', 'u', ':d']
# ['niall', 'follow', 'fan', ':)', "i'm", 'still', 'without', 'follow', '👍']
# ['sister', 'best', 'best', 'pre', 'bday', 'celebr', ':)']
# ['among', 'time', 'fav', 'tweet', ':d']
# ['happi', 'birthday', 'g', 'best', 'life', ':)']
# ['need', 'stress', 'time', ':)']
# ['immedi', 'plan', 'hope', 'someday', 'futur', ':)']
# ['could', 'make', "foxy'", 'song', 'version', 'instrument', 'form', 'sound', 'epic', 'beat', 'alon', ':)']
# ['second', 'well', 'done', ':)']
# ['think', 'hard', 'bed', ':p']
# ['tomorrow', 'goldcoast', ':)']
# ['like', 'way', 'said', 'gal', 'lelomustfal', 'beautiful', 'way', ':)']
# ['happi', 'save', 'day', ':)', 'hope', 'enjoy', 'meal', 'sam']
# ['thank', 'min', ':)']
# ['5g', 'liker', ':)', 'like', 'fast']
# ['like', 'morn', 'got', 'dress', 'bought', ':)', "i'm", 'total', 'love', '♡', 'newdress', 'happi', '…']
# ['ff', 'could', 'anyon', 'resist', 'beauti', 'smile', ':-)', 'quacketyquack']
# ['u', 'mean', 'hide', 'fot', ':p']
# ['aww', 'thankyou', ':)']
# ['ok', 'good', 'night', 'wish', 'troy', 'ugli', 'met', 'today', ':)', '):', 'ok', 'today', 'fun', "i'm", 'excit', 'tmrw']
# ['inde', ':-)']
# [':)', 'good', 'afternoon', ':d', 'twitterfollowerswhatsup', 'happyfriedday', 'keepsafealway', 'loveyeah', 'emojasp_her']
# ['okay', ':)']
# ['make', 'two', 'us', ':d']
# ['hurt', 'read', "people'", 'holiday', 'work', ':d']
# ['nice', 'hear', 'want', 'switch', 'us', ':)', 'pro', 'kit', 'would', 'best', 'choic', 'follow', 'link']
# ['beauti', '...', 'winter', 'like', 'summer', 'russia', ':)']
# ['thought', '’', 'like', 'mate', ':)']
# ["i'm", 'play', 'brain', 'dot', 'braindot']
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418981	b"i'm play brain dot braindot"
# ['stat', 'week', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# ['dm', ':p']
# ['also', 'come', 'game', ':)']
# ['thank', ':)']
# [':)', 'hope', 'enjoy']
# ['ok', 'first', 'time', 'chat', 'made', 'joke', 'lol', 'believ', 'wont', 'forget', 'u', ':)', 'name']
# ['mymonsoonstori', 'bodi', 'shop', 'bodi', 'mist', 'vanilla', 'work', 'wonder', 'skin', ':)']
# [':)', 'best', 'youtub', '...', 'keep', 'good', 'work', 'man', 'starsquad', 'sidemen']
# ['yaaayyy', 'best', 'friendaaa', 'shout', 'like', 'minion', ':)']
# ['thank', 'ad', 'us', 'list', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# ['1tbps4', 'wow', 'prize', 'delight', 'eye', 'pick', 'win', 'burst', 'sing', 'ps4', 'mine', 'feel', 'divin', ':)']
# ['bath', ':)', 'even', '’', 'wheeli', 'bin', 'nowher', 'put']
# ['get', 'readi', '...', 'ubericecream', 'messengerforaday', ':)']
# ['yeap', ':)']
# ['must', 'watch', ':d', 'bajrangibhaijaanhighestweek', '1']
# ['cool', '...', 'congrat', 'kyli', 'u', 'look', 'nice', ':-)']
# ['thought', 'work', 'season', 'realli', 'busi', 'day', 'ok', 'deal', 'weekend', 'toilet', 'break', ':p']
# ['daddi', 'af', '...', ':-)']
# ['latest', 'one', ':)']
# ['happi', 'make', ':)']
# ['far', 'good', 'ikaw', 'musta', 'cheatmat', ':)']
# ['e', 'l', 'f', 'thank', 'singer', ':)', 'kyuhyun', 'thank', 'e', 'l', 'f']
# ['20', 'ghanton', 'se', 'light', 'nahi', ':)']
# ['one', 'last', 'long', 'lol', 'block', 'alreadi', 'must', 'nice', 'tweet', 'hate', ':)']
# ['ur', 'skin', 'think', 'ur', 'still', '16', 'decid', 'break', ':-)', 'cool']
# ['easy.get', '5:30', 'go', 'work', 'come', 'home', 'bout', '6', 'take', 'care', 'home', 'famili', 'therein', "that'", 'see', ':-)']
# ['thank', 'majalah', 'juli', 'issu', ':)', 'love', '👍🏼', '👍🏼', '👍🏼', '😍', '😍', '😍', '🌸', '🌸', '🌸']
# ['piti', 'parti', ':-)']
# ['tgif', 'unless', 'one', 'student', ':)', 'light', 'read', 'singapor', 'hero', 'gp', 'essay', 'alevel']
# ['dominiqu', "i'm", 'biggest', 'fan', 'like', 'oh', "i'm", 'england', 'get', 'fan', 'sign', ':)']
# ['good', 'caus', "i'd", 'like', 'upload', ':)']
# ['goood', 'mornin', 'earthl', ':d']
# ['happi', 'tweet', 'like', 'new', 'build', ':)', 'mm']
# ['okay', 'yay', 'ask', 'tomorrow', 'pleas', ':)']
# ['alway', ':)', 'posit']
# ['lamp', 'shop', ':)']
# ['word', 'big', 'site', 'got', 'chang', 'a-foot', ':)', 'websit', 'develop', 'revamp']
# ['vote', 'brainchild', '3', 'time', 'pleas', 'may', 'poem', ':d']
# ['confid', 'confin', 'u', 'ur', 'limit', '...', ':)']
# ['wish', 'colorado', ':)']
# ['happi', 'friday', 'folk', 'order', 'goodyear', 'tyre', 'onlin', 'get', 'upto', '£', '40', 'cashback', 'cs', 'appli', 'yourewelcom', ':)']
# ['nightli', 'routin', 'simpin', ':-)']
# ['add', 'snapchat', 'yall', ':)', 'give', 'name']
# ["i'm", 'look', 'influenc', 'app', ':)', 'interest', "here'", 'invit']
# ['sketchbook', 'art', 'love', '4wild', 'draw', 'hair', 'turn', 'pretti', 'cool', ':d', 'art', 'hair', 'color', 'colorpencil', 'cray', '…']
# ['tune', 'back', 'hubbi', ':)', 'u', 'play', 'queen', 'pl']
# ['fell', 'asleep', 'like', '6:30', "can't", 'fall', 'asleep', 'two', 'hour', ':-)']
# ['great', 'night', 'great', 'peopl', ':)']
# ['imma', 'use', 'next', 'time', ':)']
# ['ob', '11h', 'v', 'kino', ':)']
# ['gone', 'make', 'tho', 'posit', 'day', ':)', 'adult', "can't", 'keep', 'act', 'like', 'mom', '..']
# ['hi', 'see', 'u', 'like', 'fourfivesecond', 'think', 'u', 'might', 'like', 'deaf', 'ear', 'plz', 'let', 'know', 'u', 'think', ':)']
# ['great', 'went', 'kardamena', 'last', 'summer', 'amaz', 'beach', 'wonder', 'sea', 'year', 'time', 'go', 'samo', 'greec', ':)', ':)']
# ['chicken', 'caesar', 'salad', 'tad', 'bland', 'live', ':)']
# ['love', 'afraid', 'respond', 'hate', ':)', 'ili', 'x', 'x', 'x']
# ['first', 'leg', 'tour', 'go', 'well', ':d', 'music', 'band', 'rock', 'magictrik', 'tour']
# ['okk', 'den', 'call', 'abp', 'n', 'spread', 'allov', 'india', 'n', 'abroad', 'well', ':p']
# ['thank', 'much', ':)']
# ['pleas', 'let', 'us', 'know', 'store', 'abl', 'visit', 'may', 'inform', 'expect', ':)']
# ['tweet', 'much', 'appreci', 'thank', 'dedic', 'member', ':)']
# ['freedom', 'hangout', 'whoever', 'want', ':)']
# ["i'm", 'like', ':)']
# ['hi', ':-)', 'look', 'tourist', 'info', 'get', 'applic', 'zonzofox', 'click', 'link', 'bye', ';-)']
# ['leo', 'season', ':-)', '♌', '️']
# ['life', 'kutiyapanti', ':d', 'love', 'life', ':d']
# ['thank', 'support', ':)', 'kunoriforceo', 'ceo', '1month']
# ['profession', 'hit', 'video', 'wick', 'boomshot', 'fuh', 'di', 'world', 'even', 'thank', ':)']
# ['yeeey', 'welcom', 'club', 'one', 'half', 'year', 'whatsapp', '..', 'donot', 'regret', '..', ':)']
# ['problem', ':)', 'pleasur', '❤', '️']
# ['send', 'one', 'pleas', ':)', 'wont', 'expos', 'roast', '<3']
# ['lemm', 'cover', 'u', 'lipstick', 'n', 'cran', 'vodka', ':-)']
# ['road', 'trip', ':d']
# ['alway', 'walk', 'past', 'place', 'may', 'go', 'tri', ':d']
# ['yeah', "i'v", 'lost', 'call', 'day', ':)']
# ['jummah', 'mubarak', 'rememb', 'prayr', ':)']
# ['member', 'හෙල', 'හවුල', 'chanc', ':d']
# ['miss', 'babi', ':)', 'onemochaonelov']
# ['yo', 'southpaw', 'great', 'movi', 'someon', 'better', 'get', 'award', ':d']
# ['music', 'human', 'geniu', 'stroma', ':)']
# ['🔴', 'live', 'younow', 'jonah', 'jareddd', ':)']
# ['messag', 'full', 'name', 'b', 'address', 'postcod', 'talkmobil', 'phone', 'number', 'thank', ':)']
# ['last', 'class', 'morn', 'two', 'week', 'break', ':-)']
# ['happi', 'happi', 'birthday', 'emili', ':d']
# ['elf', 'fight', 'huha', ':d', ':)', 'teenchoic', 'choiceinternationalartist', 'superjunior']
# ['may', 'find', 'confus', ':)', 'simpl', 'wolf']
# ['nice', 'pic', ':)']
# ['promot', ':)']
# ['yeah', 'bird', 'transform', 'sword', ':d']
# ['even', 'real', 'word', ':d']
# ['could', 'misread', 'wors', 'thing', ':p']
# ['forward', 'richard', '...', 'follow', ':)']
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via']
# ['yup', 'happen', 'everywher', 'peopl', 'cant', 'debat', 'come', 'name', 'call', ':-)']
# ['need', 'get', 'work', 'today', 'ibiza', ':)', ':)', ':)', 'birthdaymoneyforjesusjuic']
# ['anytim', ':)']
# ['mistak', 'happen', 'man', 'long', 'get', 'play', 'game', "we'll", 'happi', ':)']
# ['hey', 'wanna', 'check', 'ytb', 'channel', 'post', 'gameplay', 'tutori', ':)', 'via']
# ['one', 'construct', 'critic', 'welcom', ':)', 'ganesha', 'textur', 'photographi', 'art', 'hinduism', 'hindugod', 'elephantgod']
# ['ye', 'alway', 'selfish', 'fuck', ':)']
# ['hey', 'like', 'fnaf', 'check', 'youtub', 'channel', ':)', 'via']
# ['want', 'creat', 'first', 'bboy', 'cardgam', 'pixelart', 'gamedesign', ':d', 'think', 'indiedev', 'pixel_daili', 'gamedev']
# ['sound', 'still', 'like', 'good', 'idea', ':)']
# ['limit', 'plateau', 'must', 'stay', 'must', 'go', 'beyond', ':)', 'bruce', 'lee']
# ['man', 'sing', 'rain', ':)']
# ['laguna', ':)', 'see']
# [':)', 'time', 'nhi', 'tha', 'offic', 'work', 'bahot', 'tha', '10', 'baje', 'raat', 'ko', 'liya', 'tha', 'hath', 'tri', 'creat', 'best', '2', 'ghant', 'itna', 'hi', 'bana', 'paya']
# ["that'", 'true', 'quit', 'whenev', 'want', ':d']
# ['thank', ':)', 'weekend', 'tri', 'best', ':)']
# ['u', 'like', 'uta', 'read', 'manga', ':-)', 'love', 'even', ':-)', 'haha', 'yeah']
# ['famili', 'hang', ':)', '—', 'feel', 'festiv', 'jamuna', 'futur', 'park']
# ['move', 'forward', 'happi', 'spirit', 'find', 'thing', 'alway', 'work', '\\:']
# ['rememb', 'sent', 'present', 'last', 'christma', 'dub', 'swiftma', ':)']
# ['miss', ':-)']
# ['super', 'proud', ':)']
# ['love', 'pic', 'fab', 'show', ':-)', 'x']
# ['morn', ':)']
# ['tha', 'case', 'trion', 'interact', 'forum', 'twitch', ':)']
# ["that'", 'spirit', ':)', 'wsalelov']
# ['sort', 'earli', 'hour', 'thank', 'help', 'rais', 'initi', 'issu', 'make', 'commun', ':)']
# ['hii', 'follow', 'pleas', "i'd", 'like', 'ask', 'one', 'thing', 'dm', ':)', '💞']
# ['happi', 'b-day', ':)']
# ["that'", 'disgust', 'glad', 'acc', 'back', ':)', 'hope', 'get', 'deserv']
# ['back', '80', 'brand', 'new', 'commodor', '64', 'program', 'commun', 'town', ':)', '12th', 'august']
# ['okay', ':)']
# ['im', 'wear', 'mine', 'dj', 'next', 'fri', ':-)']
# ['thank', 'take', 'time', 'tweet', 'us', 'annabel', "we'll", 'pass', 'london', 'bridg', 'team', ':)']
# ['alreadi', ':)']
# ['everi', 'way', 'like', 'jess', ':)']
# ['happi', 'friday', ':)']
# ['short', 'routin', 'quest', 'borderland', ':)', 'wanderrook']
# ['thank', 'made', 'day', ':)', "let'", 'organis', 'meet', 'soon', 'base', 'london']
# ["i'm", 'person', 'workout', 'eat', 'healthi', 'minut', 'gain', 'weight', ':-)']
# ['gm', 'meet', 'preciou', 'soft', 'ladi', 'real', 'friend', 'mizz', 'preciou', ':)', ';)', 'mani', 'like', '...']
# ['aameen', '..', ':)', 'long', 'live', 'pakistan', '..', 'bleedgreen', '..', '✌🏻', '️']
# ['alreadi', 'follow', 'back', 'oppa', ':)']
# ['liam', 'sophia', 'chicago', ':)', '♥']
# ['btw', 'honeymoon', ':)']
# ['yeah', 'bring', 'boom', "da'esh", 'co-ord', 'fsa', 'estat', ':)']
# ['welcom', ':)', "when'", 'next', 'meet']
# ['singer', 'dusti', 'tunisia', '<3', 'music', 'tunisia', '<3', 'wonder', 'nice', 'peopl', ':-)', '<3', 'youtub', '...']
# ['la', "class'", ':p']
# ['hahaha', 'go', 'doug', ':-)']
# ['forgot', 'ask', 'may', 'post', 'fb', 'happi', 'friday', ':-)']
# ['visit', 'blog', 'thank', ':d']
# ['everyon', 'fuckin', 'irrit', ':)']
# ['also', 'mean', 'imma', 'go', 'back', 'twitter', 'activ', ':d', 'caus', 'know', 'everyon', 'miss', ';)', 'xd']
# ['hello', 'ladi', 'apolog', 'delay', 'pleas', 'dm', 'us', 'address', 'size', 'detail', "we'll", 'ship', 'prize', ':)']
# ['free', 'voucher', 'twitter', 'friend', 'use', 'fiverr', ':)']
# ['oh', 'gina', 'busi', ':-)', "can't", 'wait', 'see', 'hear', 'xxx', 'soproud']
# ['happi', 'friday', 'everyon', 'hope', 'fantast', 'week', ':)', 'friday']
# ['ye', 'one', 'team', ':)']
# ['happi', 'belat', 'birthday', 'sweeti', ':)']
# ['morn', 'emma', ':)']
# ['thank', 'guy', ':)']
# ['would', 'say', ':-)']
# ['love', 'make', 'two', 'heart', 'one', ':)']
# ['thank', 'ad', 'us', 'list', ':)', 'make', 'sure', 'keep', 'touch', 'news', 'light', 'bulb', 'made', 'corn', 'wast']
# ['thank', 'mr', 'bee', 'xxx', ':-)']
# ['thankyou', ':)']
# ['close', 'enought', ':)']
# ['good', 'luck', '...', 'anoth', 'potenti', 'favourit', 'water', 'hole', ':-)']
# ['bad', 'boy', ':)', 'burger', 'melbourneburg']
# ['want', 'ft', 'arianna', ':-)']
# ['everyon', 'follow', ':)']
# ['hey', 'lesley', 'sorri', 'get', 'shall', 'send', 'post', 'tonight', ':)']
# ['thank', 'esai', ':-)']
# ['thank', 'text', 'back', ':)', "i'm", 'text', 'tomorrow', ':)']
# ['unfollow', 'back', ':)']
# ['hope', 'enjoy', 'stay', 'rotterdam', 'know', 'cheer', 'jordi', 'clasi', ':)']
# ['hi', 'hot', 'girl', 'say', 'hot', 'horni', 'darl', 'xx', ':)', '♥']
# ['sure', 'done', ':)']
# ['salon', 'bleach', 'hair', 'olaplex', 'damag', 'like', ':)']
# ['teamwork', 'right', ':d', 'zitecofficestori']
# ['ff', 'happyfriday', 'great', 'friday', ':-)']
# ['sure', ':)']
# ['다쇼', 'got', '7', "let'", 'got', '7', 'fact', ':)']
# ['still', 'tomorrow', 'work', 'colleagu', 'interest', 'bring', 'kid', 'along', ':)', 'point', 'eb', 'page']
# ['tack', '<3', ':d']
# ["t'would", 'tweetup', 'without', 'book', 'rest', 'assur', 'book', ':)']
# ['thank', 'much', 'know', 'greatest', 'magic', 'detect', 'jonathancreek', 'back', 'tv', 'set', 'dvr', ':)']
# ['get', 'home', '4', 'wake', '9', ':)', ':)']
# ['thank', 'take', 'time', 'tweet', 'kat', ':)']
# ['lot', 'rarer', 'life', 'twitter', ':)']
# ['okkk', 'frend', 'milt', 'h', 'break', 'k', 'bad', ':)']
# ['could', 'fun', 'sexi', 'girl', 'two', 'sexi', 'girl', ':)', '👉', '👈', '😘']
# ['..', 'thank', 'mario', '...', 'wonder', 'friday', '...', ':)']
# ['fun', 'daniel', 'hope', 'goe', 'well', ':-)']
# ['thank', 'hope', 'got', 'good', 'book', 'keep', 'compani', ':-)']
# ['yeah', "i'v", 'watch', 'cours', 'rewatch', 'ad', 'free', 'faster', 'hope', ':)', 'thank', 'look', 'forward']
# ['price', 'around', '1600', "i'm", 'gonna', 'forward', 'info', 'email', 'decid', 'interest', ':)']
# ['got', 'bed', 'yet', ':-)']
# ['awww', 'sige', 'next', 'time', 'u', 'know', 'na', 'punta', 'kayo', 'dun', 'imma', 'make', 'sure', 'na', "we'll", 'go', 'din', ':-)']
# ['sure', 'thing', ':)', 'x']
# ['...', 'friday', ':d']
# ['cours', 'would', 'like', ':)', 'x']
# ['nooo', 'didnt', 'even', 'know', 'that', 'actual', 'type', 'googl', ':)']
# ['found', 'prompt', ':-)']
# ['chillin', 'w', 'salmon', ':)']
# ['see', 'beauti', 'believ', 'exist', 'first', ':)']
# ['hi', 'j', 'upgrad', 't-mobil', 'orang', 'ee', 'us', 'dm', 'mobil', 'number', "i'll", 'ask', 'sale', 'call', ':)']
# ['congratul', 'realli', 'look', 'forward', 'book', 'good', 'sunday', 'morn', 'view', "that'", 'awesom', 'teapot', 'btw', ':-)', 'x']
# ['three', 'refresh', 'cocktail', 'even', '«', 'hotter', '»', 'summer', 'one', 'suit', ':)', 'londoutrad', 'cocktail']
# ['love', ':)', '<3']
# ['wip', 'let', 'get', 'thing', 'tweak', "i'll", 'link', ':)', 'max', 'kal', 'tak']
# ['fab', 'giveaway', ':)']
# ['case', '..', 'facebook', 'wall', ':p']
# ['stat', 'week', 'arriv', '3', 'new', 'follow', 'unfollow', ':)', 'via']
# ['home', 'alon', ':d']
# ['wish', 'happi', 'birthday', 'awesom', 'fun', 'fill', 'day', ':d']
# ['let', 'know', 'hear', 'anyth', ':)', 'xx']
# ['wayward', 'pine', 'later', ':)']
# ['yeah', 'better', 'use', 'offici', 'account', ':)', 'like', '❤', '️']
# ['rock', 'muscl', ':d', 'ilikeit']
# ['far', 'lfc', 'fan', 'make', 'expert', 'spot', 'mental', 'weak', 'lack', 'consist', ':-)']
# ['check', 'page', 'belong', 'one', 'watford', 'commun', 'hous', 'trust', 'enterpris', 'cube', 'particp', ':-)', '...']
# ['follow', 'back', 'pleass', ':)']
# ['omg', 'that', 'sweet', 'thing', 'say', 'thank', ':-)', 'yeah', 'use', 'go', 'saudi', 'arabia', 'lot', 'dad']
# ['ty', 'followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# ['good', 'luck', 'ur', 'exam', ':)']
# ['one', 'approv', 'recogn', 'fanbas', 'bailona', ':)']
# ['nice', 'see', 'peopl', 'chang', 'need', 'fix', 'care', ':)']
# ['happi', 'responsibilti', 'ask', 'other', 'make', 'happi', ':)', 'fb']
# ['park', 'get', 'sunlight']
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49636406	b'park get sunlight'
# ['happi', ':)', '<3']
# ['good', 'night', 'tiger', 'sweet', 'furri', 'dream', 'xxoo']
# ['nice', 'one', ':)']
# ['want', 'elev', 'posit', 'want', 'promot', 'want', 'favor', 'god', 'favor', 'men', '...', ':)']
# ["i'm", 'insecur', 'tonight', ':-)']
# ['<3', 'guy', ':)']
# ['dan', 'god', 'bless', 'meet', 'greet', 'soon', ':)']
# ['mom', ':)', 'horror', 'movi']
# ['oh', 'hell', 'yeah', ':)', "i'll", 'expect', 'text', 'next', 'tuesday']
# ['welcom', 'sabah', ':-)']
# ['match', 'day', 'bitchesss', 'real', 'madrid', 'vs', 'man', 'shitti', ':d']
# ['squash', 'commit', 'still', 'make', '200', 'commit', ':)']
# ['west', 'countri', 'weekend', 'next', 'ride', 'day', 'tuesday', ':)', 'sunni', 'weekend', 'around']
# ['ourdaughtersourprid', 'mani', 'mani', 'congratul', 'papa', 'ji', ':)']
# ['thank', 'becca', ':)']
# ['love', 'new', 'song', 'delta', 'rock', ':)']
# ['saw', 'thought', 'might', 'need', 'upgrad', 'girl', 'get', 'bigger', ':)']
# ['first', 'love', 'wanna', 'fuck', 'late', 'night', 'think', 'got', 'nut', ':-)', 'v', 'look', '...']
# ['enjoy', 'cute', 'babi', 'panda', ':)']
# ['done', 'yun', ':)']
# ['watch', 'joe', 'dirt', '2', ':)']
# ['ohh', 'happyfriday', 'thank', 'love', 'team', ':)']
# ['alway', 'posit', ':)', 'postiv', 'selfi']
# ['good', 'morn', 'sharon', 'realli', 'hope', 'better', 'today', 'medicin', 'work', 'thank', ':)', 'ttyl', 'x']
# ['oh', 'fab', 'gav', 'love', 'love', 'ladi', 'linda', 'talk', 'time', 'great', 'actress', ':d', 'x']
# ['follback', ':d']
# ['answer', 'super', 'sonic', 'fast', ':)', 'would', 'love', 'win', 'first', 'time', ';)', 'gohf']
# ['3hr', '..', ':)', 'tym', 'prepar']
# ['dieback', 'music', 'pack', 'total', 'worth', 'awesom', ':)', 'dota', '2']
# ['morn', ':)']
# ['think', 'might', 'endit', 'london', 'photo', 'vid', 'minecon', 'london', 'video', ':)', 'look', 'rememb', 'great', 'time']
# ['ok', '...', 'sere', '2', 'play', 'yah', 'min', '..', 'haha', ':)']
# ['joerin', 'scene', ':)', 'joshan', 'power', 'tandem']
# [':d', "can't", 'sleep', 'need', 'tri', 'lay', 'bed', 'bore']
# ['stat', 'day', 'arriv', '6', 'new', 'follow', 'unfollow', ':)', 'via']
# ['b', 'call', 'friend', 'need', ':)', '...']
# ['hello', 'ligao', 'citi', 'albay', ':-)', 'concert', 'bcyc', 'lnh']
# ['goodnight', 'love', 'luke', 'heart', ':-)', 'love', '💜']
# ['happi', 'birthday', 'enjoy', 'vacat', ':)']
# ['congratul', 'sat', '3rd', 'honorari', 'degre', 'everyon', 'alac', ':)']
# ['hey', 'raspberri', 'island', 'skelo_ghost', ':)', 'want', 'get', 'iph', '0ne', '6', 'free', 'kindli', 'check', 'bi0', 'thx']
# ['thank', 'u', ':)']
# ['thank', 'great', ':)', '❤', '️', '😘']
# ['deserv', 'madadagdagan', 'pa', 'yan', ':-)', 'congrat', ':-)', 'bmc', '<3']
# ['save', 'money', 'use', 'good', 'way', 'money', 'money', 'better', 'life', 'fun', ':)', 'nice', 'day', '11:11']
# ['u', 'find', 'ur', 'friend', 'ditch', 'u', 'caus', 'lot', 'thing', ':)', 'wtf', 'done', 'im', 'actual', 'nice', 'person']
# ['order', 'dress', '..', ':)', ':)']
# ['like', 'eye', ':d']
# ...
# ['peopl', 'usual', 'stay', 'asleep', 'wtf', ':(']
# ['cheer', ':-(']
# ['payback', 'like', 'video', 'tri', 'help', 'get', 'kit', 'kat', ':(']
# ["i'm", 'even', 'tire', ':-(']
# ['one', 'come', 'smoke', ':(']
# ['87000', 'jobe', 'deliveri', 'pl', ':(']
# ['happi', 'birthday', 'be', 'enjoy', 'day', 'beb', 'love', 'miss', 'sooo', 'muchi', ':(', 'see', 'soon', 'sana', '💞', '🎈', '🎂', '🎉', '😘']
# ['cuti', ':(']
# ['alway', 'fall', 'asleep', 'earli', "i'm", 'text', 'someon', ':(']
# ['say', 'icecream', 'avail', ':(']
# ['ask', 'go', 'bathroom', ':-(', "i'm", 'realli', 'enjoy', 'show', 'though']
# ['lagg', 'much', 'certain', 'peopl', ':(']
# ['need', 'clear', 'head', ':(']
# ['babi', 'went', 'back', 'sleep', "i'm", 'bore', ':-(']
# ['ughh', 'got', 'noth', 'pain', ':(']
# ['laper', 'banget', ':(']
# ['naw', ':(', 'deep', 'dream', 'novel', 'hope', "there'd", 'invis', 'page', 'beast', 'scuttl', 'around', "there'", 'worm', 'track']
# ['bauuukkk', ':(']
# ['bad', 'guy', 'cant', 'attend', "today'", 'music', 'bank', ':(']
# ['worri', ':-(']
# ['“', 'mine', '...', 'damnnn', 'finee', 'omaigoshhh', ':(']
# ['care', 'muslim', ':(']
# [':(']
# ['jessica', 'call', 'quit', 'power', 'ab', '5:15', ':-(']
# ['lost', 'us', 'friend', '...', ':(', 'one', 'start', 'argument']
# ['hope', 'fun', 'vidcon', 'rlli', 'bum', 'couldnt', 'go', ':(', 'love', 'sunshin', '💛', '💛', '💛']
# ['yepp', '..', "i'm", 'get', 'bore', ':(']
# ['last', 'night', 'good', ':(', '😺', '💒', '💎', '🎉']
# ['follow', ':(']
# ['feelin', 'sick', ':(']
# ['want', 'biscuit', 'slather', 'chocol', 'definit', 'tax', 'boo', ':(']
# ['investig', 'answer', 'especi', 'pup', 'die', 'within', 'free', 'insur', 'period', ':(']
# ['jsut', 'end', ':(']
# ['heart', 'hurt', 'real', 'bad', ':(']
# ['aw', ':(']
# ['follow', 'pl', ':(']
# ["i'm", 'realist', '...', ':(']
# ['belov', 'grandmoth']
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'
# ['happi', 'princess', 'today', ':(', 'sigh', 'get', 'work', 'done', 'x', 'purpl', 'princess', 'edit']
# ['babee', ':(', 'demn', 'hotaisndonwyvauwjoqhsjsnaihsuswtf']
# ['someth', 'wrong', ':(']
# ['word', 'explain', 'way', 'miss', ':(']
# ['think', 'need', '2', 'year', 'train', 'beat', 'record', 'sia', ':(']
# ['niram', 'ya', 'geng', ':(', 'fikri', 'anna', '6', 'other', 'tirtagangga', 'hotel', '—']
# ['char', 'im', 'realli', 'sick', ':(', 'one', 'font', 'size', '8', 'minion', 'float', 'font', 'size', '12', 'sick', 'kid', 'pl', ':(']
# ['bestfriend', 'like', 'ed', 'plsss', ':(']
# ['riprishikeshwari', 'soul', 'rest', 'peac', ':(']
# [':(', 'unfollow', 'like', '300', 'peopl', 'caus', 'follow', '1k', 'peopl', 'difficult']
# ['enough', 'time', 'listen', 'artist', 'music', ':-(']
# ['take', 'ice', 'creamist', 'pleasee', ':(']
# ['alway', 'go', 'terribl', 'time', ':(']
# [':-(', 'challeng', 'though', 'pleas', 'check', 'fb', 'page', 'entri', 'rather', 'substitut', 'thank']
# ["can't", 'even', 'see', 'hyungwon', ':(']
# ['tell', 'pl', 'eat', ':-(']
# ['that', 'life', 'get', 'call', 'peopl', 'havent', 'seen', '20', 'year', 'alway', 'favour']
# ['omg', ':(', 'everi', 'time', 'would', 'complain', 'skin', 'mom', 'everyon', 'get', 'pimpl', 'like', 'although']
# ['letsfootbal', 'atk', 'greymind', '43', 'break', 'news', 'chri', 'gayl', 'say', 'cricket', '2-3', 'month', 'due', 'back', 'surgeri', ':(', 'cplt', '20', 'cp', '…']
# ['miss', 'hannah', 'montana', "that'", 'raven', 'sooo', 'much', ':-(']
# ['want', 'rt', ':(']
# ['gonna', 'okay', 'love', ':(']
# ['awh', ':-(', '💙', 'stay', '💪']
# ['last', 'full', 'night', 'greec', ':(', 'opu', 'inner', 'pleasur']
# ['disappoint', 'hear', 'especi', 'invest', 'one', ':-(']
# ['ye', ':(', 'bbq', 'attend']
# ['work', ':(']
# ['three', '190', 'row', '33', ':(']
# ['throat', 'hurt', 'bad', ':(']
# ['lolliv', ':(']
# ['im', 'watch', 'disney', 'channel', ':(']
# ['nobodi', 'pick', 'one', 'right', ':(']
# ['someon', 'gift', ':(', 'calibraskaep', 'need', 'bad']
# ['lol', 'got', 'split', 'hard', 'lol', 'singl', 'singl', 'split', 'collat', 'spilt', 'singl', 'singl', 'spilt', 'singl', 'split', 'singl', 'singl', 'collat', ':(']
# ['hope', 'feel', 'better', 'jay', ':(']
# ['ye', 'mani', 'time', ':(', 'quitkarwaoyaaro']
# ['stu', 'deacti̇v', ':(']
# ['disappoint', ':(', 'never', 'ever', 'lucki', 'handl', 'jabongatpumaurbanstamped']
# ['hello', 'need', '2.5', 'g2a', 'code', 'pl', ':(']
# ['thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'thesi', 'sherep', 'nemen', 'ng', 'behey', 'ke', ':(']
# ['deactiv', 'acc', ':(', 'otwolgrandtrail']
# ['still', 'sad', 'kick', 'epic', 'motherfuck', ':(']
# ['realli', 'want', 'anoth', 'tattoo', ':(']
# ['someon', 'get', 'mad', 'reec', 'vm', 'tomorrow', 'pleas', 'never', 'one', ':(']
# ['deth', 'deth', 'dont', 'leav', ':(']
# ['true', ':-(']
# ["let'", 'go', '더쇼', 'cast', 'vote', 'got', '7', 'today', ':(']
# ['someon', 'hug', 'pl', ':(']
# ['omg', ':(', 'gonna', 'happen', 'yeah', 'wish', '..']
# [':(', 'lest', 'gp', 'get']
# ['aww', ':(', 'catch', 'departur']
# ['appar', 'isnt', ':(']
# ['miss', 'day', ':(', 'toothsensit']
# ['unavail', ':(']
# ['mean', "can't", 'wipe', ':-(']
# ['found', 'flight', 'home', '13', 'hour', 'long', ':(']
# ['ugh', 'yuck', ':(', 'make', 'sure', 'rest', 'next', 'two', 'day']
# ['omg', 'sad', 'birthday', 'sorri', 'didnt', 'send', 'someth', 'ystrday', 'ill', 'later', 'cuz', 'dont', 'phone', ':(']
# ['seolhyun', 'isnt', 'first', 'ep', 'she', 'film', 'drama', ':(']
# ['sorri', ':(']
# ['alway', 'get', 'like', '5', '4', 'piec', 'spici', 'nugget', ':(']
# ['im', 'sooo', 'hungri', 'though', ':(']
# ['thigh', 'cramp', ':-(']
# ['fellow', 'morn', 'owl', 'sure', 'notic', 'sun', 'alreadi', 'rise', 'bit', 'later', '...', 'sign', 'winter', 'come', ':(']
# ['nowher', 'near', 'tire', ':(']
# ['hot', ':(']
# ['dude', ':(', "i'm", 'scare', 'lol']
# ['rain', 'whole', 'day', 'mumbai', '’', 'feel', 'like', 'work', ':(']
# ['best', 'get', 'littl', 'ladi', "pj'", 'need', 'go', 'wallpap', 'mom', ':(', 'realli', 'cba', 'today']
# ['ye', 'pl', 'far', 'need', ':(']
# ['even', 'know', 'could', 'get', 'hotter', 'fml', ':(']
# ['aw', 'bless', 'made', 'smile', "i'm", 'miss', ':(']
# ['hi', 'life', ':(']
# ['mood', 'whole', 'day', ':-(']
# ['almost', 'done', 'park', 'rec', ':(', 'lol']
# ['u', 'come', 'back', ':(']
# ['hi', "we'r", 'sorri', 'hear', ':(', 'log', 'abl', 'see', 'inform', 'need']
# ['gotdamn', ':-(']
# ['want', 'phone', 'baaack', ':(']
# ['honest', 'miss', 'dubai', 'dubai', 'miss', 'want', 'come', 'back', ':(']
# ['final', 'get', 'star', 'driver', 'srw', 'mobag', ':(']
# ['sad', 'reason', 'suck', 'u', 'dunno', 'stop', 'sad', 'u', 'gotta', 'chill', 'ur', 'room', 'listen', 'music', 'b', 'alon', ':(']
# ['stream', 'pass', 'melon', 'pleas', 'stream', 'much', '인피니트', 'digit', 'bad', ':(']
# ['snapchat', 'jannygreen', '18', 'snapchat', 'kiksex', 'hot', 'teen', 'lgbt', 'goodmus', 'sexcam', ':(']
# ['aw', ':(', 'stroke']
# ['first', 'saw', 'gnr', 'open', 'alic', 'cooper', 'famou', 'parti', 'backstag', 'alic', 'r', 'slash', ':(']
# ['tag', '♡', "i'm", 'sorri', 'lot', 'music', 'prolli', 'know', 'half', ':(', 'also']
# ['24', 'hour', 'enough', ':(']
# ['awww', 'poor', 'bunni', ':(']
# ['stress', 'let', 'go', ':(']
# ['wish', 'blooper', ':(']
# ['love', 'u', 'fuck', 'know', ':(']
# ['yeah', ':(']
# ['noth', 'though', ':(']
# ['aww', "i'v", 'alreadi', 'left', 'would', 'come', 'said', 'hey', 'seen', 'sooner', ':(', 'good', 'night', 'x']
# ['weird', ':(']
# ['sr', 'financi', 'analyst', 'expedia', 'inc', 'bellevu', 'wa', 'financ', 'expediajob', 'job', 'job', 'hire']
# THE TWEET IS: Sr. Financial Analyst - Expedia, Inc.: (#Bellevue, WA) http://t.co/ktknMhvwCI #Finance #ExpediaJobs #Job #Jobs #Hiring
# THE PROCESSED TWEET IS: ['sr', 'financi', 'analyst', 'expedia', 'inc', 'bellevu', 'wa', 'financ', 'expediajob', 'job', 'job', 'hire']
# 0	0.50648699	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'
# ['serious', ':(']
# ['tri', 'make', 'prison', 'style', 'alcohol', 'fail', 'badli', 'end', 'massiv', 'dose', 'shit', '...', ':(']
# ['fair', 'still', 'look', 'cute', ':(']
# ['hi', 'love', 'u', ':(', ':(']
# ['overli', 'attach', ':(']
# ["m'", 'voic', ':(', 'lord', 'help']
# ['want', 'bandana', 'bottl', 'set', 'huhuh', ':(']
# ["can't", 'sleep', 'bc', 'heartburn', ':-(']
# ['meet', 'steven', 'kid', 'listen', ':(']
# ["i'm", 'fuck', 'jealou', 'everyon', 'holiday', ':(']
# ['terribl', 'thing', 'doin', 'yoga', 'work', 'stop', 'start', '...', 'awalmu', 'njareeem', ':(']
# ['nooo', 'last', 'day', 'today', ':(']
# ['care', 'maggi', 'psycho', 'bitch', 'want', 'kill', 'take', 'two', 'day', 'vacat', 'twitter', ':(', 'wahhh']
# ['realli', 'look', 'forward', 'work', 'tonight', 'though', ':(']
# ['miss', 'abudhabi', ':(']
# ['go', 'home', 'blue', ':-(', 'back', 'monday', 'hiby', 'social', 'action', 'plan', 'shareyoursumm']
# ['pro', 'soccer', 'play', 'would', 'cool', ':(']
# ['wish', 'b8', 'strong', ':(']
# ['hey', 'girl', 'must.b', 'dairi', 'produxt', 'want', "can't", 'lactos', 'intoler', ':(']
# ['midland', 'ye', 'thank', 'depress', 'weather', 'forecast', 'word', 'rain', 'mention', 'sever', 'time', ':-(']
# ['cri', ':(']
# ['old', 'one', 'day', '...', ':(']
# ['liter', 'spent', 'day', 'yesterday', 'sleep', 'bed', "i'm", 'still', 'absolut', 'fuck', 'knacker', 'today', ':(']
# ['new', 'sandra', 'bland', 'footag', 'realli', 'ice', 'cake', '..', 'heartbreak', 'drag', 'lifeless', 'bodi', 'polic', 'car', ':(']
# ['knowww', ':(']
# ["we'r", 'sorri', 'feel', 'way', 'shell', ':(', 'regularli', 'review', 'price', 'offer', 'best']
# ['sorri', 'hear', 'jess', ':(', 'quickest', 'way', 'call', '44', '7782', '333', '333', 'add', 'account', 'within', '72', 'hour']
# ['pengen', 'box', ':(', '—']
# ['girlll', 'u', 'hear', 'abt', 'possibl', 'tsunami', 'us', 'west', 'indi', 'im', 'island', 'im', 'afraid', 'lol', ':(']
# ['snap', ':(']
# ['would', 'love', 'see', 'w', 'nick', 'pick', 'one', 'waist', 'tv', 'time', 'never', 'work', 'anyway', ':(']
# ['hulk', 'hogan', 'news', 'racial', 'tirad', ':(', 'thought', 'couldnt', 'stoop', 'lower', 'role', 'thunder', 'paradis']
# ['sorri', 'forget', 'import', 'day', 'huhu', 'fight', 'im', 'sorri', ':(']
# ['break', 'habit', 'lifetim', '...', "i'm", 'play', 'call', 'duti', 'game', '..', ':(']
# ['apolog', 'annoy', 'much', 'snapchat', ':(']
# ['adult', 'take', 'thing', 'seriou', 'realli', 'miss', 'kid', ':(']
# ['facad', 'democraci', 'drop', 'quickli', ':(']
# ['confus', 'brat', ':(']
# ['someon', 'come', "i'll", 'make', 'popcorn', 'watch', 'movi', 'pl', 'cuddl', ':(']
# ['final', 'home', 'drive', 'sinc', '5am', ':(']
# ['tb', 'mr', "o'", 'class', ':(']
# ['bade', 'fursat', 'se', 'usey', 'banaya', 'hai', 'usey', 'uppar', 'waal', 'ney', 'afso', 'hums', 'dur', 'hai', 'wo', ':(']
# ['oh', 'realli', ':(', 'saw', 'gif', 'post', 'seen', 'realli', 'happi', 'mayb', 'peopl', "who'd", 'happi', 'naruhina']
# ["can't", ':(']
# ['that', 'english', 'namee', ':(', 'haiqal', 'isnt', 'english', 'name', 'rememb']
# ['want', 'dont', 'paypal', ':(']
# ["that'", '360hr', 'summer', 'end', '...', 'huhuhu', 'miss', 'picc', 'lot', ':(']
# ['heart', 'hurt', ':(']
# ['instor', 'card', 'expir', 'june', 'havent', 'sent', 'new', 'one', ':(']
# ['mcountdown', 'pre-vot', 'begin', '5th', 'place', ':(']
# ['felt', 'bad', 'iren', 'forgot', 'go', 'say', ':(']
# ['wow', "that'", 'great', "what'", 'usernam', ':(']
# ['minho', 'still', 'injur', ':(', 'get', 'well', 'oppa', 'miss', '<3']
# ["can't", 'even', 'deliv', 'ice', 'cream', 'tri', 'twice', 'ice', 'cream', 'van', 'busi', ':(']
# ['want', 'durian', 'strudel', ':(']
# ['vidcon', ':(']
# ['guy', 'add', 'snapchat', 'amargolonnard', 'snapchat', 'kikmeboy', 'sexi', 'french', 'dirtykik', 'newmus', 'sexcam', ':(']
# ['u', 'chang', 'u', 'say', 'chang', 'tsk', ':(']
# ['damn', '..', 'wish', 'could', 'sleep', ':(']
# ['like', 'join', 'marin', ':-(']
# ["i'm", 'sad', 'yall', 'thought', 'real', ':(']
# ["i'm", 'go', ':(', 'kailan', 'ba', 'may', 'tix', 'ka']
# ['alreadi', 'kill', 'tho', ':(']
# ['hotel', 'dog', 'pretti', 'sad', 'brother', 'sister', 'got', 'separ', ':(']
# ['miss', 'cute', 'someon', 'la', ':(']
# ['payday', 'feel', 'like', 'payhour', 'gone', 'bill', 'immedi', ':(']
# ['lmao', ':(', 'natur', 'hair', "i'v", 'seen', 'ugli', 'swear']
# ['nope', ':(', 'best', 'place', 'get', 'first', 'pre-ord', 'amazon']
# ['sunday', 'littl', 'abl', 'get', 'much', 'year', 'busi', ':(', 'look', 'great', 'tho']
# ['fwm', ':(']
# ["what'", 'wrong', ':(']
# ['miss', 'guppi', ':-(']
# ['go', 'away', '...', 'must', 'go', 'dentist', ':(', 'poorkid']
# ['thank', 'lack', 'time', 'problem', ':(']
# ['get', 'misunderstood', ':(']
# ['ur', 'cat', 'super', 'nice', 'cuddli', 'suddenli', 'scratch', 'tri', 'bite', ':(', 'like', 'trust', 'anymor']
# ['hit', 'thumb', ':(']
# ['almost', 'got', 'see', 'cute', 'ankl', 'sock', ':(']
# ['honestli', 'point', 'care', 'compens', 'want', 'abl', 'play', 'bf', ':(']
# ['song', ':(']
# ['awww', 'babi', ':(', '💕']
# ['sleep', 'last', 'night', 'n', 'help', 'wake', '8', 'morn', 'n', 'phone', 'even', 'charg', ':(']
# ['pleas', 'tell', 'everyon', 'didnt', 'go', 'vidcon', ':(']
# ['need', 'like', 'tell', 'na', 'na', 'okay', 'lang', ':(']
# ['follow', 'back', ':(']
# ['heart', 'current', 'tortur', ':(', 'lol', 'wat']
# ['femal', 'student', 'kill', 'cast', 'love', 'kirkiri', ':(']
# ["i'v", 'run', 'bread', 'feel', 'well', 'enough', 'make', ':(']
# ['dream', ':(']
# [':(', 'broken', 'heart', "that'", 'phase', 'worri']
# ['stop', 'sour', ':(', 'suit', '😂', '💞']
# ['wonho', 'remind', 'someon', '>:(', 'cant', 'put', 'finger']
# ['wont', 'work', 'today', 'feel', 'ill', ':(', 'tummi', 'bug', 'xx']
# ['last', 'day', 'beach', ':-(', ':-(', ':-(', '...']
# ['rain', ':(']
# ['visual', 'studio', '2015', 'got', 'switch', 'alreadi', 'broke', 'lot', 'code', ':(']
# ['serious', 'unfair', 'ask', 'question', 'readi', 'answer', 'win', ':(', "='(", 'busi', 'ask', 'question']
# ['mission', 'bear', 'fail', ':(']
# [':-(', 'ugli', 'af', ':-(']
# ['pap', 'spirit', 'anim', '—', 'dont', ':(']
# ['total', 'ship', 'danzel', "i'm", 'craft', "can't", 'go', 'vidcon', 'would', 'sell', 'soul', 'devil', 'get', 'hug', 'dan', 'phil', ':(']
# ['hate', ':(']
# ["he'", 'gona', 'miss', 'sheff', 'utd', 'york', 'probabl', 'wait', 'visa', 'leav', 'gim', '1', 'friendli', 'bet', 'start', 'season', 'bench', ':(']
# ['lead', 'us', 'gone', ':(']
# ['😂', '😩', '😩', 'mess', ':(']
# ['ironi', 'harm', '..', ':(']
# ['miss', 'much', ':(', 'xxx']
# ['motiv', ':(']
# ['point', 'yolo', 'sort', 'die', 'lactos', '...', 'ugh', 'like', '3', 'month', 'pregnant', 'bloat', ':(']
# ['realli', 'sorri', 'cant', 'find', 'imag', 'mention', ':(']
# ['im', 'get', 'olli', 'tweet', 'notif', ':(']
# ['go', 'home', 'tomorrow', ':-(']
# ['bad', "i'm", 'poor', ':(']
# ['team', 'kill', ':(']
# ['way', ':(']
# ["i'm", 'inact', ':(']
# [':(', 'world', 'alterni', 'kill', 'realli', 'sad', 'leav', 'place', 'everyon', 'die']
# ['everyon', 'gonna', 'talk', 'abt', 'rat', 'boy', 'today', 'bc', ':(']
# ['earth', 'assum', 'rain', 'london', 'like', 'influenc', 'overal', 'warm', 'dri', 'past', 'week', 'continent', 'europ', ':(']
# ['rememb', 'fab', 'four', '24', 'hour', 'call', 'damn', 'miss', 'much', ':(']
# ['😀', '🔫', 'r', 'u', 'sure', 'u', 'want', 'b', 'r', 'u', 'h', 'bare', 'surviv', 'w', 'tank', 'top', ':(']
# ['thirsti', ':(']
# ['konami', 'polici', 'pe', 'pc', 'version', 'happen', 'version', ':(']
# ['sound', 'effect', ':(']
# ['blame', 'ranti', ':(']
# ['ummm', 'ok', 'new', 'develop', ':(']
# ['guy', 'never', ':(', '—', 'aw', 'sorri', "we'r", 'realli', 'bust', 'atm', '..', 'shall', 'back', 'soon']
# ['bad', ':(', 'like', 'video', 'mani', 'pervers']
# ['first', 'time', 'go', 'school', 'without', 'bracelet', ':(', 'feel', 'odd']
# ["can't", 'fall', 'back', 'asleep', ':(']
# ['im', 'twin', 'follow', 'back', 'bylfnnz', ':(']
# ['unfair', '..', 'u', 'ban', 'film', 'pakistan', ':(']
# ['want', 'one', ':(']
# ['feel', 'sick', ':(']
# ['hmmm', '10', 'min', 'get', 'train', "i'm", 'current', '15', 'min', 'away', ':(', 'failsatlif']
# ["i'm", 'hungri', ':(']
# ['want', 'birthday', 'alreadi', ':(']
# ['complet', 'agre', 'press', ':(']
# ['im', 'super', 'duper', 'tire', ':(']
# ['bore', 'time', ':(', 'know', '...']
# ['ill', 'soon', 'promis', ':(', 'waaah']
# ['wanna', 'chang', 'avi', 'usanel', ':(']
# ['puppi', 'broke', 'foot', ':(']
# ["where'", 'jaebum', 'babi', 'pictur', ':(']
# ['mr', 'ahmad', 'maslan', 'cook', ':(']
# ['hull', 'support', 'expect', 'misser', 'week', ':-(']

# %% [markdown]
# Later in this specialization, we will see how we can use deeplearning to improve the prediction performance.

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [[0.48125421]]
# Negative sentiment
